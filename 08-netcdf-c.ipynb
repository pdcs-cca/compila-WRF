# %% [markdown]
# # netcdf-C

# %% [markdown]
# ## Configuración del código fuente

# %%
# %%bash -l
# #Inicializar entorno para el uso de compiladores INTEL
# pwd
# SETVARS_ARGS="--config=/opt/software/apps/intel/oneapi/config.txt"
# source /opt/software/apps/intel/oneapi/setvars.sh
#
# #Definir variables para el uso de los compiladores de intel
# #para la configuración del código fuente
# export CC=icc FC=ifort F77=ifort F90=ifort CXX=icpc
# export CFLAGS=" -O3"
# export CPPFLAGS="-I$HOME/tmp/2022/wrf/include"
# export LDFLAGS="-L$HOME/tmp/2022/wrf/lib -Wl,-rpath=$HOME/tmp/2022/wrf/lib"
#
# #Crear el directorio build  si  NO existe
# test ! -e build && mkdir -v build
# cd build
#
# #Desempaquetar código fuente
# tar xzf ../src/netcdf-c-4.8.1.tar.gz
# cd netcdf-c-4.8.1
#
# #Configurar el código fuentes usando los compiladores de intel
# #previamente se definieron las variables de entorno
# #CC, FC, F77, F90, CFLAGS
#
# #Se indica mediante la opción --prefix  el directorio de instalación
# ./configure --disable-dap-remote-tests --prefix=$HOME/tmp/2022/wrf
# Out:
# /LUSTRE/tmp/soporte/compila-WRF
#
# :: initializing oneAPI environment ...
#    bash: BASH_VERSION = 5.1.4(1)-release
#    args: Using "SETVARS_ARGS" for setvars.sh arguments: --config=/opt/software/apps/intel/oneapi/config.txt
# :: compiler -- latest
# :: mpi -- latest
# :: oneAPI environment initialized ::
#
# configure: netCDF 4.8.1
# checking build system type... x86_64-pc-linux-gnu
# checking host system type... x86_64-pc-linux-gnu
# checking target system type... x86_64-pc-linux-gnu
# checking for gcc... icc
# checking whether the C compiler works... yes
# checking for C compiler default output file name... a.out
# checking for suffix of executables...
# checking whether we are cross compiling... no
# checking for suffix of object files... o
# checking whether we are using the GNU C compiler... yes
# checking whether icc accepts -g... yes
# checking for icc option to accept ISO C89... none needed
# checking whether icc understands -c and -o together... yes
# checking whether compiler supports -fno-strict-aliasing... yes
# checking for a BSD-compatible install... /usr/bin/install -c
# checking whether build environment is sane... yes
# checking for a thread-safe mkdir -p... /usr/bin/mkdir -p
# checking for gawk... gawk
# checking whether make sets $(MAKE)... yes
# checking whether make supports the include directive... yes (GNU style)
# checking whether make supports nested variables... yes
# checking dependency style of icc... gcc3
# checking whether to enable maintainer-specific portions of Makefiles... no
# configure: checking supported formats
# checking whether we should build with netcdf4 (alias for HDF5)... yes (deprecated; Please use with --disable-hdf5)
# checking whether we should build with netcdf-4 (alias for HDF5)... yes
# checking whether we should build with HDF5... yes
# checking whether CDF5 support should be disabled... auto
# checking whether reading of HDF4 SD files is to be enabled... no
# checking whether parallel I/O for classic files is to be enabled... no
# checking for curl_easy_setopt in -lcurl... yes
# checking for library containing curl_easy_setopt... -lcurl
# checking whether DAP client(s) are to be built... yes
# checking whether netcdf zarr storage format should be disabled... yes
# checking whether netcdf-4 should be forcibly enabled... yes
# configure: checking user options
# checking whether a NCIO_MINBLOCKSIZE was specified... 256
# checking for valgrind... no
# checking if fsync support is enabled... no
# checking if jna bug workaround is enabled... no
# checking if unfixed tests with memory leaks should be enabled... no
# checking if unit tests should be disabled... yes
# checking do we require hdf5 dynamic-loading support... yes
# checking whether to fetch some sample HDF4 files from Unidata ftp site to test HDF4 reading (requires wget)... no
# checking whether we should attempt to install netcdf-fortran (EXPERIMENTAL)... no
# checking whether parallel IO tests should be run... no
# checking whether a user specified program to run mpi programs... mpiexec
# checking whether a default chunk size in bytes was specified... 4194304
# checking whether a maximum per-variable cache size for HDF5 was specified... 67108864
# checking whether a number of chunks for the default per-variable cache was specified... 10
# checking whether a default file cache size for HDF5 was specified... 16777216
# checking whether a default file cache maximum number of elements for HDF5 was specified... 4133
# checking whether a default cache preemption for HDF5 was specified... 0.75
# checking whether netCDF-4 logging is enabled... no
# checking whether nc_set_log_level() function is included (will do nothing unless enable-logging is also used)... yes
# checking whether CURLOPT_USERNAME is defined... yes
# checking whether CURLOPT_PASSWORD is defined... yes
# checking whether CURLOPT_KEYPASSWD is defined... yes
# checking whether CURLINFO_RESPONSE_CODE is defined... yes
# checking whether CURLOPT_BUFFERSIZE is defined... yes
# checking whether CURLOPT_TCP_KEEPALIVE is defined... yes
# checking whether libcurl is version 7.66 or later?... yes
# checking whether dap remote testing should be enabled... no
# checking whether dap remote authorization testing should be enabled (default off)... no
# checking which remote test server(s) to use... remotetest.unidata.ucar.edu
# checking whether the time-consuming dap tests should be enabled (default off)... no
# checking for zip_open in -lzip... no
# checking whether libzip library is available... no
# checking whether nczarr zip support is enabled... no
# checking whether netcdf zarr S3 support should be enabled... no
# checking whether AWS S3 SDK library is available... no
# checking whether netcdf zarr S3 testing should be enabled... no
# checking whether a default file cache size for NCZarr was specified... 4194304
# checking whether multi-filter support is enabled... yes
# checking whether to enable strict null-byte header padding when reading (default off)... no
# checking whether FFIO will be used... no
# checking whether STDIO will be used... no
# checking whether examples should be built... yes
# checking whether v2 netCDF API should be built... yes
# checking whether the ncgen/ncdump/nccopy should be built... yes
# checking whether test should be built and run... yes
# checking whether large file (> 2GB) tests should be run... no
# checking whether benchmarks should be run... no
# checking whether extreme numbers should be used in tests... yes
# checking where to put large temp files if large file tests are run... .
# checking Extra values for _NCProperties...
# checking whether user-defined format 0 was specified...
# checking whether a magic number for user-defined format 0 was specified...
# checking whether user-defined format 1 was specified...
# checking whether a magic number for user-defined format 1 was specified...
# configure: finding C compiler
# checking for gcc... (cached) icc
# checking whether we are using the GNU C compiler... (cached) yes
# checking whether icc accepts -g... (cached) yes
# checking for icc option to accept ISO C89... (cached) none needed
# checking whether icc understands -c and -o together... (cached) yes
# checking whether we are using the GNU C++ compiler... yes
# checking whether icpc accepts -g... yes
# checking dependency style of icpc... gcc3
# checking for an ANSI C-conforming const... yes
# configure: setting up libtool
# checking how to print strings... printf
# checking for a sed that does not truncate output... /usr/bin/sed
# checking for grep that handles long lines and -e... /usr/bin/grep
# checking for egrep... /usr/bin/grep -E
# checking for fgrep... /usr/bin/grep -F
# checking for ld used by icc... /usr/bin/ld
# checking if the linker (/usr/bin/ld) is GNU ld... yes
# checking for BSD- or MS-compatible name lister (nm)... /usr/bin/nm -B
# checking the name lister (/usr/bin/nm -B) interface... BSD nm
# checking whether ln -s works... yes
# checking the maximum length of command line arguments... 3458764513820540925
# checking how to convert x86_64-pc-linux-gnu file names to x86_64-pc-linux-gnu format... func_convert_file_noop
# checking how to convert x86_64-pc-linux-gnu file names to toolchain format... func_convert_file_noop
# checking for /usr/bin/ld option to reload object files... -r
# checking for objdump... objdump
# checking how to recognize dependent libraries... pass_all
# checking for dlltool... no
# checking how to associate runtime and link libraries... printf %s\n
# checking for ar... ar
# checking for archiver @FILE support... @
# checking for strip... strip
# checking for ranlib... ranlib
# checking command to parse /usr/bin/nm -B output from icc object... ok
# checking for sysroot... no
# checking for a working dd... /usr/bin/dd
# checking how to truncate binary pipes... /usr/bin/dd bs=4096 count=1
# checking for mt... mt
# checking if mt is a manifest tool... no
# checking how to run the C preprocessor... icc -E
# checking for ANSI C header files... yes
# checking for sys/types.h... yes
# checking for sys/stat.h... yes
# checking for stdlib.h... yes
# checking for string.h... yes
# checking for memory.h... yes
# checking for strings.h... yes
# checking for inttypes.h... yes
# checking for stdint.h... yes
# checking for unistd.h... yes
# checking for dlfcn.h... yes
# checking for objdir... .libs
# checking if icc supports -fno-rtti -fno-exceptions... yes
# checking for icc option to produce PIC... -fPIC -DPIC
# checking if icc PIC flag -fPIC -DPIC works... yes
# checking if icc static flag -static works... yes
# checking if icc supports -c -o file.o... yes
# checking if icc supports -c -o file.o... (cached) yes
# checking whether the icc linker (/usr/bin/ld -m elf_x86_64) supports shared libraries... yes
# checking whether -lc should be explicitly linked in... no
# checking dynamic linker characteristics... GNU/Linux ld.so
# checking how to hardcode library paths into programs... immediate
# checking whether stripping libraries is possible... yes
# checking if libtool supports shared libraries... yes
# checking whether to build shared libraries... yes
# checking whether to build static libraries... yes
# checking how to run the C++ preprocessor... icpc -E
# checking for ld used by icpc... /usr/bin/ld -m elf_x86_64
# checking if the linker (/usr/bin/ld -m elf_x86_64) is GNU ld... yes
# checking whether the icpc linker (/usr/bin/ld -m elf_x86_64) supports shared libraries... yes
# checking for icpc option to produce PIC... -fPIC -DPIC
# checking if icpc PIC flag -fPIC -DPIC works... yes
# checking if icpc static flag -static works... yes
# checking if icpc supports -c -o file.o... yes
# checking if icpc supports -c -o file.o... (cached) yes
# checking whether the icpc linker (/usr/bin/ld -m elf_x86_64) supports shared libraries... yes
# checking dynamic linker characteristics... (cached) GNU/Linux ld.so
# checking how to hardcode library paths into programs... immediate
# configure: finding other utilities
# checking for m4... m4
# checking for doxygen... doxygen
# checking for dot... dot
# checking for special C compiler options needed for large files... no
# checking for _FILE_OFFSET_BITS value needed for large files... no
# configure: displaying some results
# checking CPPFLAGS... -I/home/soporte/tmp/2022/wrf/include
# checking CC CFLAGS... icc  -O3 -fno-strict-aliasing
# checking type icc... icc is /opt/software/apps/intel/oneapi/compiler/2022.0.2/linux/bin/intel64/icc
# checking CXX... icpc
# checking CXXFLAGS... -g -O2
# checking type icpc... icpc is /opt/software/apps/intel/oneapi/compiler/2022.0.2/linux/bin/intel64/icpc
# checking FC... ifort
# checking FFLAGS...
# checking type ifort... ifort is /opt/software/apps/intel/oneapi/compiler/2022.0.2/linux/bin/intel64/ifort
# checking F90... ifort
# checking FCFLAGS...
# checking type ifort... ifort is /opt/software/apps/intel/oneapi/compiler/2022.0.2/linux/bin/intel64/ifort
# checking AR... ar
# checking AR_FLAGS... cr
# checking type ar... ar is /usr/bin/ar
# checking NM... /usr/bin/nm -B
# checking NMFLAGS...
# configure: checking types, headers, and functions
# checking sys/param.h usability... yes
# checking sys/param.h presence... yes
# checking for sys/param.h... yes
# checking libgen.h usability... yes
# checking libgen.h presence... yes
# checking for libgen.h... yes
# checking for ANSI C header files... (cached) yes
# checking locale.h usability... yes
# checking locale.h presence... yes
# checking for locale.h... yes
# checking stdio.h usability... yes
# checking stdio.h presence... yes
# checking for stdio.h... yes
# checking stdarg.h usability... yes
# checking stdarg.h presence... yes
# checking for stdarg.h... yes
# checking fcntl.h usability... yes
# checking fcntl.h presence... yes
# checking for fcntl.h... yes
# checking malloc.h usability... yes
# checking malloc.h presence... yes
# checking for malloc.h... yes
# checking for stdlib.h... (cached) yes
# checking for string.h... (cached) yes
# checking for strings.h... (cached) yes
# checking for unistd.h... (cached) yes
# checking for sys/stat.h... (cached) yes
# checking getopt.h usability... yes
# checking getopt.h presence... yes
# checking for getopt.h... yes
# checking sys/time.h usability... yes
# checking sys/time.h presence... yes
# checking for sys/time.h... yes
# checking for sys/types.h... (cached) yes
# checking time.h usability... yes
# checking time.h presence... yes
# checking for time.h... yes
# checking dirent.h usability... yes
# checking dirent.h presence... yes
# checking for dirent.h... yes
# checking sys/resource.h usability... yes
# checking sys/resource.h presence... yes
# checking for sys/resource.h... yes
# checking ftw.h usability... yes
# checking ftw.h presence... yes
# checking for ftw.h... yes
# checking execinfo.h usability... yes
# checking execinfo.h presence... yes
# checking for execinfo.h... yes
# checking for strlcat... no
# checking for snprintf... yes
# checking for strcasecmp... yes
# checking for fileno... yes
# checking for strdup... yes
# checking for strtoll... yes
# checking for strtoull... yes
# checking for mkstemp... yes
# checking for mktemp... yes
# checking for random... yes
# checking for getrlimit... yes
# checking for gettimeofday... yes
# checking for fsync... yes
# checking for MPI_Comm_f2c... no
# checking for MPI_Info_f2c... no
# checking for strncasecmp... yes
# checking for clock_gettime... yes
# checking for struct timespec... yes
# checking for memmove... yes
# checking for getpagesize... yes
# checking for sysconf... yes
# checking whether mmap is enabled for in-memory files... no
# checking for mmap... yes
# checking for mremap... yes
# checking whether MAP_ANONYMOUS is defined... yes
# mmap functionality is not available: disabling mmap
# checking whether byte range support is enabled... no
# checking for size_t... yes
# checking for working alloca.h... yes
# checking for alloca... yes
# checking whether isnan is declared... yes
# checking whether isinf is declared... yes
# checking whether isfinite is declared... yes
# checking for struct stat.st_blksize... yes
# checking for IEEE floating point format... yes
# checking for size_t... (cached) yes
# checking for ssize_t... yes
# checking for schar... no
# checking for uchar... no
# checking for longlong... no
# checking for ushort... yes
# checking for uint... yes
# checking for int64... no
# checking for uint64... no
# checking for size64_t... no
# checking for ssize64_t... no
# checking for _off64_t... no
# checking for uint64_t... yes
# checking for off_t... yes
# checking for uintptr_t... yes
# checking whether char is unsigned... no
# checking whether byte ordering is bigendian... no
# checking size of short... 2
# checking size of int... 4
# checking size of long... 8
# checking size of long long... 8
# checking size of float... 4
# checking size of double... 8
# checking size of off_t... 8
# checking size of size_t... 8
# checking size of unsigned long long... 8
# checking size of unsigned char... 1
# checking size of ushort... 2
# checking size of uint... 4
# checking size of ushort... (cached) 2
# checking size of uint... (cached) 4
# checking size of ssize_t... 8
# checking size of void*... 8
# checking for library containing deflate... -lz
# checking for library containing dlopen... none required
# checking for floor in -lm... yes
# checking for library containing H5Fflush... -lhdf5
# checking for library containing H5DSis_scale... -lhdf5_hl
# checking hdf5.h usability... yes
# checking hdf5.h presence... yes
# checking for hdf5.h... yes
# checking for H5Pget_fapl_mpio... no
# checking for H5Pset_deflate... yes
# checking for H5Z_SZIP... yes
# checking for H5free_memory... yes
# checking for H5resize_memory... yes
# checking for H5allocate_memory... yes
# checking for H5Pset_all_coll_metadata_ops... no
# checking for H5Literate... yes
# checking whether parallel io is enabled in hdf5... no
# checking for library containing H5Dread_chunk... none required
# checking for library containing H5Pset_fapl_ros3... no
# checking whether HDF5 allows parallel filters... yes
# checking whether szlib was used when building HDF5... yes
# checking whether HDF5 library is version 1.10.6 or later... yes
# checking whether parallel I/O is enabled for netcdf-4... no
# checking for unsigned long long int... yes
# checking for long long int... yes
# checking for unsigned long long int... (cached) yes
# checking what to call the output of the ftpbin target... binary-netcdf-4.8.1.tar ifort icpc
# checking if libtool needs -no-undefined flag to build shared libraries... no
# checking value of LIBS... -lhdf5_hl -lhdf5 -lm -lz -lcurl
# checking whether filter testing should be run... yes
# configure: generating header files and makefiles
# checking that generated files are newer than configure... done
# configure: creating ./config.status
# config.status: creating test_common.sh
# config.status: creating nczarr_test/timer_utils.h
# config.status: creating nczarr_test/timer_utils.c
# config.status: creating nc_test4/findplugin.sh
# config.status: creating examples/C/findplugin.sh
# config.status: creating ncdap_test/findtestserver.c
# config.status: creating dap4_test/findtestserver4.c
# config.status: creating dap4_test/pingurl4.c
# config.status: creating h5_test/run_par_tests.sh
# config.status: creating nc_test4/run_par_test.sh
# config.status: creating nc_perf/run_par_bm_test.sh
# config.status: creating nc_perf/run_gfs_test.sh
# config.status: creating examples/C/run_par_test.sh
# config.status: creating nc-config
# config.status: creating Makefile
# config.status: creating netcdf.pc
# config.status: creating libnetcdf.settings
# config.status: creating postinstall.sh
# config.status: creating include/netcdf_meta.h
# config.status: creating include/netcdf_dispatch.h
# config.status: creating include/Makefile
# config.status: creating h5_test/Makefile
# config.status: creating hdf4_test/Makefile
# config.status: creating libsrc/Makefile
# config.status: creating libsrc4/Makefile
# config.status: creating libhdf5/Makefile
# config.status: creating libsrcp/Makefile
# config.status: creating ncdump/Makefile
# config.status: creating ncgen3/Makefile
# config.status: creating ncgen/Makefile
# config.status: creating examples/Makefile
# config.status: creating examples/C/Makefile
# config.status: creating examples/CDL/Makefile
# config.status: creating oc2/Makefile
# config.status: creating libdap2/Makefile
# config.status: creating libdap4/Makefile
# config.status: creating libhdf4/Makefile
# config.status: creating libnczarr/Makefile
# config.status: creating libdispatch/Makefile
# config.status: creating liblib/Makefile
# config.status: creating ncdump/cdl/Makefile
# config.status: creating ncdump/expected/Makefile
# config.status: creating docs/Makefile
# config.status: creating docs/images/Makefile
# config.status: creating unit_test/Makefile
# config.status: creating nctest/Makefile
# config.status: creating nc_test4/Makefile
# config.status: creating nc_perf/Makefile
# config.status: creating nc_test/Makefile
# config.status: creating ncdap_test/Makefile
# config.status: creating ncdap_test/testdata3/Makefile
# config.status: creating ncdap_test/expected3/Makefile
# config.status: creating ncdap_test/expectremote3/Makefile
# config.status: creating dap4_test/Makefile
# config.status: creating plugins/Makefile
# config.status: creating nczarr_test/Makefile
# config.status: creating config.h
# config.status: linking dap4_test/baselinethredds/GOES16_TEST1.nc4.thredds to dap4_test/baselinethredds/GOES16_CONUS_20170821_020218_0.47_1km_33.3N_91.4W.nc4.thredds
# config.status: executing depfiles commands
# config.status: executing libtool commands
# # NetCDF C Configuration Summary
# ==============================
#
# # General
# -------
# NetCDF Version:		4.8.1
# Dispatch Version:       3
# Configured On:		Sun Apr 17 17:18:28 CDT 2022
# Host System:		x86_64-pc-linux-gnu
# Build Directory: 	/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1
# Install Prefix:         /home/soporte/tmp/2022/wrf
#
# # Compiling Options
# -----------------
# C Compiler:		/opt/software/apps/intel/oneapi/compiler/2022.0.2/linux/bin/intel64/icc
# CFLAGS:			 -O3 -fno-strict-aliasing
# CPPFLAGS:		-I/home/soporte/tmp/2022/wrf/include
# LDFLAGS:		-L/home/soporte/tmp/2022/wrf/lib -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib
# AM_CFLAGS:
# AM_CPPFLAGS:
# AM_LDFLAGS:
# Shared Library:		yes
# Static Library:		yes
# Extra libraries:	-lhdf5_hl -lhdf5 -lm -lz -lcurl
#
# # Features
# --------
# NetCDF-2 API:		yes
# HDF4 Support:		no
# HDF5 Support:		yes
# NetCDF-4 API:		yes
# NC-4 Parallel Support:	no
# PnetCDF Support:	no
# DAP2 Support:		yes
# DAP4 Support:		yes
# Byte-Range Support:	no
# Diskless Support:	yes
# MMap Support:		no
# JNA Support:		no
# CDF5 Support:		yes
# ERANGE Fill Support:	no
# Relaxed Boundary Check:	yes
# SZIP Support:           yes
# SZIP Write Support:     yes
# Parallel Filters:       yes
# NCZarr Support:		yes
# Multi-Filter Support:	yes
# configure: WARNING: AWS SDK not found; disabling S3 support
# configure: WARNING: Parallel io disabled for netcdf-4 because hdf5 does not support

# %% [markdown]
# ## Construcción o compilación de la biblioteca
#
# Se construye la biblioteca  con el comando __make__ y posteriormente se realizan pruebas de uso con el comando __make check__, por último se instala la biblioteca con el comando __make install__ en el directorio indicado con la opción  __--prefix__ durante el proceso de configuración.

# %%
# %%bash -l
# pwd
# SETVARS_ARGS="--config=/opt/software/apps/intel/oneapi/config.txt"
# source /opt/software/apps/intel/oneapi/setvars.sh
#
# #Ingresar al directorio del código fuente previamente desempaquetado
# #y configurado.
# #Utilizar la herramienta make para la construcción de la biblioteca
# cd build/netcdf-c-4.8.1
# \time -v make -j4
# Out:
# /LUSTRE/tmp/soporte/compila-WRF
#
# :: initializing oneAPI environment ...
#    bash: BASH_VERSION = 5.1.4(1)-release
#    args: Using "SETVARS_ARGS" for setvars.sh arguments: --config=/opt/software/apps/intel/oneapi/config.txt
# :: compiler -- latest
# :: mpi -- latest
# :: oneAPI environment initialized ::
#
# make  all-recursive
# make[1]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1'
# Making all in include
# make[2]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/include'
# make[2]: No se hace nada para 'all'.
# make[2]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/include'
# Making all in h5_test
# make[2]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/h5_test'
# make[2]: No se hace nada para 'all'.
# make[2]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/h5_test'
# Making all in libdispatch
# make[2]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/libdispatch'
# /bin/bash ../libtool  --tag=CC   --mode=compile icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT libdispatch_la-dparallel.lo -MD -MP -MF .deps/libdispatch_la-dparallel.Tpo -c -o libdispatch_la-dparallel.lo `test -f 'dparallel.c' || echo './'`dparallel.c
# /bin/bash ../libtool  --tag=CC   --mode=compile icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT libdispatch_la-dcopy.lo -MD -MP -MF .deps/libdispatch_la-dcopy.Tpo -c -o libdispatch_la-dcopy.lo `test -f 'dcopy.c' || echo './'`dcopy.c
# /bin/bash ../libtool  --tag=CC   --mode=compile icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT libdispatch_la-dfile.lo -MD -MP -MF .deps/libdispatch_la-dfile.Tpo -c -o libdispatch_la-dfile.lo `test -f 'dfile.c' || echo './'`dfile.c
# /bin/bash ../libtool  --tag=CC   --mode=compile icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT libdispatch_la-ddim.lo -MD -MP -MF .deps/libdispatch_la-ddim.Tpo -c -o libdispatch_la-ddim.lo `test -f 'ddim.c' || echo './'`ddim.c
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I.. -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include -O3 -fno-strict-aliasing -MT libdispatch_la-dparallel.lo -MD -MP -MF .deps/libdispatch_la-dparallel.Tpo -c dparallel.c  -fPIC -DPIC -o .libs/libdispatch_la-dparallel.o
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I.. -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include -O3 -fno-strict-aliasing -MT libdispatch_la-dcopy.lo -MD -MP -MF .deps/libdispatch_la-dcopy.Tpo -c dcopy.c  -fPIC -DPIC -o .libs/libdispatch_la-dcopy.o
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I.. -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include -O3 -fno-strict-aliasing -MT libdispatch_la-dfile.lo -MD -MP -MF .deps/libdispatch_la-dfile.Tpo -c dfile.c  -fPIC -DPIC -o .libs/libdispatch_la-dfile.o
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I.. -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include -O3 -fno-strict-aliasing -MT libdispatch_la-ddim.lo -MD -MP -MF .deps/libdispatch_la-ddim.Tpo -c ddim.c  -fPIC -DPIC -o .libs/libdispatch_la-ddim.o
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I.. -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include -O3 -fno-strict-aliasing -MT libdispatch_la-dparallel.lo -MD -MP -MF .deps/libdispatch_la-dparallel.Tpo -c dparallel.c -o libdispatch_la-dparallel.o >/dev/null 2>&1
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I.. -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include -O3 -fno-strict-aliasing -MT libdispatch_la-ddim.lo -MD -MP -MF .deps/libdispatch_la-ddim.Tpo -c ddim.c -o libdispatch_la-ddim.o >/dev/null 2>&1
# mv -f .deps/libdispatch_la-dparallel.Tpo .deps/libdispatch_la-dparallel.Plo
# /bin/bash ../libtool  --tag=CC   --mode=compile icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT libdispatch_la-datt.lo -MD -MP -MF .deps/libdispatch_la-datt.Tpo -c -o libdispatch_la-datt.lo `test -f 'datt.c' || echo './'`datt.c
# mv -f .deps/libdispatch_la-ddim.Tpo .deps/libdispatch_la-ddim.Plo
# /bin/bash ../libtool  --tag=CC   --mode=compile icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT libdispatch_la-dattinq.lo -MD -MP -MF .deps/libdispatch_la-dattinq.Tpo -c -o libdispatch_la-dattinq.lo `test -f 'dattinq.c' || echo './'`dattinq.c
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I.. -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include -O3 -fno-strict-aliasing -MT libdispatch_la-datt.lo -MD -MP -MF .deps/libdispatch_la-datt.Tpo -c datt.c  -fPIC -DPIC -o .libs/libdispatch_la-datt.o
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I.. -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include -O3 -fno-strict-aliasing -MT libdispatch_la-dfile.lo -MD -MP -MF .deps/libdispatch_la-dfile.Tpo -c dfile.c -o libdispatch_la-dfile.o >/dev/null 2>&1
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I.. -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include -O3 -fno-strict-aliasing -MT libdispatch_la-dattinq.lo -MD -MP -MF .deps/libdispatch_la-dattinq.Tpo -c dattinq.c  -fPIC -DPIC -o .libs/libdispatch_la-dattinq.o
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I.. -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include -O3 -fno-strict-aliasing -MT libdispatch_la-datt.lo -MD -MP -MF .deps/libdispatch_la-datt.Tpo -c datt.c -o libdispatch_la-datt.o >/dev/null 2>&1
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I.. -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include -O3 -fno-strict-aliasing -MT libdispatch_la-dattinq.lo -MD -MP -MF .deps/libdispatch_la-dattinq.Tpo -c dattinq.c -o libdispatch_la-dattinq.o >/dev/null 2>&1
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I.. -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include -O3 -fno-strict-aliasing -MT libdispatch_la-dcopy.lo -MD -MP -MF .deps/libdispatch_la-dcopy.Tpo -c dcopy.c -o libdispatch_la-dcopy.o >/dev/null 2>&1
# mv -f .deps/libdispatch_la-datt.Tpo .deps/libdispatch_la-datt.Plo
# /bin/bash ../libtool  --tag=CC   --mode=compile icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT libdispatch_la-dattput.lo -MD -MP -MF .deps/libdispatch_la-dattput.Tpo -c -o libdispatch_la-dattput.lo `test -f 'dattput.c' || echo './'`dattput.c
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I.. -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include -O3 -fno-strict-aliasing -MT libdispatch_la-dattput.lo -MD -MP -MF .deps/libdispatch_la-dattput.Tpo -c dattput.c  -fPIC -DPIC -o .libs/libdispatch_la-dattput.o
# mv -f .deps/libdispatch_la-dattinq.Tpo .deps/libdispatch_la-dattinq.Plo
# /bin/bash ../libtool  --tag=CC   --mode=compile icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT libdispatch_la-dattget.lo -MD -MP -MF .deps/libdispatch_la-dattget.Tpo -c -o libdispatch_la-dattget.lo `test -f 'dattget.c' || echo './'`dattget.c
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I.. -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include -O3 -fno-strict-aliasing -MT libdispatch_la-dattget.lo -MD -MP -MF .deps/libdispatch_la-dattget.Tpo -c dattget.c  -fPIC -DPIC -o .libs/libdispatch_la-dattget.o
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I.. -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include -O3 -fno-strict-aliasing -MT libdispatch_la-dattput.lo -MD -MP -MF .deps/libdispatch_la-dattput.Tpo -c dattput.c -o libdispatch_la-dattput.o >/dev/null 2>&1
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I.. -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include -O3 -fno-strict-aliasing -MT libdispatch_la-dattget.lo -MD -MP -MF .deps/libdispatch_la-dattget.Tpo -c dattget.c -o libdispatch_la-dattget.o >/dev/null 2>&1
# mv -f .deps/libdispatch_la-dfile.Tpo .deps/libdispatch_la-dfile.Plo
# /bin/bash ../libtool  --tag=CC   --mode=compile icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT libdispatch_la-derror.lo -MD -MP -MF .deps/libdispatch_la-derror.Tpo -c -o libdispatch_la-derror.lo `test -f 'derror.c' || echo './'`derror.c
# mv -f .deps/libdispatch_la-dattput.Tpo .deps/libdispatch_la-dattput.Plo
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I.. -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include -O3 -fno-strict-aliasing -MT libdispatch_la-derror.lo -MD -MP -MF .deps/libdispatch_la-derror.Tpo -c derror.c  -fPIC -DPIC -o .libs/libdispatch_la-derror.o
# /bin/bash ../libtool  --tag=CC   --mode=compile icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT libdispatch_la-dvar.lo -MD -MP -MF .deps/libdispatch_la-dvar.Tpo -c -o libdispatch_la-dvar.lo `test -f 'dvar.c' || echo './'`dvar.c
# mv -f .deps/libdispatch_la-dattget.Tpo .deps/libdispatch_la-dattget.Plo
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I.. -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include -O3 -fno-strict-aliasing -MT libdispatch_la-dvar.lo -MD -MP -MF .deps/libdispatch_la-dvar.Tpo -c dvar.c  -fPIC -DPIC -o .libs/libdispatch_la-dvar.o
# /bin/bash ../libtool  --tag=CC   --mode=compile icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT libdispatch_la-dvarget.lo -MD -MP -MF .deps/libdispatch_la-dvarget.Tpo -c -o libdispatch_la-dvarget.lo `test -f 'dvarget.c' || echo './'`dvarget.c
# mv -f .deps/libdispatch_la-dcopy.Tpo .deps/libdispatch_la-dcopy.Plo
# /bin/bash ../libtool  --tag=CC   --mode=compile icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT libdispatch_la-dvarput.lo -MD -MP -MF .deps/libdispatch_la-dvarput.Tpo -c -o libdispatch_la-dvarput.lo `test -f 'dvarput.c' || echo './'`dvarput.c
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I.. -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include -O3 -fno-strict-aliasing -MT libdispatch_la-dvarget.lo -MD -MP -MF .deps/libdispatch_la-dvarget.Tpo -c dvarget.c  -fPIC -DPIC -o .libs/libdispatch_la-dvarget.o
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I.. -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include -O3 -fno-strict-aliasing -MT libdispatch_la-dvarput.lo -MD -MP -MF .deps/libdispatch_la-dvarput.Tpo -c dvarput.c  -fPIC -DPIC -o .libs/libdispatch_la-dvarput.o
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I.. -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include -O3 -fno-strict-aliasing -MT libdispatch_la-derror.lo -MD -MP -MF .deps/libdispatch_la-derror.Tpo -c derror.c -o libdispatch_la-derror.o >/dev/null 2>&1
# mv -f .deps/libdispatch_la-derror.Tpo .deps/libdispatch_la-derror.Plo
# /bin/bash ../libtool  --tag=CC   --mode=compile icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT libdispatch_la-dvarinq.lo -MD -MP -MF .deps/libdispatch_la-dvarinq.Tpo -c -o libdispatch_la-dvarinq.lo `test -f 'dvarinq.c' || echo './'`dvarinq.c
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I.. -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include -O3 -fno-strict-aliasing -MT libdispatch_la-dvar.lo -MD -MP -MF .deps/libdispatch_la-dvar.Tpo -c dvar.c -o libdispatch_la-dvar.o >/dev/null 2>&1
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I.. -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include -O3 -fno-strict-aliasing -MT libdispatch_la-dvarinq.lo -MD -MP -MF .deps/libdispatch_la-dvarinq.Tpo -c dvarinq.c  -fPIC -DPIC -o .libs/libdispatch_la-dvarinq.o
# mv -f .deps/libdispatch_la-dvar.Tpo .deps/libdispatch_la-dvar.Plo
# /bin/bash ../libtool  --tag=CC   --mode=compile icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT libdispatch_la-dinternal.lo -MD -MP -MF .deps/libdispatch_la-dinternal.Tpo -c -o libdispatch_la-dinternal.lo `test -f 'dinternal.c' || echo './'`dinternal.c
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I.. -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include -O3 -fno-strict-aliasing -MT libdispatch_la-dvarinq.lo -MD -MP -MF .deps/libdispatch_la-dvarinq.Tpo -c dvarinq.c -o libdispatch_la-dvarinq.o >/dev/null 2>&1
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I.. -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include -O3 -fno-strict-aliasing -MT libdispatch_la-dinternal.lo -MD -MP -MF .deps/libdispatch_la-dinternal.Tpo -c dinternal.c  -fPIC -DPIC -o .libs/libdispatch_la-dinternal.o
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I.. -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include -O3 -fno-strict-aliasing -MT libdispatch_la-dvarget.lo -MD -MP -MF .deps/libdispatch_la-dvarget.Tpo -c dvarget.c -o libdispatch_la-dvarget.o >/dev/null 2>&1
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I.. -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include -O3 -fno-strict-aliasing -MT libdispatch_la-dinternal.lo -MD -MP -MF .deps/libdispatch_la-dinternal.Tpo -c dinternal.c -o libdispatch_la-dinternal.o >/dev/null 2>&1
# mv -f .deps/libdispatch_la-dvarinq.Tpo .deps/libdispatch_la-dvarinq.Plo
# mv -f .deps/libdispatch_la-dinternal.Tpo .deps/libdispatch_la-dinternal.Plo
# /bin/bash ../libtool  --tag=CC   --mode=compile icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT libdispatch_la-ddispatch.lo -MD -MP -MF .deps/libdispatch_la-ddispatch.Tpo -c -o libdispatch_la-ddispatch.lo `test -f 'ddispatch.c' || echo './'`ddispatch.c
# /bin/bash ../libtool  --tag=CC   --mode=compile icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT libdispatch_la-dutf8.lo -MD -MP -MF .deps/libdispatch_la-dutf8.Tpo -c -o libdispatch_la-dutf8.lo `test -f 'dutf8.c' || echo './'`dutf8.c
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I.. -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include -O3 -fno-strict-aliasing -MT libdispatch_la-dvarput.lo -MD -MP -MF .deps/libdispatch_la-dvarput.Tpo -c dvarput.c -o libdispatch_la-dvarput.o >/dev/null 2>&1
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I.. -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include -O3 -fno-strict-aliasing -MT libdispatch_la-dutf8.lo -MD -MP -MF .deps/libdispatch_la-dutf8.Tpo -c dutf8.c  -fPIC -DPIC -o .libs/libdispatch_la-dutf8.o
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I.. -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include -O3 -fno-strict-aliasing -MT libdispatch_la-ddispatch.lo -MD -MP -MF .deps/libdispatch_la-ddispatch.Tpo -c ddispatch.c  -fPIC -DPIC -o .libs/libdispatch_la-ddispatch.o
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I.. -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include -O3 -fno-strict-aliasing -MT libdispatch_la-dutf8.lo -MD -MP -MF .deps/libdispatch_la-dutf8.Tpo -c dutf8.c -o libdispatch_la-dutf8.o >/dev/null 2>&1
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I.. -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include -O3 -fno-strict-aliasing -MT libdispatch_la-ddispatch.lo -MD -MP -MF .deps/libdispatch_la-ddispatch.Tpo -c ddispatch.c -o libdispatch_la-ddispatch.o >/dev/null 2>&1
# mv -f .deps/libdispatch_la-dutf8.Tpo .deps/libdispatch_la-dutf8.Plo
# /bin/bash ../libtool  --tag=CC   --mode=compile icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT libdispatch_la-nclog.lo -MD -MP -MF .deps/libdispatch_la-nclog.Tpo -c -o libdispatch_la-nclog.lo `test -f 'nclog.c' || echo './'`nclog.c
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I.. -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include -O3 -fno-strict-aliasing -MT libdispatch_la-nclog.lo -MD -MP -MF .deps/libdispatch_la-nclog.Tpo -c nclog.c  -fPIC -DPIC -o .libs/libdispatch_la-nclog.o
# mv -f .deps/libdispatch_la-ddispatch.Tpo .deps/libdispatch_la-ddispatch.Plo
# /bin/bash ../libtool  --tag=CC   --mode=compile icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT libdispatch_la-dstring.lo -MD -MP -MF .deps/libdispatch_la-dstring.Tpo -c -o libdispatch_la-dstring.lo `test -f 'dstring.c' || echo './'`dstring.c
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I.. -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include -O3 -fno-strict-aliasing -MT libdispatch_la-dstring.lo -MD -MP -MF .deps/libdispatch_la-dstring.Tpo -c dstring.c  -fPIC -DPIC -o .libs/libdispatch_la-dstring.o
# mv -f .deps/libdispatch_la-dvarget.Tpo .deps/libdispatch_la-dvarget.Plo
# /bin/bash ../libtool  --tag=CC   --mode=compile icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT libdispatch_la-ncuri.lo -MD -MP -MF .deps/libdispatch_la-ncuri.Tpo -c -o libdispatch_la-ncuri.lo `test -f 'ncuri.c' || echo './'`ncuri.c
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I.. -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include -O3 -fno-strict-aliasing -MT libdispatch_la-nclog.lo -MD -MP -MF .deps/libdispatch_la-nclog.Tpo -c nclog.c -o libdispatch_la-nclog.o >/dev/null 2>&1
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I.. -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include -O3 -fno-strict-aliasing -MT libdispatch_la-ncuri.lo -MD -MP -MF .deps/libdispatch_la-ncuri.Tpo -c ncuri.c  -fPIC -DPIC -o .libs/libdispatch_la-ncuri.o
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I.. -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include -O3 -fno-strict-aliasing -MT libdispatch_la-dstring.lo -MD -MP -MF .deps/libdispatch_la-dstring.Tpo -c dstring.c -o libdispatch_la-dstring.o >/dev/null 2>&1
# mv -f .deps/libdispatch_la-nclog.Tpo .deps/libdispatch_la-nclog.Plo
# mv -f .deps/libdispatch_la-dvarput.Tpo .deps/libdispatch_la-dvarput.Plo
# /bin/bash ../libtool  --tag=CC   --mode=compile icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT libdispatch_la-nclist.lo -MD -MP -MF .deps/libdispatch_la-nclist.Tpo -c -o libdispatch_la-nclist.lo `test -f 'nclist.c' || echo './'`nclist.c
# /bin/bash ../libtool  --tag=CC   --mode=compile icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT libdispatch_la-ncbytes.lo -MD -MP -MF .deps/libdispatch_la-ncbytes.Tpo -c -o libdispatch_la-ncbytes.lo `test -f 'ncbytes.c' || echo './'`ncbytes.c
# mv -f .deps/libdispatch_la-dstring.Tpo .deps/libdispatch_la-dstring.Plo
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I.. -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include -O3 -fno-strict-aliasing -MT libdispatch_la-nclist.lo -MD -MP -MF .deps/libdispatch_la-nclist.Tpo -c nclist.c  -fPIC -DPIC -o .libs/libdispatch_la-nclist.o
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I.. -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include -O3 -fno-strict-aliasing -MT libdispatch_la-ncbytes.lo -MD -MP -MF .deps/libdispatch_la-ncbytes.Tpo -c ncbytes.c  -fPIC -DPIC -o .libs/libdispatch_la-ncbytes.o
# /bin/bash ../libtool  --tag=CC   --mode=compile icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT libdispatch_la-nchashmap.lo -MD -MP -MF .deps/libdispatch_la-nchashmap.Tpo -c -o libdispatch_la-nchashmap.lo `test -f 'nchashmap.c' || echo './'`nchashmap.c
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I.. -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include -O3 -fno-strict-aliasing -MT libdispatch_la-nchashmap.lo -MD -MP -MF .deps/libdispatch_la-nchashmap.Tpo -c nchashmap.c  -fPIC -DPIC -o .libs/libdispatch_la-nchashmap.o
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I.. -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include -O3 -fno-strict-aliasing -MT libdispatch_la-ncbytes.lo -MD -MP -MF .deps/libdispatch_la-ncbytes.Tpo -c ncbytes.c -o libdispatch_la-ncbytes.o >/dev/null 2>&1
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I.. -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include -O3 -fno-strict-aliasing -MT libdispatch_la-nclist.lo -MD -MP -MF .deps/libdispatch_la-nclist.Tpo -c nclist.c -o libdispatch_la-nclist.o >/dev/null 2>&1
# mv -f .deps/libdispatch_la-ncbytes.Tpo .deps/libdispatch_la-ncbytes.Plo
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I.. -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include -O3 -fno-strict-aliasing -MT libdispatch_la-nchashmap.lo -MD -MP -MF .deps/libdispatch_la-nchashmap.Tpo -c nchashmap.c -o libdispatch_la-nchashmap.o >/dev/null 2>&1
# /bin/bash ../libtool  --tag=CC   --mode=compile icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT libdispatch_la-nctime.lo -MD -MP -MF .deps/libdispatch_la-nctime.Tpo -c -o libdispatch_la-nctime.lo `test -f 'nctime.c' || echo './'`nctime.c
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I.. -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include -O3 -fno-strict-aliasing -MT libdispatch_la-nctime.lo -MD -MP -MF .deps/libdispatch_la-nctime.Tpo -c nctime.c  -fPIC -DPIC -o .libs/libdispatch_la-nctime.o
# mv -f .deps/libdispatch_la-nclist.Tpo .deps/libdispatch_la-nclist.Plo
# /bin/bash ../libtool  --tag=CC   --mode=compile icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT libdispatch_la-nc.lo -MD -MP -MF .deps/libdispatch_la-nc.Tpo -c -o libdispatch_la-nc.lo `test -f 'nc.c' || echo './'`nc.c
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I.. -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include -O3 -fno-strict-aliasing -MT libdispatch_la-nc.lo -MD -MP -MF .deps/libdispatch_la-nc.Tpo -c nc.c  -fPIC -DPIC -o .libs/libdispatch_la-nc.o
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I.. -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include -O3 -fno-strict-aliasing -MT libdispatch_la-ncuri.lo -MD -MP -MF .deps/libdispatch_la-ncuri.Tpo -c ncuri.c -o libdispatch_la-ncuri.o >/dev/null 2>&1
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I.. -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include -O3 -fno-strict-aliasing -MT libdispatch_la-nc.lo -MD -MP -MF .deps/libdispatch_la-nc.Tpo -c nc.c -o libdispatch_la-nc.o >/dev/null 2>&1
# mv -f .deps/libdispatch_la-nchashmap.Tpo .deps/libdispatch_la-nchashmap.Plo
# mv -f .deps/libdispatch_la-nc.Tpo .deps/libdispatch_la-nc.Plo
# /bin/bash ../libtool  --tag=CC   --mode=compile icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT libdispatch_la-nclistmgr.lo -MD -MP -MF .deps/libdispatch_la-nclistmgr.Tpo -c -o libdispatch_la-nclistmgr.lo `test -f 'nclistmgr.c' || echo './'`nclistmgr.c
# /bin/bash ../libtool  --tag=CC   --mode=compile icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT libdispatch_la-dauth.lo -MD -MP -MF .deps/libdispatch_la-dauth.Tpo -c -o libdispatch_la-dauth.lo `test -f 'dauth.c' || echo './'`dauth.c
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I.. -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include -O3 -fno-strict-aliasing -MT libdispatch_la-nclistmgr.lo -MD -MP -MF .deps/libdispatch_la-nclistmgr.Tpo -c nclistmgr.c  -fPIC -DPIC -o .libs/libdispatch_la-nclistmgr.o
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I.. -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include -O3 -fno-strict-aliasing -MT libdispatch_la-dauth.lo -MD -MP -MF .deps/libdispatch_la-dauth.Tpo -c dauth.c  -fPIC -DPIC -o .libs/libdispatch_la-dauth.o
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I.. -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include -O3 -fno-strict-aliasing -MT libdispatch_la-nctime.lo -MD -MP -MF .deps/libdispatch_la-nctime.Tpo -c nctime.c -o libdispatch_la-nctime.o >/dev/null 2>&1
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I.. -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include -O3 -fno-strict-aliasing -MT libdispatch_la-nclistmgr.lo -MD -MP -MF .deps/libdispatch_la-nclistmgr.Tpo -c nclistmgr.c -o libdispatch_la-nclistmgr.o >/dev/null 2>&1
# mv -f .deps/libdispatch_la-nclistmgr.Tpo .deps/libdispatch_la-nclistmgr.Plo
# /bin/bash ../libtool  --tag=CC   --mode=compile icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT libdispatch_la-doffsets.lo -MD -MP -MF .deps/libdispatch_la-doffsets.Tpo -c -o libdispatch_la-doffsets.lo `test -f 'doffsets.c' || echo './'`doffsets.c
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I.. -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include -O3 -fno-strict-aliasing -MT libdispatch_la-doffsets.lo -MD -MP -MF .deps/libdispatch_la-doffsets.Tpo -c doffsets.c  -fPIC -DPIC -o .libs/libdispatch_la-doffsets.o
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I.. -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include -O3 -fno-strict-aliasing -MT libdispatch_la-dauth.lo -MD -MP -MF .deps/libdispatch_la-dauth.Tpo -c dauth.c -o libdispatch_la-dauth.o >/dev/null 2>&1
# mv -f .deps/libdispatch_la-nctime.Tpo .deps/libdispatch_la-nctime.Plo
# /bin/bash ../libtool  --tag=CC   --mode=compile icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT libdispatch_la-dpathmgr.lo -MD -MP -MF .deps/libdispatch_la-dpathmgr.Tpo -c -o libdispatch_la-dpathmgr.lo `test -f 'dpathmgr.c' || echo './'`dpathmgr.c
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I.. -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include -O3 -fno-strict-aliasing -MT libdispatch_la-doffsets.lo -MD -MP -MF .deps/libdispatch_la-doffsets.Tpo -c doffsets.c -o libdispatch_la-doffsets.o >/dev/null 2>&1
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I.. -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include -O3 -fno-strict-aliasing -MT libdispatch_la-dpathmgr.lo -MD -MP -MF .deps/libdispatch_la-dpathmgr.Tpo -c dpathmgr.c  -fPIC -DPIC -o .libs/libdispatch_la-dpathmgr.o
# mv -f .deps/libdispatch_la-doffsets.Tpo .deps/libdispatch_la-doffsets.Plo
# /bin/bash ../libtool  --tag=CC   --mode=compile icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT libdispatch_la-dutil.lo -MD -MP -MF .deps/libdispatch_la-dutil.Tpo -c -o libdispatch_la-dutil.lo `test -f 'dutil.c' || echo './'`dutil.c
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I.. -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include -O3 -fno-strict-aliasing -MT libdispatch_la-dutil.lo -MD -MP -MF .deps/libdispatch_la-dutil.Tpo -c dutil.c  -fPIC -DPIC -o .libs/libdispatch_la-dutil.o
# mv -f .deps/libdispatch_la-ncuri.Tpo .deps/libdispatch_la-ncuri.Plo
# /bin/bash ../libtool  --tag=CC   --mode=compile icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT libdispatch_la-dreadonly.lo -MD -MP -MF .deps/libdispatch_la-dreadonly.Tpo -c -o libdispatch_la-dreadonly.lo `test -f 'dreadonly.c' || echo './'`dreadonly.c
# mv -f .deps/libdispatch_la-dauth.Tpo .deps/libdispatch_la-dauth.Plo
# /bin/bash ../libtool  --tag=CC   --mode=compile icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT libdispatch_la-dnotnc4.lo -MD -MP -MF .deps/libdispatch_la-dnotnc4.Tpo -c -o libdispatch_la-dnotnc4.lo `test -f 'dnotnc4.c' || echo './'`dnotnc4.c
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I.. -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include -O3 -fno-strict-aliasing -MT libdispatch_la-dreadonly.lo -MD -MP -MF .deps/libdispatch_la-dreadonly.Tpo -c dreadonly.c  -fPIC -DPIC -o .libs/libdispatch_la-dreadonly.o
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I.. -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include -O3 -fno-strict-aliasing -MT libdispatch_la-dnotnc4.lo -MD -MP -MF .deps/libdispatch_la-dnotnc4.Tpo -c dnotnc4.c  -fPIC -DPIC -o .libs/libdispatch_la-dnotnc4.o
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I.. -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include -O3 -fno-strict-aliasing -MT libdispatch_la-dpathmgr.lo -MD -MP -MF .deps/libdispatch_la-dpathmgr.Tpo -c dpathmgr.c -o libdispatch_la-dpathmgr.o >/dev/null 2>&1
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I.. -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include -O3 -fno-strict-aliasing -MT libdispatch_la-dreadonly.lo -MD -MP -MF .deps/libdispatch_la-dreadonly.Tpo -c dreadonly.c -o libdispatch_la-dreadonly.o >/dev/null 2>&1
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I.. -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include -O3 -fno-strict-aliasing -MT libdispatch_la-dutil.lo -MD -MP -MF .deps/libdispatch_la-dutil.Tpo -c dutil.c -o libdispatch_la-dutil.o >/dev/null 2>&1
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I.. -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include -O3 -fno-strict-aliasing -MT libdispatch_la-dnotnc4.lo -MD -MP -MF .deps/libdispatch_la-dnotnc4.Tpo -c dnotnc4.c -o libdispatch_la-dnotnc4.o >/dev/null 2>&1
# mv -f .deps/libdispatch_la-dreadonly.Tpo .deps/libdispatch_la-dreadonly.Plo
# /bin/bash ../libtool  --tag=CC   --mode=compile icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT libdispatch_la-dnotnc3.lo -MD -MP -MF .deps/libdispatch_la-dnotnc3.Tpo -c -o libdispatch_la-dnotnc3.lo `test -f 'dnotnc3.c' || echo './'`dnotnc3.c
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I.. -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include -O3 -fno-strict-aliasing -MT libdispatch_la-dnotnc3.lo -MD -MP -MF .deps/libdispatch_la-dnotnc3.Tpo -c dnotnc3.c  -fPIC -DPIC -o .libs/libdispatch_la-dnotnc3.o
# mv -f .deps/libdispatch_la-dnotnc4.Tpo .deps/libdispatch_la-dnotnc4.Plo
# /bin/bash ../libtool  --tag=CC   --mode=compile icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT libdispatch_la-daux.lo -MD -MP -MF .deps/libdispatch_la-daux.Tpo -c -o libdispatch_la-daux.lo `test -f 'daux.c' || echo './'`daux.c
# mv -f .deps/libdispatch_la-dutil.Tpo .deps/libdispatch_la-dutil.Plo
# /bin/bash ../libtool  --tag=CC   --mode=compile icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT libdispatch_la-dinfermodel.lo -MD -MP -MF .deps/libdispatch_la-dinfermodel.Tpo -c -o libdispatch_la-dinfermodel.lo `test -f 'dinfermodel.c' || echo './'`dinfermodel.c
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I.. -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include -O3 -fno-strict-aliasing -MT libdispatch_la-daux.lo -MD -MP -MF .deps/libdispatch_la-daux.Tpo -c daux.c  -fPIC -DPIC -o .libs/libdispatch_la-daux.o
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I.. -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include -O3 -fno-strict-aliasing -MT libdispatch_la-dnotnc3.lo -MD -MP -MF .deps/libdispatch_la-dnotnc3.Tpo -c dnotnc3.c -o libdispatch_la-dnotnc3.o >/dev/null 2>&1
# mv -f .deps/libdispatch_la-dpathmgr.Tpo .deps/libdispatch_la-dpathmgr.Plo
# /bin/bash ../libtool  --tag=CC   --mode=compile icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT libdispatch_la-dcrc32.lo -MD -MP -MF .deps/libdispatch_la-dcrc32.Tpo -c -o libdispatch_la-dcrc32.lo `test -f 'dcrc32.c' || echo './'`dcrc32.c
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I.. -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include -O3 -fno-strict-aliasing -MT libdispatch_la-dinfermodel.lo -MD -MP -MF .deps/libdispatch_la-dinfermodel.Tpo -c dinfermodel.c  -fPIC -DPIC -o .libs/libdispatch_la-dinfermodel.o
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I.. -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include -O3 -fno-strict-aliasing -MT libdispatch_la-dcrc32.lo -MD -MP -MF .deps/libdispatch_la-dcrc32.Tpo -c dcrc32.c  -fPIC -DPIC -o .libs/libdispatch_la-dcrc32.o
# mv -f .deps/libdispatch_la-dnotnc3.Tpo .deps/libdispatch_la-dnotnc3.Plo
# /bin/bash ../libtool  --tag=CC   --mode=compile icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT libdispatch_la-dcrc64.lo -MD -MP -MF .deps/libdispatch_la-dcrc64.Tpo -c -o libdispatch_la-dcrc64.lo `test -f 'dcrc64.c' || echo './'`dcrc64.c
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I.. -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include -O3 -fno-strict-aliasing -MT libdispatch_la-dcrc64.lo -MD -MP -MF .deps/libdispatch_la-dcrc64.Tpo -c dcrc64.c  -fPIC -DPIC -o .libs/libdispatch_la-dcrc64.o
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I.. -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include -O3 -fno-strict-aliasing -MT libdispatch_la-dcrc32.lo -MD -MP -MF .deps/libdispatch_la-dcrc32.Tpo -c dcrc32.c -o libdispatch_la-dcrc32.o >/dev/null 2>&1
# mv -f .deps/libdispatch_la-dcrc32.Tpo .deps/libdispatch_la-dcrc32.Plo
# /bin/bash ../libtool  --tag=CC   --mode=compile icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT libdispatch_la-ncexhash.lo -MD -MP -MF .deps/libdispatch_la-ncexhash.Tpo -c -o libdispatch_la-ncexhash.lo `test -f 'ncexhash.c' || echo './'`ncexhash.c
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I.. -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include -O3 -fno-strict-aliasing -MT libdispatch_la-ncexhash.lo -MD -MP -MF .deps/libdispatch_la-ncexhash.Tpo -c ncexhash.c  -fPIC -DPIC -o .libs/libdispatch_la-ncexhash.o
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I.. -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include -O3 -fno-strict-aliasing -MT libdispatch_la-daux.lo -MD -MP -MF .deps/libdispatch_la-daux.Tpo -c daux.c -o libdispatch_la-daux.o >/dev/null 2>&1
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I.. -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include -O3 -fno-strict-aliasing -MT libdispatch_la-dcrc64.lo -MD -MP -MF .deps/libdispatch_la-dcrc64.Tpo -c dcrc64.c -o libdispatch_la-dcrc64.o >/dev/null 2>&1
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I.. -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include -O3 -fno-strict-aliasing -MT libdispatch_la-dinfermodel.lo -MD -MP -MF .deps/libdispatch_la-dinfermodel.Tpo -c dinfermodel.c -o libdispatch_la-dinfermodel.o >/dev/null 2>&1
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I.. -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include -O3 -fno-strict-aliasing -MT libdispatch_la-ncexhash.lo -MD -MP -MF .deps/libdispatch_la-ncexhash.Tpo -c ncexhash.c -o libdispatch_la-ncexhash.o >/dev/null 2>&1
# mv -f .deps/libdispatch_la-dcrc64.Tpo .deps/libdispatch_la-dcrc64.Plo
# /bin/bash ../libtool  --tag=CC   --mode=compile icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT libdispatch_la-ncxcache.lo -MD -MP -MF .deps/libdispatch_la-ncxcache.Tpo -c -o libdispatch_la-ncxcache.lo `test -f 'ncxcache.c' || echo './'`ncxcache.c
# mv -f .deps/libdispatch_la-daux.Tpo .deps/libdispatch_la-daux.Plo
# /bin/bash ../libtool  --tag=CC   --mode=compile icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT libdispatch_la-ncjson.lo -MD -MP -MF .deps/libdispatch_la-ncjson.Tpo -c -o libdispatch_la-ncjson.lo `test -f 'ncjson.c' || echo './'`ncjson.c
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I.. -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include -O3 -fno-strict-aliasing -MT libdispatch_la-ncxcache.lo -MD -MP -MF .deps/libdispatch_la-ncxcache.Tpo -c ncxcache.c  -fPIC -DPIC -o .libs/libdispatch_la-ncxcache.o
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I.. -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include -O3 -fno-strict-aliasing -MT libdispatch_la-ncjson.lo -MD -MP -MF .deps/libdispatch_la-ncjson.Tpo -c ncjson.c  -fPIC -DPIC -o .libs/libdispatch_la-ncjson.o
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I.. -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include -O3 -fno-strict-aliasing -MT libdispatch_la-ncxcache.lo -MD -MP -MF .deps/libdispatch_la-ncxcache.Tpo -c ncxcache.c -o libdispatch_la-ncxcache.o >/dev/null 2>&1
# mv -f .deps/libdispatch_la-dinfermodel.Tpo .deps/libdispatch_la-dinfermodel.Plo
# /bin/bash ../libtool  --tag=CC   --mode=compile icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT libdispatch_la-utf8proc.lo -MD -MP -MF .deps/libdispatch_la-utf8proc.Tpo -c -o libdispatch_la-utf8proc.lo `test -f 'utf8proc.c' || echo './'`utf8proc.c
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I.. -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include -O3 -fno-strict-aliasing -MT libdispatch_la-utf8proc.lo -MD -MP -MF .deps/libdispatch_la-utf8proc.Tpo -c utf8proc.c  -fPIC -DPIC -o .libs/libdispatch_la-utf8proc.o
# mv -f .deps/libdispatch_la-ncxcache.Tpo .deps/libdispatch_la-ncxcache.Plo
# /bin/bash ../libtool  --tag=CC   --mode=compile icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT libdispatch_la-drc.lo -MD -MP -MF .deps/libdispatch_la-drc.Tpo -c -o libdispatch_la-drc.lo `test -f 'drc.c' || echo './'`drc.c
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I.. -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include -O3 -fno-strict-aliasing -MT libdispatch_la-drc.lo -MD -MP -MF .deps/libdispatch_la-drc.Tpo -c drc.c  -fPIC -DPIC -o .libs/libdispatch_la-drc.o
# mv -f .deps/libdispatch_la-ncexhash.Tpo .deps/libdispatch_la-ncexhash.Plo
# /bin/bash ../libtool  --tag=CC   --mode=compile icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT libdispatch_la-dgroup.lo -MD -MP -MF .deps/libdispatch_la-dgroup.Tpo -c -o libdispatch_la-dgroup.lo `test -f 'dgroup.c' || echo './'`dgroup.c
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I.. -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include -O3 -fno-strict-aliasing -MT libdispatch_la-dgroup.lo -MD -MP -MF .deps/libdispatch_la-dgroup.Tpo -c dgroup.c  -fPIC -DPIC -o .libs/libdispatch_la-dgroup.o
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I.. -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include -O3 -fno-strict-aliasing -MT libdispatch_la-dgroup.lo -MD -MP -MF .deps/libdispatch_la-dgroup.Tpo -c dgroup.c -o libdispatch_la-dgroup.o >/dev/null 2>&1
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I.. -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include -O3 -fno-strict-aliasing -MT libdispatch_la-drc.lo -MD -MP -MF .deps/libdispatch_la-drc.Tpo -c drc.c -o libdispatch_la-drc.o >/dev/null 2>&1
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I.. -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include -O3 -fno-strict-aliasing -MT libdispatch_la-ncjson.lo -MD -MP -MF .deps/libdispatch_la-ncjson.Tpo -c ncjson.c -o libdispatch_la-ncjson.o >/dev/null 2>&1
# mv -f .deps/libdispatch_la-dgroup.Tpo .deps/libdispatch_la-dgroup.Plo
# /bin/bash ../libtool  --tag=CC   --mode=compile icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT libdispatch_la-dvlen.lo -MD -MP -MF .deps/libdispatch_la-dvlen.Tpo -c -o libdispatch_la-dvlen.lo `test -f 'dvlen.c' || echo './'`dvlen.c
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I.. -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include -O3 -fno-strict-aliasing -MT libdispatch_la-utf8proc.lo -MD -MP -MF .deps/libdispatch_la-utf8proc.Tpo -c utf8proc.c -o libdispatch_la-utf8proc.o >/dev/null 2>&1
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I.. -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include -O3 -fno-strict-aliasing -MT libdispatch_la-dvlen.lo -MD -MP -MF .deps/libdispatch_la-dvlen.Tpo -c dvlen.c  -fPIC -DPIC -o .libs/libdispatch_la-dvlen.o
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I.. -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include -O3 -fno-strict-aliasing -MT libdispatch_la-dvlen.lo -MD -MP -MF .deps/libdispatch_la-dvlen.Tpo -c dvlen.c -o libdispatch_la-dvlen.o >/dev/null 2>&1
# mv -f .deps/libdispatch_la-dvlen.Tpo .deps/libdispatch_la-dvlen.Plo
# /bin/bash ../libtool  --tag=CC   --mode=compile icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT libdispatch_la-dcompound.lo -MD -MP -MF .deps/libdispatch_la-dcompound.Tpo -c -o libdispatch_la-dcompound.lo `test -f 'dcompound.c' || echo './'`dcompound.c
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I.. -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include -O3 -fno-strict-aliasing -MT libdispatch_la-dcompound.lo -MD -MP -MF .deps/libdispatch_la-dcompound.Tpo -c dcompound.c  -fPIC -DPIC -o .libs/libdispatch_la-dcompound.o
# mv -f .deps/libdispatch_la-drc.Tpo .deps/libdispatch_la-drc.Plo
# /bin/bash ../libtool  --tag=CC   --mode=compile icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT libdispatch_la-dtype.lo -MD -MP -MF .deps/libdispatch_la-dtype.Tpo -c -o libdispatch_la-dtype.lo `test -f 'dtype.c' || echo './'`dtype.c
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I.. -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include -O3 -fno-strict-aliasing -MT libdispatch_la-dtype.lo -MD -MP -MF .deps/libdispatch_la-dtype.Tpo -c dtype.c  -fPIC -DPIC -o .libs/libdispatch_la-dtype.o
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I.. -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include -O3 -fno-strict-aliasing -MT libdispatch_la-dcompound.lo -MD -MP -MF .deps/libdispatch_la-dcompound.Tpo -c dcompound.c -o libdispatch_la-dcompound.o >/dev/null 2>&1
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I.. -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include -O3 -fno-strict-aliasing -MT libdispatch_la-dtype.lo -MD -MP -MF .deps/libdispatch_la-dtype.Tpo -c dtype.c -o libdispatch_la-dtype.o >/dev/null 2>&1
# mv -f .deps/libdispatch_la-dcompound.Tpo .deps/libdispatch_la-dcompound.Plo
# /bin/bash ../libtool  --tag=CC   --mode=compile icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT libdispatch_la-denum.lo -MD -MP -MF .deps/libdispatch_la-denum.Tpo -c -o libdispatch_la-denum.lo `test -f 'denum.c' || echo './'`denum.c
# mv -f .deps/libdispatch_la-dtype.Tpo .deps/libdispatch_la-dtype.Plo
# /bin/bash ../libtool  --tag=CC   --mode=compile icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT libdispatch_la-dopaque.lo -MD -MP -MF .deps/libdispatch_la-dopaque.Tpo -c -o libdispatch_la-dopaque.lo `test -f 'dopaque.c' || echo './'`dopaque.c
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I.. -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include -O3 -fno-strict-aliasing -MT libdispatch_la-denum.lo -MD -MP -MF .deps/libdispatch_la-denum.Tpo -c denum.c  -fPIC -DPIC -o .libs/libdispatch_la-denum.o
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I.. -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include -O3 -fno-strict-aliasing -MT libdispatch_la-dopaque.lo -MD -MP -MF .deps/libdispatch_la-dopaque.Tpo -c dopaque.c  -fPIC -DPIC -o .libs/libdispatch_la-dopaque.o
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I.. -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include -O3 -fno-strict-aliasing -MT libdispatch_la-denum.lo -MD -MP -MF .deps/libdispatch_la-denum.Tpo -c denum.c -o libdispatch_la-denum.o >/dev/null 2>&1
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I.. -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include -O3 -fno-strict-aliasing -MT libdispatch_la-dopaque.lo -MD -MP -MF .deps/libdispatch_la-dopaque.Tpo -c dopaque.c -o libdispatch_la-dopaque.o >/dev/null 2>&1
# mv -f .deps/libdispatch_la-denum.Tpo .deps/libdispatch_la-denum.Plo
# /bin/bash ../libtool  --tag=CC   --mode=compile icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT libdispatch_la-dfilter.lo -MD -MP -MF .deps/libdispatch_la-dfilter.Tpo -c -o libdispatch_la-dfilter.lo `test -f 'dfilter.c' || echo './'`dfilter.c
# mv -f .deps/libdispatch_la-dopaque.Tpo .deps/libdispatch_la-dopaque.Plo
# /bin/bash ../libtool  --tag=CC   --mode=compile icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -DDLL_EXPORT -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT libnetcdf2_la-dv2i.lo -MD -MP -MF .deps/libnetcdf2_la-dv2i.Tpo -c -o libnetcdf2_la-dv2i.lo `test -f 'dv2i.c' || echo './'`dv2i.c
# mv -f .deps/libdispatch_la-utf8proc.Tpo .deps/libdispatch_la-utf8proc.Plo
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I.. -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include -O3 -fno-strict-aliasing -MT libdispatch_la-dfilter.lo -MD -MP -MF .deps/libdispatch_la-dfilter.Tpo -c dfilter.c  -fPIC -DPIC -o .libs/libdispatch_la-dfilter.o
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I.. -I../include -I../include -I../oc2 -DDLL_EXPORT -I/home/soporte/tmp/2022/wrf/include -O3 -fno-strict-aliasing -MT libnetcdf2_la-dv2i.lo -MD -MP -MF .deps/libnetcdf2_la-dv2i.Tpo -c dv2i.c  -fPIC -DPIC -o .libs/libnetcdf2_la-dv2i.o
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I.. -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include -O3 -fno-strict-aliasing -MT libdispatch_la-dfilter.lo -MD -MP -MF .deps/libdispatch_la-dfilter.Tpo -c dfilter.c -o libdispatch_la-dfilter.o >/dev/null 2>&1
# mv -f .deps/libdispatch_la-ncjson.Tpo .deps/libdispatch_la-ncjson.Plo
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I.. -I../include -I../include -I../oc2 -DDLL_EXPORT -I/home/soporte/tmp/2022/wrf/include -O3 -fno-strict-aliasing -MT libnetcdf2_la-dv2i.lo -MD -MP -MF .deps/libnetcdf2_la-dv2i.Tpo -c dv2i.c -o libnetcdf2_la-dv2i.o >/dev/null 2>&1
# mv -f .deps/libdispatch_la-dfilter.Tpo .deps/libdispatch_la-dfilter.Plo
# ...
# libtool: link: icc -shared  -fPIC -DPIC  .libs/H5Znoop.o .libs/H5Zutil.o   -Wl,-rpath -Wl,/home/soporte/tmp/2022/wrf/lib -Wl,-rpath -Wl,/home/soporte/tmp/2022/wrf/lib -L/home/soporte/tmp/2022/wrf/lib /home/soporte/tmp/2022/wrf/lib/libhdf5_hl.so /home/soporte/tmp/2022/wrf/lib/libhdf5.so -lm -lz /home/soporte/tmp/2022/wrf/lib/libcurl.so  -O3 -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib   -pthread -Wl,-soname -Wl,libnoop.so -o .libs/libnoop.so
# libtool: link: icc -shared  -fPIC -DPIC  .libs/H5Znoop1.o .libs/H5Zutil.o   -Wl,-rpath -Wl,/home/soporte/tmp/2022/wrf/lib -Wl,-rpath -Wl,/home/soporte/tmp/2022/wrf/lib -L/home/soporte/tmp/2022/wrf/lib /home/soporte/tmp/2022/wrf/lib/libhdf5_hl.so /home/soporte/tmp/2022/wrf/lib/libhdf5.so -lm -lz /home/soporte/tmp/2022/wrf/lib/libcurl.so  -O3 -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib   -pthread -Wl,-soname -Wl,libnoop1.so -o .libs/libnoop1.so
# libtool: link: ( cd ".libs" && rm -f "libmisc.la" && ln -s "../libmisc.la" "libmisc.la" )
# /bin/bash ../libtool  --tag=CC   --mode=link icc  -O3 -fno-strict-aliasing  -module -avoid-version -shared -export-dynamic -rpath /LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/plugins  -L/home/soporte/tmp/2022/wrf/lib -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o libh5bzip2.la -rpath /home/soporte/tmp/2022/wrf/lib H5Zbzip2.lo blocksort.lo huffman.lo crctable.lo randtable.lo compress.lo decompress.lo bzlib.lo    -lhdf5_hl -lhdf5 -lm -lz -lcurl
# libtool: link: ( cd ".libs" && rm -f "libnoop.la" && ln -s "../libnoop.la" "libnoop.la" )
# libtool: link: ( cd ".libs" && rm -f "libnoop1.la" && ln -s "../libnoop1.la" "libnoop1.la" )
# libtool: link: icc -shared  -fPIC -DPIC  .libs/H5Zbzip2.o .libs/blocksort.o .libs/huffman.o .libs/crctable.o .libs/randtable.o .libs/compress.o .libs/decompress.o .libs/bzlib.o   -Wl,-rpath -Wl,/home/soporte/tmp/2022/wrf/lib -Wl,-rpath -Wl,/home/soporte/tmp/2022/wrf/lib -L/home/soporte/tmp/2022/wrf/lib /home/soporte/tmp/2022/wrf/lib/libhdf5_hl.so /home/soporte/tmp/2022/wrf/lib/libhdf5.so -lm -lz /home/soporte/tmp/2022/wrf/lib/libcurl.so  -O3 -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib   -pthread -Wl,-soname -Wl,libh5bzip2.so -o .libs/libh5bzip2.so
# libtool: link: ( cd ".libs" && rm -f "libh5bzip2.la" && ln -s "../libh5bzip2.la" "libh5bzip2.la" )
# make[3]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/plugins'
# make[2]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/plugins'
# Making all in unit_test
# make[2]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/unit_test'
# make[2]: No se hace nada para 'all'.
# make[2]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/unit_test'
# Making all in nctest
# make[2]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/nctest'
# make[2]: No se hace nada para 'all'.
# make[2]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/nctest'
# Making all in nc_test
# make[2]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/nc_test'
# make[2]: No se hace nada para 'all'.
# make[2]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/nc_test'
# Making all in nc_test4
# make[2]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/nc_test4'
# make[2]: No se hace nada para 'all'.
# make[2]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/nc_test4'
# Making all in ncdap_test
# make[2]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/ncdap_test'
# echo "#DODSRC" >.dodsrc
# echo "HTTP.READ.BUFFERSIZE=max" >>.dodsrc
# echo "HTTP.KEEPALIVE=60/60" >>.dodsrc
# make  all-recursive
# make[3]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/ncdap_test'
# Making all in testdata3
# make[4]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/ncdap_test/testdata3'
# make[4]: No se hace nada para 'all'.
# make[4]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/ncdap_test/testdata3'
# Making all in expected3
# make[4]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/ncdap_test/expected3'
# make[4]: No se hace nada para 'all'.
# make[4]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/ncdap_test/expected3'
# Making all in expectremote3
# make[4]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/ncdap_test/expectremote3'
# make[4]: No se hace nada para 'all'.
# make[4]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/ncdap_test/expectremote3'
# make[4]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/ncdap_test'
# make[4]: No se hace nada para 'all-am'.
# make[4]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/ncdap_test'
# make[3]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/ncdap_test'
# make[2]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/ncdap_test'
# Making all in dap4_test
# make[2]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/dap4_test'
# echo "#DAPRC" >.daprc
# make  all-am
# make[3]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/dap4_test'
# depbase=`echo findtestserver4.o | sed 's|[^/]*$|.deps/&|;s|\.o$||'`;\
# icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I../liblib -I../libdap4 -DTOPSRCDIR=/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1 -DTOPBINDIR= -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT findtestserver4.o -MD -MP -MF $depbase.Tpo -c -o findtestserver4.o findtestserver4.c &&\
# mv -f $depbase.Tpo $depbase.Po
# depbase=`echo pingurl4.o | sed 's|[^/]*$|.deps/&|;s|\.o$||'`;\
# icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I../liblib -I../libdap4 -DTOPSRCDIR=/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1 -DTOPBINDIR= -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT pingurl4.o -MD -MP -MF $depbase.Tpo -c -o pingurl4.o pingurl4.c &&\
# mv -f $depbase.Tpo $depbase.Po
# /bin/bash ../libtool  --tag=CC   --mode=link icc  -O3 -fno-strict-aliasing  -L/home/soporte/tmp/2022/wrf/lib -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o pingurl4 pingurl4.o ../liblib/libnetcdf.la -lhdf5_hl -lhdf5 -lm -lz -lcurl
# /bin/bash ../libtool  --tag=CC   --mode=link icc  -O3 -fno-strict-aliasing  -L/home/soporte/tmp/2022/wrf/lib -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o findtestserver4 findtestserver4.o ../liblib/libnetcdf.la -lhdf5_hl -lhdf5 -lm -lz -lcurl
# libtool: link: icc -O3 -fno-strict-aliasing -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o .libs/pingurl4 pingurl4.o  -L/home/soporte/tmp/2022/wrf/lib ../liblib/.libs/libnetcdf.so /home/soporte/tmp/2022/wrf/lib/libhdf5_hl.so /home/soporte/tmp/2022/wrf/lib/libhdf5.so -lm -lz /home/soporte/tmp/2022/wrf/lib/libcurl.so -pthread -Wl,-rpath -Wl,/home/soporte/tmp/2022/wrf/lib
# libtool: link: icc -O3 -fno-strict-aliasing -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o .libs/findtestserver4 findtestserver4.o  -L/home/soporte/tmp/2022/wrf/lib ../liblib/.libs/libnetcdf.so /home/soporte/tmp/2022/wrf/lib/libhdf5_hl.so /home/soporte/tmp/2022/wrf/lib/libhdf5.so -lm -lz /home/soporte/tmp/2022/wrf/lib/libcurl.so -pthread -Wl,-rpath -Wl,/home/soporte/tmp/2022/wrf/lib
# make[3]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/dap4_test'
# make[2]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/dap4_test'
# Making all in nczarr_test
# make[2]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/nczarr_test'
# depbase=`echo zmapio.o | sed 's|[^/]*$|.deps/&|;s|\.o$||'`;\
# icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I.. -I../libnczarr -I../libnczarr -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT zmapio.o -MD -MP -MF $depbase.Tpo -c -o zmapio.o zmapio.c &&\
# mv -f $depbase.Tpo $depbase.Po
# depbase=`echo zhex.o | sed 's|[^/]*$|.deps/&|;s|\.o$||'`;\
# icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I.. -I../libnczarr -I../libnczarr -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT zhex.o -MD -MP -MF $depbase.Tpo -c -o zhex.o zhex.c &&\
# mv -f $depbase.Tpo $depbase.Po
# depbase=`echo zisjson.o | sed 's|[^/]*$|.deps/&|;s|\.o$||'`;\
# icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I.. -I../libnczarr -I../libnczarr -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT zisjson.o -MD -MP -MF $depbase.Tpo -c -o zisjson.o zisjson.c &&\
# mv -f $depbase.Tpo $depbase.Po
# depbase=`echo zs3parse.o | sed 's|[^/]*$|.deps/&|;s|\.o$||'`;\
# icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I.. -I../libnczarr -I../libnczarr -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT zs3parse.o -MD -MP -MF $depbase.Tpo -c -o zs3parse.o zs3parse.c &&\
# mv -f $depbase.Tpo $depbase.Po
# depbase=`echo ncdumpchunks.o | sed 's|[^/]*$|.deps/&|;s|\.o$||'`;\
# icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I.. -I../libnczarr -I../libnczarr -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT ncdumpchunks.o -MD -MP -MF $depbase.Tpo -c -o ncdumpchunks.o ncdumpchunks.c &&\
# mv -f $depbase.Tpo $depbase.Po
# /bin/bash ../libtool  --tag=CC   --mode=link icc  -O3 -fno-strict-aliasing  ../liblib/libnetcdf.la -L/home/soporte/tmp/2022/wrf/lib -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o zhex zhex.o ../liblib/libnetcdf.la -lhdf5_hl -lhdf5 -lm -lz -lcurl
# /bin/bash ../libtool  --tag=CC   --mode=link icc  -O3 -fno-strict-aliasing  ../liblib/libnetcdf.la -L/home/soporte/tmp/2022/wrf/lib -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o zisjson zisjson.o ../liblib/libnetcdf.la -lhdf5_hl -lhdf5 -lm -lz -lcurl
# libtool: link: icc -O3 -fno-strict-aliasing -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o .libs/zhex zhex.o  -L/home/soporte/tmp/2022/wrf/lib ../liblib/.libs/libnetcdf.so /home/soporte/tmp/2022/wrf/lib/libhdf5_hl.so /home/soporte/tmp/2022/wrf/lib/libhdf5.so -lm -lz /home/soporte/tmp/2022/wrf/lib/libcurl.so -pthread -Wl,-rpath -Wl,/home/soporte/tmp/2022/wrf/lib
# /bin/bash ../libtool  --tag=CC   --mode=link icc  -O3 -fno-strict-aliasing  ../liblib/libnetcdf.la -L/home/soporte/tmp/2022/wrf/lib -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o zs3parse zs3parse.o ../liblib/libnetcdf.la -lhdf5_hl -lhdf5 -lm -lz -lcurl
# libtool: link: icc -O3 -fno-strict-aliasing -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o .libs/zisjson zisjson.o  -L/home/soporte/tmp/2022/wrf/lib ../liblib/.libs/libnetcdf.so /home/soporte/tmp/2022/wrf/lib/libhdf5_hl.so /home/soporte/tmp/2022/wrf/lib/libhdf5.so -lm -lz /home/soporte/tmp/2022/wrf/lib/libcurl.so -pthread -Wl,-rpath -Wl,/home/soporte/tmp/2022/wrf/lib
# libtool: link: icc -O3 -fno-strict-aliasing -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o .libs/zs3parse zs3parse.o  -L/home/soporte/tmp/2022/wrf/lib ../liblib/.libs/libnetcdf.so /home/soporte/tmp/2022/wrf/lib/libhdf5_hl.so /home/soporte/tmp/2022/wrf/lib/libhdf5.so -lm -lz /home/soporte/tmp/2022/wrf/lib/libcurl.so -pthread -Wl,-rpath -Wl,/home/soporte/tmp/2022/wrf/lib
# /bin/bash ../libtool  --tag=CC   --mode=link icc  -O3 -fno-strict-aliasing  ../liblib/libnetcdf.la -L/home/soporte/tmp/2022/wrf/lib -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o zmapio zmapio.o ../liblib/libnetcdf.la -lhdf5_hl -lhdf5 -lm -lz -lcurl
# libtool: link: icc -O3 -fno-strict-aliasing -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o .libs/zmapio zmapio.o  -L/home/soporte/tmp/2022/wrf/lib ../liblib/.libs/libnetcdf.so /home/soporte/tmp/2022/wrf/lib/libhdf5_hl.so /home/soporte/tmp/2022/wrf/lib/libhdf5.so -lm -lz /home/soporte/tmp/2022/wrf/lib/libcurl.so -pthread -Wl,-rpath -Wl,/home/soporte/tmp/2022/wrf/lib
# /bin/bash ../libtool  --tag=CC   --mode=link icc  -O3 -fno-strict-aliasing  ../liblib/libnetcdf.la -L/home/soporte/tmp/2022/wrf/lib -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o ncdumpchunks ncdumpchunks.o ../liblib/libnetcdf.la -lhdf5_hl -lhdf5 -lm -lz -lcurl
# libtool: link: icc -O3 -fno-strict-aliasing -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o .libs/ncdumpchunks ncdumpchunks.o  -L/home/soporte/tmp/2022/wrf/lib ../liblib/.libs/libnetcdf.so /home/soporte/tmp/2022/wrf/lib/libhdf5_hl.so /home/soporte/tmp/2022/wrf/lib/libhdf5.so -lm -lz /home/soporte/tmp/2022/wrf/lib/libcurl.so -pthread -Wl,-rpath -Wl,/home/soporte/tmp/2022/wrf/lib
# make[2]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/nczarr_test'
# Making all in docs
# make[2]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/docs'
# Making all in images
# make[3]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/docs/images'
# make[3]: No se hace nada para 'all'.
# make[3]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/docs/images'
# make[3]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/docs'
# make[3]: No se hace nada para 'all-am'.
# make[3]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/docs'
# make[2]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/docs'
# Making all in examples
# make[2]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/examples'
# Making all in C
# make[3]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/examples/C'
# make[3]: No se hace nada para 'all'.
# make[3]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/examples/C'
# Making all in CDL
# make[3]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/examples/CDL'
# make[3]: No se hace nada para 'all'.
# make[3]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/examples/CDL'
# make[3]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/examples'
# make[3]: No se hace nada para 'all-am'.
# make[3]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/examples'
# make[2]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/examples'
# make[2]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1'
# make[2]: No se hace nada para 'all-am'.
# make[2]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1'
# make[1]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1'
# dcrc32.c(303): warning #180: argument is incompatible with formal parameter
#       value = crc32_z(value, cbuf, len);
#                                    ^
#
# dceparse.c(183): warning #810: conversion from "void *" to "CEsort={enum CEsort}" may lose significant bits
#       sel->operator = (CEsort)relop0;
#                       ^
#
# libtool: warning: ignoring multiple '-rpath's for a libtool library
# 	Command being timed: "make -j4"
# 	User time (seconds): 119.34
# 	System time (seconds): 18.48
# 	Percent of CPU this job got: 251%
# 	Elapsed (wall clock) time (h:mm:ss or m:ss): 0:54.69
# 	Average shared text size (kbytes): 0
# 	Average unshared data size (kbytes): 0
# 	Average stack size (kbytes): 0
# 	Average total size (kbytes): 0
# 	Maximum resident set size (kbytes): 256660
# 	Average resident set size (kbytes): 0
# 	Major (requiring I/O) page faults: 1705
# 	Minor (reclaiming a frame) page faults: 5028613
# 	Voluntary context switches: 58108
# 	Involuntary context switches: 2117
# 	Swaps: 0
# 	File system inputs: 9216
# 	File system outputs: 165736
# 	Socket messages sent: 0
# 	Socket messages received: 0
# 	Signals delivered: 0
# 	Page size (bytes): 4096
# 	Exit status: 0

# %%
# %%bash -l
# pwd
# SETVARS_ARGS="--config=/opt/software/apps/intel/oneapi/config.txt"
# source /opt/software/apps/intel/oneapi/setvars.sh
# cd build/netcdf-c-4.8.1
# \time -v make -j4 check
# Out:
# /LUSTRE/tmp/soporte/compila-WRF
#
# :: initializing oneAPI environment ...
#    bash: BASH_VERSION = 5.1.4(1)-release
#    args: Using "SETVARS_ARGS" for setvars.sh arguments: --config=/opt/software/apps/intel/oneapi/config.txt
# :: compiler -- latest
# :: mpi -- latest
# :: oneAPI environment initialized ::
#
# Making check in include
# make[1]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/include'
# make[1]: No se hace nada para 'check'.
# make[1]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/include'
# Making check in h5_test
# make[1]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/h5_test'
# make  tst_h_files tst_h_files2 tst_h_files4 tst_h_atts tst_h_atts3 tst_h_atts4 tst_h_vars tst_h_vars2 tst_h_vars3 tst_h_grps tst_h_compounds tst_h_compounds2 tst_h_wrt_cmp tst_h_vl tst_h_opaques tst_h_strings tst_h_strings1 tst_h_strings2 tst_h_ints tst_h_dimscales tst_h_dimscales1 tst_h_dimscales2 tst_h_dimscales3 tst_h_enums tst_h_dimscales4 tst_h_rename
# make[2]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/h5_test'
# depbase=`echo tst_h_files.o | sed 's|[^/]*$|.deps/&|;s|\.o$||'`;\
# icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT tst_h_files.o -MD -MP -MF $depbase.Tpo -c -o tst_h_files.o tst_h_files.c &&\
# mv -f $depbase.Tpo $depbase.Po
# depbase=`echo tst_h_files2.o | sed 's|[^/]*$|.deps/&|;s|\.o$||'`;\
# icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT tst_h_files2.o -MD -MP -MF $depbase.Tpo -c -o tst_h_files2.o tst_h_files2.c &&\
# mv -f $depbase.Tpo $depbase.Po
# depbase=`echo tst_h_files4.o | sed 's|[^/]*$|.deps/&|;s|\.o$||'`;\
# icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT tst_h_files4.o -MD -MP -MF $depbase.Tpo -c -o tst_h_files4.o tst_h_files4.c &&\
# mv -f $depbase.Tpo $depbase.Po
# depbase=`echo tst_h_atts.o | sed 's|[^/]*$|.deps/&|;s|\.o$||'`;\
# icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT tst_h_atts.o -MD -MP -MF $depbase.Tpo -c -o tst_h_atts.o tst_h_atts.c &&\
# mv -f $depbase.Tpo $depbase.Po
# depbase=`echo tst_h_atts3.o | sed 's|[^/]*$|.deps/&|;s|\.o$||'`;\
# icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT tst_h_atts3.o -MD -MP -MF $depbase.Tpo -c -o tst_h_atts3.o tst_h_atts3.c &&\
# mv -f $depbase.Tpo $depbase.Po
# depbase=`echo tst_h_atts4.o | sed 's|[^/]*$|.deps/&|;s|\.o$||'`;\
# icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT tst_h_atts4.o -MD -MP -MF $depbase.Tpo -c -o tst_h_atts4.o tst_h_atts4.c &&\
# mv -f $depbase.Tpo $depbase.Po
# depbase=`echo tst_h_vars.o | sed 's|[^/]*$|.deps/&|;s|\.o$||'`;\
# icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT tst_h_vars.o -MD -MP -MF $depbase.Tpo -c -o tst_h_vars.o tst_h_vars.c &&\
# mv -f $depbase.Tpo $depbase.Po
# depbase=`echo tst_h_vars2.o | sed 's|[^/]*$|.deps/&|;s|\.o$||'`;\
# icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT tst_h_vars2.o -MD -MP -MF $depbase.Tpo -c -o tst_h_vars2.o tst_h_vars2.c &&\
# mv -f $depbase.Tpo $depbase.Po
# depbase=`echo tst_h_vars3.o | sed 's|[^/]*$|.deps/&|;s|\.o$||'`;\
# icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT tst_h_vars3.o -MD -MP -MF $depbase.Tpo -c -o tst_h_vars3.o tst_h_vars3.c &&\
# mv -f $depbase.Tpo $depbase.Po
# depbase=`echo tst_h_grps.o | sed 's|[^/]*$|.deps/&|;s|\.o$||'`;\
# icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT tst_h_grps.o -MD -MP -MF $depbase.Tpo -c -o tst_h_grps.o tst_h_grps.c &&\
# mv -f $depbase.Tpo $depbase.Po
# depbase=`echo tst_h_compounds.o | sed 's|[^/]*$|.deps/&|;s|\.o$||'`;\
# icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT tst_h_compounds.o -MD -MP -MF $depbase.Tpo -c -o tst_h_compounds.o tst_h_compounds.c &&\
# mv -f $depbase.Tpo $depbase.Po
# depbase=`echo tst_h_compounds2.o | sed 's|[^/]*$|.deps/&|;s|\.o$||'`;\
# icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT tst_h_compounds2.o -MD -MP -MF $depbase.Tpo -c -o tst_h_compounds2.o tst_h_compounds2.c &&\
# mv -f $depbase.Tpo $depbase.Po
# depbase=`echo tst_h_wrt_cmp.o | sed 's|[^/]*$|.deps/&|;s|\.o$||'`;\
# icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT tst_h_wrt_cmp.o -MD -MP -MF $depbase.Tpo -c -o tst_h_wrt_cmp.o tst_h_wrt_cmp.c &&\
# mv -f $depbase.Tpo $depbase.Po
# depbase=`echo tst_h_vl.o | sed 's|[^/]*$|.deps/&|;s|\.o$||'`;\
# icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT tst_h_vl.o -MD -MP -MF $depbase.Tpo -c -o tst_h_vl.o tst_h_vl.c &&\
# mv -f $depbase.Tpo $depbase.Po
# depbase=`echo tst_h_opaques.o | sed 's|[^/]*$|.deps/&|;s|\.o$||'`;\
# icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT tst_h_opaques.o -MD -MP -MF $depbase.Tpo -c -o tst_h_opaques.o tst_h_opaques.c &&\
# mv -f $depbase.Tpo $depbase.Po
# depbase=`echo tst_h_strings.o | sed 's|[^/]*$|.deps/&|;s|\.o$||'`;\
# icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT tst_h_strings.o -MD -MP -MF $depbase.Tpo -c -o tst_h_strings.o tst_h_strings.c &&\
# mv -f $depbase.Tpo $depbase.Po
# depbase=`echo tst_h_strings1.o | sed 's|[^/]*$|.deps/&|;s|\.o$||'`;\
# icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT tst_h_strings1.o -MD -MP -MF $depbase.Tpo -c -o tst_h_strings1.o tst_h_strings1.c &&\
# mv -f $depbase.Tpo $depbase.Po
# depbase=`echo tst_h_strings2.o | sed 's|[^/]*$|.deps/&|;s|\.o$||'`;\
# icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT tst_h_strings2.o -MD -MP -MF $depbase.Tpo -c -o tst_h_strings2.o tst_h_strings2.c &&\
# mv -f $depbase.Tpo $depbase.Po
# depbase=`echo tst_h_ints.o | sed 's|[^/]*$|.deps/&|;s|\.o$||'`;\
# icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT tst_h_ints.o -MD -MP -MF $depbase.Tpo -c -o tst_h_ints.o tst_h_ints.c &&\
# mv -f $depbase.Tpo $depbase.Po
# depbase=`echo tst_h_dimscales.o | sed 's|[^/]*$|.deps/&|;s|\.o$||'`;\
# icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT tst_h_dimscales.o -MD -MP -MF $depbase.Tpo -c -o tst_h_dimscales.o tst_h_dimscales.c &&\
# mv -f $depbase.Tpo $depbase.Po
# depbase=`echo tst_h_dimscales1.o | sed 's|[^/]*$|.deps/&|;s|\.o$||'`;\
# icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT tst_h_dimscales1.o -MD -MP -MF $depbase.Tpo -c -o tst_h_dimscales1.o tst_h_dimscales1.c &&\
# mv -f $depbase.Tpo $depbase.Po
# depbase=`echo tst_h_dimscales2.o | sed 's|[^/]*$|.deps/&|;s|\.o$||'`;\
# icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT tst_h_dimscales2.o -MD -MP -MF $depbase.Tpo -c -o tst_h_dimscales2.o tst_h_dimscales2.c &&\
# mv -f $depbase.Tpo $depbase.Po
# depbase=`echo tst_h_dimscales3.o | sed 's|[^/]*$|.deps/&|;s|\.o$||'`;\
# icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT tst_h_dimscales3.o -MD -MP -MF $depbase.Tpo -c -o tst_h_dimscales3.o tst_h_dimscales3.c &&\
# mv -f $depbase.Tpo $depbase.Po
# depbase=`echo tst_h_enums.o | sed 's|[^/]*$|.deps/&|;s|\.o$||'`;\
# icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT tst_h_enums.o -MD -MP -MF $depbase.Tpo -c -o tst_h_enums.o tst_h_enums.c &&\
# mv -f $depbase.Tpo $depbase.Po
# depbase=`echo tst_h_dimscales4.o | sed 's|[^/]*$|.deps/&|;s|\.o$||'`;\
# icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT tst_h_dimscales4.o -MD -MP -MF $depbase.Tpo -c -o tst_h_dimscales4.o tst_h_dimscales4.c &&\
# mv -f $depbase.Tpo $depbase.Po
# depbase=`echo tst_h_rename.o | sed 's|[^/]*$|.deps/&|;s|\.o$||'`;\
# icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT tst_h_rename.o -MD -MP -MF $depbase.Tpo -c -o tst_h_rename.o tst_h_rename.c &&\
# mv -f $depbase.Tpo $depbase.Po
# /bin/bash ../libtool  --tag=CC   --mode=link icc  -O3 -fno-strict-aliasing  -L/home/soporte/tmp/2022/wrf/lib -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o tst_h_files tst_h_files.o  -lhdf5_hl -lhdf5 -lm -lz -lcurl
# /bin/bash ../libtool  --tag=CC   --mode=link icc  -O3 -fno-strict-aliasing  -L/home/soporte/tmp/2022/wrf/lib -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o tst_h_files2 tst_h_files2.o  -lhdf5_hl -lhdf5 -lm -lz -lcurl
# libtool: link: icc -O3 -fno-strict-aliasing -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o tst_h_files tst_h_files.o  -L/home/soporte/tmp/2022/wrf/lib /home/soporte/tmp/2022/wrf/lib/libhdf5_hl.so /home/soporte/tmp/2022/wrf/lib/libhdf5.so -lm -lz /home/soporte/tmp/2022/wrf/lib/libcurl.so -pthread -Wl,-rpath -Wl,/home/soporte/tmp/2022/wrf/lib -Wl,-rpath -Wl,/home/soporte/tmp/2022/wrf/lib
# libtool: link: icc -O3 -fno-strict-aliasing -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o tst_h_files2 tst_h_files2.o  -L/home/soporte/tmp/2022/wrf/lib /home/soporte/tmp/2022/wrf/lib/libhdf5_hl.so /home/soporte/tmp/2022/wrf/lib/libhdf5.so -lm -lz /home/soporte/tmp/2022/wrf/lib/libcurl.so -pthread -Wl,-rpath -Wl,/home/soporte/tmp/2022/wrf/lib -Wl,-rpath -Wl,/home/soporte/tmp/2022/wrf/lib
# /bin/bash ../libtool  --tag=CC   --mode=link icc  -O3 -fno-strict-aliasing  -L/home/soporte/tmp/2022/wrf/lib -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o tst_h_files4 tst_h_files4.o  -lhdf5_hl -lhdf5 -lm -lz -lcurl
# /bin/bash ../libtool  --tag=CC   --mode=link icc  -O3 -fno-strict-aliasing  -L/home/soporte/tmp/2022/wrf/lib -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o tst_h_atts tst_h_atts.o  -lhdf5_hl -lhdf5 -lm -lz -lcurl
# libtool: link: icc -O3 -fno-strict-aliasing -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o tst_h_files4 tst_h_files4.o  -L/home/soporte/tmp/2022/wrf/lib /home/soporte/tmp/2022/wrf/lib/libhdf5_hl.so /home/soporte/tmp/2022/wrf/lib/libhdf5.so -lm -lz /home/soporte/tmp/2022/wrf/lib/libcurl.so -pthread -Wl,-rpath -Wl,/home/soporte/tmp/2022/wrf/lib -Wl,-rpath -Wl,/home/soporte/tmp/2022/wrf/lib
# libtool: link: icc -O3 -fno-strict-aliasing -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o tst_h_atts tst_h_atts.o  -L/home/soporte/tmp/2022/wrf/lib /home/soporte/tmp/2022/wrf/lib/libhdf5_hl.so /home/soporte/tmp/2022/wrf/lib/libhdf5.so -lm -lz /home/soporte/tmp/2022/wrf/lib/libcurl.so -pthread -Wl,-rpath -Wl,/home/soporte/tmp/2022/wrf/lib -Wl,-rpath -Wl,/home/soporte/tmp/2022/wrf/lib
# /bin/bash ../libtool  --tag=CC   --mode=link icc  -O3 -fno-strict-aliasing  -L/home/soporte/tmp/2022/wrf/lib -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o tst_h_atts3 tst_h_atts3.o  -lhdf5_hl -lhdf5 -lm -lz -lcurl
# /bin/bash ../libtool  --tag=CC   --mode=link icc  -O3 -fno-strict-aliasing  -L/home/soporte/tmp/2022/wrf/lib -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o tst_h_atts4 tst_h_atts4.o  -lhdf5_hl -lhdf5 -lm -lz -lcurl
# libtool: link: icc -O3 -fno-strict-aliasing -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o tst_h_atts3 tst_h_atts3.o  -L/home/soporte/tmp/2022/wrf/lib /home/soporte/tmp/2022/wrf/lib/libhdf5_hl.so /home/soporte/tmp/2022/wrf/lib/libhdf5.so -lm -lz /home/soporte/tmp/2022/wrf/lib/libcurl.so -pthread -Wl,-rpath -Wl,/home/soporte/tmp/2022/wrf/lib -Wl,-rpath -Wl,/home/soporte/tmp/2022/wrf/lib
# libtool: link: icc -O3 -fno-strict-aliasing -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o tst_h_atts4 tst_h_atts4.o  -L/home/soporte/tmp/2022/wrf/lib /home/soporte/tmp/2022/wrf/lib/libhdf5_hl.so /home/soporte/tmp/2022/wrf/lib/libhdf5.so -lm -lz /home/soporte/tmp/2022/wrf/lib/libcurl.so -pthread -Wl,-rpath -Wl,/home/soporte/tmp/2022/wrf/lib -Wl,-rpath -Wl,/home/soporte/tmp/2022/wrf/lib
# /bin/bash ../libtool  --tag=CC   --mode=link icc  -O3 -fno-strict-aliasing  -L/home/soporte/tmp/2022/wrf/lib -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o tst_h_vars tst_h_vars.o  -lhdf5_hl -lhdf5 -lm -lz -lcurl
# /bin/bash ../libtool  --tag=CC   --mode=link icc  -O3 -fno-strict-aliasing  -L/home/soporte/tmp/2022/wrf/lib -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o tst_h_vars2 tst_h_vars2.o  -lhdf5_hl -lhdf5 -lm -lz -lcurl
# libtool: link: icc -O3 -fno-strict-aliasing -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o tst_h_vars tst_h_vars.o  -L/home/soporte/tmp/2022/wrf/lib /home/soporte/tmp/2022/wrf/lib/libhdf5_hl.so /home/soporte/tmp/2022/wrf/lib/libhdf5.so -lm -lz /home/soporte/tmp/2022/wrf/lib/libcurl.so -pthread -Wl,-rpath -Wl,/home/soporte/tmp/2022/wrf/lib -Wl,-rpath -Wl,/home/soporte/tmp/2022/wrf/lib
# libtool: link: icc -O3 -fno-strict-aliasing -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o tst_h_vars2 tst_h_vars2.o  -L/home/soporte/tmp/2022/wrf/lib /home/soporte/tmp/2022/wrf/lib/libhdf5_hl.so /home/soporte/tmp/2022/wrf/lib/libhdf5.so -lm -lz /home/soporte/tmp/2022/wrf/lib/libcurl.so -pthread -Wl,-rpath -Wl,/home/soporte/tmp/2022/wrf/lib -Wl,-rpath -Wl,/home/soporte/tmp/2022/wrf/lib
# /bin/bash ../libtool  --tag=CC   --mode=link icc  -O3 -fno-strict-aliasing  -L/home/soporte/tmp/2022/wrf/lib -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o tst_h_vars3 tst_h_vars3.o  -lhdf5_hl -lhdf5 -lm -lz -lcurl
# /bin/bash ../libtool  --tag=CC   --mode=link icc  -O3 -fno-strict-aliasing  -L/home/soporte/tmp/2022/wrf/lib -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o tst_h_grps tst_h_grps.o  -lhdf5_hl -lhdf5 -lm -lz -lcurl
# libtool: link: icc -O3 -fno-strict-aliasing -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o tst_h_vars3 tst_h_vars3.o  -L/home/soporte/tmp/2022/wrf/lib /home/soporte/tmp/2022/wrf/lib/libhdf5_hl.so /home/soporte/tmp/2022/wrf/lib/libhdf5.so -lm -lz /home/soporte/tmp/2022/wrf/lib/libcurl.so -pthread -Wl,-rpath -Wl,/home/soporte/tmp/2022/wrf/lib -Wl,-rpath -Wl,/home/soporte/tmp/2022/wrf/lib
# libtool: link: icc -O3 -fno-strict-aliasing -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o tst_h_grps tst_h_grps.o  -L/home/soporte/tmp/2022/wrf/lib /home/soporte/tmp/2022/wrf/lib/libhdf5_hl.so /home/soporte/tmp/2022/wrf/lib/libhdf5.so -lm -lz /home/soporte/tmp/2022/wrf/lib/libcurl.so -pthread -Wl,-rpath -Wl,/home/soporte/tmp/2022/wrf/lib -Wl,-rpath -Wl,/home/soporte/tmp/2022/wrf/lib
# /bin/bash ../libtool  --tag=CC   --mode=link icc  -O3 -fno-strict-aliasing  -L/home/soporte/tmp/2022/wrf/lib -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o tst_h_compounds tst_h_compounds.o  -lhdf5_hl -lhdf5 -lm -lz -lcurl
# /bin/bash ../libtool  --tag=CC   --mode=link icc  -O3 -fno-strict-aliasing  -L/home/soporte/tmp/2022/wrf/lib -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o tst_h_compounds2 tst_h_compounds2.o  -lhdf5_hl -lhdf5 -lm -lz -lcurl
# libtool: link: icc -O3 -fno-strict-aliasing -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o tst_h_compounds tst_h_compounds.o  -L/home/soporte/tmp/2022/wrf/lib /home/soporte/tmp/2022/wrf/lib/libhdf5_hl.so /home/soporte/tmp/2022/wrf/lib/libhdf5.so -lm -lz /home/soporte/tmp/2022/wrf/lib/libcurl.so -pthread -Wl,-rpath -Wl,/home/soporte/tmp/2022/wrf/lib -Wl,-rpath -Wl,/home/soporte/tmp/2022/wrf/lib
# libtool: link: icc -O3 -fno-strict-aliasing -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o tst_h_compounds2 tst_h_compounds2.o  -L/home/soporte/tmp/2022/wrf/lib /home/soporte/tmp/2022/wrf/lib/libhdf5_hl.so /home/soporte/tmp/2022/wrf/lib/libhdf5.so -lm -lz /home/soporte/tmp/2022/wrf/lib/libcurl.so -pthread -Wl,-rpath -Wl,/home/soporte/tmp/2022/wrf/lib -Wl,-rpath -Wl,/home/soporte/tmp/2022/wrf/lib
# /bin/bash ../libtool  --tag=CC   --mode=link icc  -O3 -fno-strict-aliasing  -L/home/soporte/tmp/2022/wrf/lib -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o tst_h_vl tst_h_vl.o  -lhdf5_hl -lhdf5 -lm -lz -lcurl
# /bin/bash ../libtool  --tag=CC   --mode=link icc  -O3 -fno-strict-aliasing  -L/home/soporte/tmp/2022/wrf/lib -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o tst_h_wrt_cmp tst_h_wrt_cmp.o  -lhdf5_hl -lhdf5 -lm -lz -lcurl
# libtool: link: icc -O3 -fno-strict-aliasing -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o tst_h_vl tst_h_vl.o  -L/home/soporte/tmp/2022/wrf/lib /home/soporte/tmp/2022/wrf/lib/libhdf5_hl.so /home/soporte/tmp/2022/wrf/lib/libhdf5.so -lm -lz /home/soporte/tmp/2022/wrf/lib/libcurl.so -pthread -Wl,-rpath -Wl,/home/soporte/tmp/2022/wrf/lib -Wl,-rpath -Wl,/home/soporte/tmp/2022/wrf/lib
# libtool: link: icc -O3 -fno-strict-aliasing -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o tst_h_wrt_cmp tst_h_wrt_cmp.o  -L/home/soporte/tmp/2022/wrf/lib /home/soporte/tmp/2022/wrf/lib/libhdf5_hl.so /home/soporte/tmp/2022/wrf/lib/libhdf5.so -lm -lz /home/soporte/tmp/2022/wrf/lib/libcurl.so -pthread -Wl,-rpath -Wl,/home/soporte/tmp/2022/wrf/lib -Wl,-rpath -Wl,/home/soporte/tmp/2022/wrf/lib
# /bin/bash ../libtool  --tag=CC   --mode=link icc  -O3 -fno-strict-aliasing  -L/home/soporte/tmp/2022/wrf/lib -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o tst_h_opaques tst_h_opaques.o  -lhdf5_hl -lhdf5 -lm -lz -lcurl
# /bin/bash ../libtool  --tag=CC   --mode=link icc  -O3 -fno-strict-aliasing  -L/home/soporte/tmp/2022/wrf/lib -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o tst_h_strings tst_h_strings.o  -lhdf5_hl -lhdf5 -lm -lz -lcurl
# libtool: link: icc -O3 -fno-strict-aliasing -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o tst_h_opaques tst_h_opaques.o  -L/home/soporte/tmp/2022/wrf/lib /home/soporte/tmp/2022/wrf/lib/libhdf5_hl.so /home/soporte/tmp/2022/wrf/lib/libhdf5.so -lm -lz /home/soporte/tmp/2022/wrf/lib/libcurl.so -pthread -Wl,-rpath -Wl,/home/soporte/tmp/2022/wrf/lib -Wl,-rpath -Wl,/home/soporte/tmp/2022/wrf/lib
# libtool: link: icc -O3 -fno-strict-aliasing -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o tst_h_strings tst_h_strings.o  -L/home/soporte/tmp/2022/wrf/lib /home/soporte/tmp/2022/wrf/lib/libhdf5_hl.so /home/soporte/tmp/2022/wrf/lib/libhdf5.so -lm -lz /home/soporte/tmp/2022/wrf/lib/libcurl.so -pthread -Wl,-rpath -Wl,/home/soporte/tmp/2022/wrf/lib -Wl,-rpath -Wl,/home/soporte/tmp/2022/wrf/lib
# /bin/bash ../libtool  --tag=CC   --mode=link icc  -O3 -fno-strict-aliasing  -L/home/soporte/tmp/2022/wrf/lib -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o tst_h_strings1 tst_h_strings1.o  -lhdf5_hl -lhdf5 -lm -lz -lcurl
# /bin/bash ../libtool  --tag=CC   --mode=link icc  -O3 -fno-strict-aliasing  -L/home/soporte/tmp/2022/wrf/lib -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o tst_h_strings2 tst_h_strings2.o  -lhdf5_hl -lhdf5 -lm -lz -lcurl
# libtool: link: icc -O3 -fno-strict-aliasing -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o tst_h_strings1 tst_h_strings1.o  -L/home/soporte/tmp/2022/wrf/lib /home/soporte/tmp/2022/wrf/lib/libhdf5_hl.so /home/soporte/tmp/2022/wrf/lib/libhdf5.so -lm -lz /home/soporte/tmp/2022/wrf/lib/libcurl.so -pthread -Wl,-rpath -Wl,/home/soporte/tmp/2022/wrf/lib -Wl,-rpath -Wl,/home/soporte/tmp/2022/wrf/lib
# libtool: link: icc -O3 -fno-strict-aliasing -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o tst_h_strings2 tst_h_strings2.o  -L/home/soporte/tmp/2022/wrf/lib /home/soporte/tmp/2022/wrf/lib/libhdf5_hl.so /home/soporte/tmp/2022/wrf/lib/libhdf5.so -lm -lz /home/soporte/tmp/2022/wrf/lib/libcurl.so -pthread -Wl,-rpath -Wl,/home/soporte/tmp/2022/wrf/lib -Wl,-rpath -Wl,/home/soporte/tmp/2022/wrf/lib
# /bin/bash ../libtool  --tag=CC   --mode=link icc  -O3 -fno-strict-aliasing  -L/home/soporte/tmp/2022/wrf/lib -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o tst_h_ints tst_h_ints.o  -lhdf5_hl -lhdf5 -lm -lz -lcurl
# /bin/bash ../libtool  --tag=CC   --mode=link icc  -O3 -fno-strict-aliasing  -L/home/soporte/tmp/2022/wrf/lib -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o tst_h_dimscales tst_h_dimscales.o  -lhdf5_hl -lhdf5 -lm -lz -lcurl
# libtool: link: icc -O3 -fno-strict-aliasing -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o tst_h_ints tst_h_ints.o  -L/home/soporte/tmp/2022/wrf/lib /home/soporte/tmp/2022/wrf/lib/libhdf5_hl.so /home/soporte/tmp/2022/wrf/lib/libhdf5.so -lm -lz /home/soporte/tmp/2022/wrf/lib/libcurl.so -pthread -Wl,-rpath -Wl,/home/soporte/tmp/2022/wrf/lib -Wl,-rpath -Wl,/home/soporte/tmp/2022/wrf/lib
# libtool: link: icc -O3 -fno-strict-aliasing -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o tst_h_dimscales tst_h_dimscales.o  -L/home/soporte/tmp/2022/wrf/lib /home/soporte/tmp/2022/wrf/lib/libhdf5_hl.so /home/soporte/tmp/2022/wrf/lib/libhdf5.so -lm -lz /home/soporte/tmp/2022/wrf/lib/libcurl.so -pthread -Wl,-rpath -Wl,/home/soporte/tmp/2022/wrf/lib -Wl,-rpath -Wl,/home/soporte/tmp/2022/wrf/lib
# /bin/bash ../libtool  --tag=CC   --mode=link icc  -O3 -fno-strict-aliasing  -L/home/soporte/tmp/2022/wrf/lib -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o tst_h_dimscales1 tst_h_dimscales1.o  -lhdf5_hl -lhdf5 -lm -lz -lcurl
# /bin/bash ../libtool  --tag=CC   --mode=link icc  -O3 -fno-strict-aliasing  -L/home/soporte/tmp/2022/wrf/lib -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o tst_h_dimscales2 tst_h_dimscales2.o  -lhdf5_hl -lhdf5 -lm -lz -lcurl
# /bin/bash ../libtool  --tag=CC   --mode=link icc  -O3 -fno-strict-aliasing  -L/home/soporte/tmp/2022/wrf/lib -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o tst_h_dimscales3 tst_h_dimscales3.o  -lhdf5_hl -lhdf5 -lm -lz -lcurl
# libtool: link: icc -O3 -fno-strict-aliasing -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o tst_h_dimscales2 tst_h_dimscales2.o  -L/home/soporte/tmp/2022/wrf/lib /home/soporte/tmp/2022/wrf/lib/libhdf5_hl.so /home/soporte/tmp/2022/wrf/lib/libhdf5.so -lm -lz /home/soporte/tmp/2022/wrf/lib/libcurl.so -pthread -Wl,-rpath -Wl,/home/soporte/tmp/2022/wrf/lib -Wl,-rpath -Wl,/home/soporte/tmp/2022/wrf/lib
# libtool: link: icc -O3 -fno-strict-aliasing -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o tst_h_dimscales1 tst_h_dimscales1.o  -L/home/soporte/tmp/2022/wrf/lib /home/soporte/tmp/2022/wrf/lib/libhdf5_hl.so /home/soporte/tmp/2022/wrf/lib/libhdf5.so -lm -lz /home/soporte/tmp/2022/wrf/lib/libcurl.so -pthread -Wl,-rpath -Wl,/home/soporte/tmp/2022/wrf/lib -Wl,-rpath -Wl,/home/soporte/tmp/2022/wrf/lib
# /bin/bash ../libtool  --tag=CC   --mode=link icc  -O3 -fno-strict-aliasing  -L/home/soporte/tmp/2022/wrf/lib -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o tst_h_enums tst_h_enums.o  -lhdf5_hl -lhdf5 -lm -lz -lcurl
# libtool: link: icc -O3 -fno-strict-aliasing -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o tst_h_dimscales3 tst_h_dimscales3.o  -L/home/soporte/tmp/2022/wrf/lib /home/soporte/tmp/2022/wrf/lib/libhdf5_hl.so /home/soporte/tmp/2022/wrf/lib/libhdf5.so -lm -lz /home/soporte/tmp/2022/wrf/lib/libcurl.so -pthread -Wl,-rpath -Wl,/home/soporte/tmp/2022/wrf/lib -Wl,-rpath -Wl,/home/soporte/tmp/2022/wrf/lib
# libtool: link: icc -O3 -fno-strict-aliasing -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o tst_h_enums tst_h_enums.o  -L/home/soporte/tmp/2022/wrf/lib /home/soporte/tmp/2022/wrf/lib/libhdf5_hl.so /home/soporte/tmp/2022/wrf/lib/libhdf5.so -lm -lz /home/soporte/tmp/2022/wrf/lib/libcurl.so -pthread -Wl,-rpath -Wl,/home/soporte/tmp/2022/wrf/lib -Wl,-rpath -Wl,/home/soporte/tmp/2022/wrf/lib
# /bin/bash ../libtool  --tag=CC   --mode=link icc  -O3 -fno-strict-aliasing  -L/home/soporte/tmp/2022/wrf/lib -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o tst_h_dimscales4 tst_h_dimscales4.o  -lhdf5_hl -lhdf5 -lm -lz -lcurl
# /bin/bash ../libtool  --tag=CC   --mode=link icc  -O3 -fno-strict-aliasing  -L/home/soporte/tmp/2022/wrf/lib -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o tst_h_rename tst_h_rename.o  -lhdf5_hl -lhdf5 -lm -lz -lcurl
# libtool: link: icc -O3 -fno-strict-aliasing -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o tst_h_rename tst_h_rename.o  -L/home/soporte/tmp/2022/wrf/lib /home/soporte/tmp/2022/wrf/lib/libhdf5_hl.so /home/soporte/tmp/2022/wrf/lib/libhdf5.so -lm -lz /home/soporte/tmp/2022/wrf/lib/libcurl.so -pthread -Wl,-rpath -Wl,/home/soporte/tmp/2022/wrf/lib -Wl,-rpath -Wl,/home/soporte/tmp/2022/wrf/lib
# libtool: link: icc -O3 -fno-strict-aliasing -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o tst_h_dimscales4 tst_h_dimscales4.o  -L/home/soporte/tmp/2022/wrf/lib /home/soporte/tmp/2022/wrf/lib/libhdf5_hl.so /home/soporte/tmp/2022/wrf/lib/libhdf5.so -lm -lz /home/soporte/tmp/2022/wrf/lib/libcurl.so -pthread -Wl,-rpath -Wl,/home/soporte/tmp/2022/wrf/lib -Wl,-rpath -Wl,/home/soporte/tmp/2022/wrf/lib
# make[2]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/h5_test'
# make  check-TESTS
# make[2]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/h5_test'
# make[3]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/h5_test'
# PASS: tst_h_files2
# PASS: tst_h_files4
# PASS: tst_h_files
# PASS: tst_h_atts4
# PASS: tst_h_atts3
# PASS: tst_h_atts
# PASS: tst_h_vars3
# PASS: tst_h_vars
# PASS: tst_h_grps
# PASS: tst_h_compounds2
# PASS: tst_h_wrt_cmp
# PASS: tst_h_vl
# PASS: tst_h_compounds
# PASS: tst_h_opaques
# PASS: tst_h_strings1
# PASS: tst_h_strings2
# PASS: tst_h_strings
# PASS: tst_h_ints
# PASS: tst_h_dimscales1
# PASS: tst_h_dimscales3
# PASS: tst_h_dimscales2
# PASS: tst_h_enums
# PASS: tst_h_dimscales
# PASS: tst_h_dimscales4
# PASS: tst_h_rename
# PASS: tst_h_vars2
# ============================================================================
# Testsuite summary for netCDF 4.8.1
# ============================================================================
# # TOTAL: 26
# # PASS:  26
# # SKIP:  0
# # XFAIL: 0
# # FAIL:  0
# # XPASS: 0
# # ERROR: 0
# ============================================================================
# make[3]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/h5_test'
# make[2]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/h5_test'
# make[1]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/h5_test'
# Making check in libdispatch
# make[1]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/libdispatch'
# make[1]: No se hace nada para 'check'.
# make[1]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/libdispatch'
# Making check in libsrc
# make[1]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/libsrc'
# make[1]: No se hace nada para 'check'.
# make[1]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/libsrc'
# Making check in libsrc4
# make[1]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/libsrc4'
# make[1]: No se hace nada para 'check'.
# make[1]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/libsrc4'
# Making check in libhdf5
# make[1]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/libhdf5'
# make[1]: No se hace nada para 'check'.
# make[1]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/libhdf5'
# Making check in oc2
# make[1]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/oc2'
# make[1]: No se hace nada para 'check'.
# make[1]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/oc2'
# Making check in libdap2
# make[1]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/libdap2'
# make[1]: No se hace nada para 'check'.
# make[1]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/libdap2'
# Making check in libdap4
# make[1]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/libdap4'
# make[1]: No se hace nada para 'check'.
# make[1]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/libdap4'
# Making check in libnczarr
# make[1]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/libnczarr'
# make[1]: No se hace nada para 'check'.
# make[1]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/libnczarr'
# Making check in liblib
# make[1]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/liblib'
# make[1]: No se hace nada para 'check'.
# make[1]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/liblib'
# Making check in ncgen3
# make[1]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/ncgen3'
# make  check-TESTS
# make[2]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/ncgen3'
# make[3]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/ncgen3'
# PASS: run_tests.sh
# PASS: run_nc4_tests.sh
# ============================================================================
# Testsuite summary for netCDF 4.8.1
# ============================================================================
# # TOTAL: 2
# # PASS:  2
# # SKIP:  0
# # XFAIL: 0
# # FAIL:  0
# # XPASS: 0
# # ERROR: 0
# ============================================================================
# make[3]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/ncgen3'
# make[2]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/ncgen3'
# make[1]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/ncgen3'
# Making check in ncgen
# make[1]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/ncgen'
# make[1]: No se hace nada para 'check'.
# make[1]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/ncgen'
# Making check in ncdump
# make[1]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/ncdump'
# Making check in cdl
# make[2]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/ncdump/cdl'
# make[2]: No se hace nada para 'check'.
# make[2]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/ncdump/cdl'
# Making check in expected
# make[2]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/ncdump/expected'
# make[2]: No se hace nada para 'check'.
# make[2]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/ncdump/expected'
# make[2]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/ncdump'
# make  rewrite-scalar ref_ctest ref_ctest64 ncdump tst_utf8 bom tst_dimsizes nctrunc tst_rcmerge tst_fileinfo tst_create_files tst_h_rdc0 tst_group_data tst_enum_data tst_opaque_data tst_string_data tst_vlen_data tst_comp tst_comp2 tst_nans tst_special_atts tst_unicode tst_fillbug tst_compress tst_chunking tst_h_scalar tst_vlen_demo
# make[3]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/ncdump'
# depbase=`echo rewrite-scalar.o | sed 's|[^/]*$|.deps/&|;s|\.o$||'`;\
# icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT rewrite-scalar.o -MD -MP -MF $depbase.Tpo -c -o rewrite-scalar.o rewrite-scalar.c &&\
# mv -f $depbase.Tpo $depbase.Po
# depbase=`echo ref_ctest.o | sed 's|[^/]*$|.deps/&|;s|\.o$||'`;\
# icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT ref_ctest.o -MD -MP -MF $depbase.Tpo -c -o ref_ctest.o ref_ctest.c &&\
# mv -f $depbase.Tpo $depbase.Po
# depbase=`echo ref_ctest64.o | sed 's|[^/]*$|.deps/&|;s|\.o$||'`;\
# icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT ref_ctest64.o -MD -MP -MF $depbase.Tpo -c -o ref_ctest64.o ref_ctest64.c &&\
# mv -f $depbase.Tpo $depbase.Po
# make[3]: 'ncdump' está actualizado.
# depbase=`echo tst_utf8.o | sed 's|[^/]*$|.deps/&|;s|\.o$||'`;\
# icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT tst_utf8.o -MD -MP -MF $depbase.Tpo -c -o tst_utf8.o tst_utf8.c &&\
# mv -f $depbase.Tpo $depbase.Po
# depbase=`echo bom.o | sed 's|[^/]*$|.deps/&|;s|\.o$||'`;\
# icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT bom.o -MD -MP -MF $depbase.Tpo -c -o bom.o bom.c &&\
# mv -f $depbase.Tpo $depbase.Po
# depbase=`echo tst_dimsizes.o | sed 's|[^/]*$|.deps/&|;s|\.o$||'`;\
# icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT tst_dimsizes.o -MD -MP -MF $depbase.Tpo -c -o tst_dimsizes.o tst_dimsizes.c &&\
# mv -f $depbase.Tpo $depbase.Po
# depbase=`echo nctrunc.o | sed 's|[^/]*$|.deps/&|;s|\.o$||'`;\
# icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT nctrunc.o -MD -MP -MF $depbase.Tpo -c -o nctrunc.o nctrunc.c &&\
# mv -f $depbase.Tpo $depbase.Po
# depbase=`echo tst_rcmerge.o | sed 's|[^/]*$|.deps/&|;s|\.o$||'`;\
# icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT tst_rcmerge.o -MD -MP -MF $depbase.Tpo -c -o tst_rcmerge.o tst_rcmerge.c &&\
# mv -f $depbase.Tpo $depbase.Po
# depbase=`echo tst_fileinfo.o | sed 's|[^/]*$|.deps/&|;s|\.o$||'`;\
# icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT tst_fileinfo.o -MD -MP -MF $depbase.Tpo -c -o tst_fileinfo.o tst_fileinfo.c &&\
# mv -f $depbase.Tpo $depbase.Po
# depbase=`echo tst_create_files.o | sed 's|[^/]*$|.deps/&|;s|\.o$||'`;\
# icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT tst_create_files.o -MD -MP -MF $depbase.Tpo -c -o tst_create_files.o tst_create_files.c &&\
# mv -f $depbase.Tpo $depbase.Po
# depbase=`echo tst_h_rdc0.o | sed 's|[^/]*$|.deps/&|;s|\.o$||'`;\
# icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT tst_h_rdc0.o -MD -MP -MF $depbase.Tpo -c -o tst_h_rdc0.o tst_h_rdc0.c &&\
# mv -f $depbase.Tpo $depbase.Po
# depbase=`echo tst_group_data.o | sed 's|[^/]*$|.deps/&|;s|\.o$||'`;\
# icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT tst_group_data.o -MD -MP -MF $depbase.Tpo -c -o tst_group_data.o tst_group_data.c &&\
# mv -f $depbase.Tpo $depbase.Po
# depbase=`echo tst_enum_data.o | sed 's|[^/]*$|.deps/&|;s|\.o$||'`;\
# icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT tst_enum_data.o -MD -MP -MF $depbase.Tpo -c -o tst_enum_data.o tst_enum_data.c &&\
# mv -f $depbase.Tpo $depbase.Po
# depbase=`echo tst_opaque_data.o | sed 's|[^/]*$|.deps/&|;s|\.o$||'`;\
# icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT tst_opaque_data.o -MD -MP -MF $depbase.Tpo -c -o tst_opaque_data.o tst_opaque_data.c &&\
# mv -f $depbase.Tpo $depbase.Po
# depbase=`echo tst_string_data.o | sed 's|[^/]*$|.deps/&|;s|\.o$||'`;\
# icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT tst_string_data.o -MD -MP -MF $depbase.Tpo -c -o tst_string_data.o tst_string_data.c &&\
# mv -f $depbase.Tpo $depbase.Po
# depbase=`echo tst_vlen_data.o | sed 's|[^/]*$|.deps/&|;s|\.o$||'`;\
# icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT tst_vlen_data.o -MD -MP -MF $depbase.Tpo -c -o tst_vlen_data.o tst_vlen_data.c &&\
# mv -f $depbase.Tpo $depbase.Po
# depbase=`echo tst_comp.o | sed 's|[^/]*$|.deps/&|;s|\.o$||'`;\
# icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT tst_comp.o -MD -MP -MF $depbase.Tpo -c -o tst_comp.o tst_comp.c &&\
# mv -f $depbase.Tpo $depbase.Po
# depbase=`echo tst_comp2.o | sed 's|[^/]*$|.deps/&|;s|\.o$||'`;\
# icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT tst_comp2.o -MD -MP -MF $depbase.Tpo -c -o tst_comp2.o tst_comp2.c &&\
# mv -f $depbase.Tpo $depbase.Po
# depbase=`echo tst_nans.o | sed 's|[^/]*$|.deps/&|;s|\.o$||'`;\
# icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT tst_nans.o -MD -MP -MF $depbase.Tpo -c -o tst_nans.o tst_nans.c &&\
# mv -f $depbase.Tpo $depbase.Po
# depbase=`echo tst_special_atts.o | sed 's|[^/]*$|.deps/&|;s|\.o$||'`;\
# icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT tst_special_atts.o -MD -MP -MF $depbase.Tpo -c -o tst_special_atts.o tst_special_atts.c &&\
# mv -f $depbase.Tpo $depbase.Po
# depbase=`echo tst_unicode.o | sed 's|[^/]*$|.deps/&|;s|\.o$||'`;\
# icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT tst_unicode.o -MD -MP -MF $depbase.Tpo -c -o tst_unicode.o tst_unicode.c &&\
# mv -f $depbase.Tpo $depbase.Po
# depbase=`echo tst_fillbug.o | sed 's|[^/]*$|.deps/&|;s|\.o$||'`;\
# icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT tst_fillbug.o -MD -MP -MF $depbase.Tpo -c -o tst_fillbug.o tst_fillbug.c &&\
# mv -f $depbase.Tpo $depbase.Po
# depbase=`echo tst_compress.o | sed 's|[^/]*$|.deps/&|;s|\.o$||'`;\
# icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT tst_compress.o -MD -MP -MF $depbase.Tpo -c -o tst_compress.o tst_compress.c &&\
# mv -f $depbase.Tpo $depbase.Po
# depbase=`echo tst_chunking.o | sed 's|[^/]*$|.deps/&|;s|\.o$||'`;\
# icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT tst_chunking.o -MD -MP -MF $depbase.Tpo -c -o tst_chunking.o tst_chunking.c &&\
# mv -f $depbase.Tpo $depbase.Po
# depbase=`echo tst_h_scalar.o | sed 's|[^/]*$|.deps/&|;s|\.o$||'`;\
# icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT tst_h_scalar.o -MD -MP -MF $depbase.Tpo -c -o tst_h_scalar.o tst_h_scalar.c &&\
# mv -f $depbase.Tpo $depbase.Po
# depbase=`echo tst_vlen_demo.o | sed 's|[^/]*$|.deps/&|;s|\.o$||'`;\
# icc -DHAVE_CONFIG_H -I. -I..  -I../include -I../include -I../oc2 -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT tst_vlen_demo.o -MD -MP -MF $depbase.Tpo -c -o tst_vlen_demo.o tst_vlen_demo.c &&\
# mv -f $depbase.Tpo $depbase.Po
# /bin/bash ../libtool  --tag=CC   --mode=link icc  -O3 -fno-strict-aliasing  -L/home/soporte/tmp/2022/wrf/lib -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o rewrite-scalar rewrite-scalar.o ../liblib/libnetcdf.la -lhdf5_hl -lhdf5 -lm -lz -lcurl
# /bin/bash ../libtool  --tag=CC   --mode=link icc  -O3 -fno-strict-aliasing  -L/home/soporte/tmp/2022/wrf/lib -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o ref_ctest ref_ctest.o ../liblib/libnetcdf.la -lhdf5_hl -lhdf5 -lm -lz -lcurl
# /bin/bash ../libtool  --tag=CC   --mode=link icc  -O3 -fno-strict-aliasing  -L/home/soporte/tmp/2022/wrf/lib -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o ref_ctest64 ref_ctest64.o ../liblib/libnetcdf.la -lhdf5_hl -lhdf5 -lm -lz -lcurl
# /bin/bash ../libtool  --tag=CC   --mode=link icc  -O3 -fno-strict-aliasing  -L/home/soporte/tmp/2022/wrf/lib -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o tst_utf8 tst_utf8.o ../liblib/libnetcdf.la -lhdf5_hl -lhdf5 -lm -lz -lcurl
# libtool: link: icc -O3 -fno-strict-aliasing -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o .libs/rewrite-scalar rewrite-scalar.o  -L/home/soporte/tmp/2022/wrf/lib ../liblib/.libs/libnetcdf.so /home/soporte/tmp/2022/wrf/lib/libhdf5_hl.so /home/soporte/tmp/2022/wrf/lib/libhdf5.so -lm -lz /home/soporte/tmp/2022/wrf/lib/libcurl.so -pthread -Wl,-rpath -Wl,/home/soporte/tmp/2022/wrf/lib
# libtool: link: icc -O3 -fno-strict-aliasing -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o .libs/ref_ctest ref_ctest.o  -L/home/soporte/tmp/2022/wrf/lib ../liblib/.libs/libnetcdf.so /home/soporte/tmp/2022/wrf/lib/libhdf5_hl.so /home/soporte/tmp/2022/wrf/lib/libhdf5.so -lm -lz /home/soporte/tmp/2022/wrf/lib/libcurl.so -pthread -Wl,-rpath -Wl,/home/soporte/tmp/2022/wrf/lib
# libtool: link: icc -O3 -fno-strict-aliasing -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o .libs/ref_ctest64 ref_ctest64.o  -L/home/soporte/tmp/2022/wrf/lib ../liblib/.libs/libnetcdf.so /home/soporte/tmp/2022/wrf/lib/libhdf5_hl.so /home/soporte/tmp/2022/wrf/lib/libhdf5.so -lm -lz /home/soporte/tmp/2022/wrf/lib/libcurl.so -pthread -Wl,-rpath -Wl,/home/soporte/tmp/2022/wrf/lib
# libtool: link: icc -O3 -fno-strict-aliasing -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o .libs/tst_utf8 tst_utf8.o  -L/home/soporte/tmp/2022/wrf/lib ../liblib/.libs/libnetcdf.so /home/soporte/tmp/2022/wrf/lib/libhdf5_hl.so /home/soporte/tmp/2022/wrf/lib/libhdf5.so -lm -lz /home/soporte/tmp/2022/wrf/lib/libcurl.so -pthread -Wl,-rpath -Wl,/home/soporte/tmp/2022/wrf/lib
# /bin/bash ../libtool  --tag=CC   --mode=link icc  -O3 -fno-strict-aliasing  -L/home/soporte/tmp/2022/wrf/lib -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o bom bom.o ../liblib/libnetcdf.la -lhdf5_hl -lhdf5 -lm -lz -lcurl
# /bin/bash ../libtool  --tag=CC   --mode=link icc  -O3 -fno-strict-aliasing  -L/home/soporte/tmp/2022/wrf/lib -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o tst_dimsizes tst_dimsizes.o ../liblib/libnetcdf.la -lhdf5_hl -lhdf5 -lm -lz -lcurl
# /bin/bash ../libtool  --tag=CC   --mode=link icc  -O3 -fno-strict-aliasing  -L/home/soporte/tmp/2022/wrf/lib -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o nctrunc nctrunc.o ../liblib/libnetcdf.la -lhdf5_hl -lhdf5 -lm -lz -lcurl
# /bin/bash ../libtool  --tag=CC   --mode=link icc  -O3 -fno-strict-aliasing  -L/home/soporte/tmp/2022/wrf/lib -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o tst_rcmerge tst_rcmerge.o ../liblib/libnetcdf.la -lhdf5_hl -lhdf5 -lm -lz -lcurl
# libtool: link: icc -O3 -fno-strict-aliasing -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o .libs/bom bom.o  -L/home/soporte/tmp/2022/wrf/lib ../liblib/.libs/libnetcdf.so /home/soporte/tmp/2022/wrf/lib/libhdf5_hl.so /home/soporte/tmp/2022/wrf/lib/libhdf5.so -lm -lz /home/soporte/tmp/2022/wrf/lib/libcurl.so -pthread -Wl,-rpath -Wl,/home/soporte/tmp/2022/wrf/lib
# libtool: link: icc -O3 -fno-strict-aliasing -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o .libs/tst_dimsizes tst_dimsizes.o  -L/home/soporte/tmp/2022/wrf/lib ../liblib/.libs/libnetcdf.so /home/soporte/tmp/2022/wrf/lib/libhdf5_hl.so /home/soporte/tmp/2022/wrf/lib/libhdf5.so -lm -lz /home/soporte/tmp/2022/wrf/lib/libcurl.so -pthread -Wl,-rpath -Wl,/home/soporte/tmp/2022/wrf/lib
# libtool: link: icc -O3 -fno-strict-aliasing -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o .libs/nctrunc nctrunc.o  -L/home/soporte/tmp/2022/wrf/lib ../liblib/.libs/libnetcdf.so /home/soporte/tmp/2022/wrf/lib/libhdf5_hl.so /home/soporte/tmp/2022/wrf/lib/libhdf5.so -lm -lz /home/soporte/tmp/2022/wrf/lib/libcurl.so -pthread -Wl,-rpath -Wl,/home/soporte/tmp/2022/wrf/lib
# libtool: link: icc -O3 -fno-strict-aliasing -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o .libs/tst_rcmerge tst_rcmerge.o  -L/home/soporte/tmp/2022/wrf/lib ../liblib/.libs/libnetcdf.so /home/soporte/tmp/2022/wrf/lib/libhdf5_hl.so /home/soporte/tmp/2022/wrf/lib/libhdf5.so -lm -lz /home/soporte/tmp/2022/wrf/lib/libcurl.so -pthread -Wl,-rpath -Wl,/home/soporte/tmp/2022/wrf/lib
# /bin/bash ../libtool  --tag=CC   --mode=link icc  -O3 -fno-strict-aliasing  -L/home/soporte/tmp/2022/wrf/lib -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o tst_fileinfo tst_fileinfo.o ../liblib/libnetcdf.la -lhdf5_hl -lhdf5 -lm -lz -lcurl
# /bin/bash ../libtool  --tag=CC   --mode=link icc  -O3 -fno-strict-aliasing  -L/home/soporte/tmp/2022/wrf/lib -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o tst_create_files tst_create_files.o ../liblib/libnetcdf.la -lhdf5_hl -lhdf5 -lm -lz -lcurl
# /bin/bash ../libtool  --tag=CC   --mode=link icc  -O3 -fno-strict-aliasing  -L/home/soporte/tmp/2022/wrf/lib -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o tst_h_rdc0 tst_h_rdc0.o ../liblib/libnetcdf.la -lhdf5_hl -lhdf5 -lm -lz -lcurl
# /bin/bash ../libtool  --tag=CC   --mode=link icc  -O3 -fno-strict-aliasing  -L/home/soporte/tmp/2022/wrf/lib -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o tst_group_data tst_group_data.o ../liblib/libnetcdf.la -lhdf5_hl -lhdf5 -lm -lz -lcurl
# libtool: link: icc -O3 -fno-strict-aliasing -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o .libs/tst_fileinfo tst_fileinfo.o  -L/home/soporte/tmp/2022/wrf/lib ../liblib/.libs/libnetcdf.so /home/soporte/tmp/2022/wrf/lib/libhdf5_hl.so /home/soporte/tmp/2022/wrf/lib/libhdf5.so -lm -lz /home/soporte/tmp/2022/wrf/lib/libcurl.so -pthread -Wl,-rpath -Wl,/home/soporte/tmp/2022/wrf/lib
# libtool: link: icc -O3 -fno-strict-aliasing -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o .libs/tst_h_rdc0 tst_h_rdc0.o  -L/home/soporte/tmp/2022/wrf/lib ../liblib/.libs/libnetcdf.so /home/soporte/tmp/2022/wrf/lib/libhdf5_hl.so /home/soporte/tmp/2022/wrf/lib/libhdf5.so -lm -lz /home/soporte/tmp/2022/wrf/lib/libcurl.so -pthread -Wl,-rpath -Wl,/home/soporte/tmp/2022/wrf/lib
# libtool: link: icc -O3 -fno-strict-aliasing -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o .libs/tst_create_files tst_create_files.o  -L/home/soporte/tmp/2022/wrf/lib ../liblib/.libs/libnetcdf.so /home/soporte/tmp/2022/wrf/lib/libhdf5_hl.so /home/soporte/tmp/2022/wrf/lib/libhdf5.so -lm -lz /home/soporte/tmp/2022/wrf/lib/libcurl.so -pthread -Wl,-rpath -Wl,/home/soporte/tmp/2022/wrf/lib
# libtool: link: icc -O3 -fno-strict-aliasing -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o .libs/tst_group_data tst_group_data.o  -L/home/soporte/tmp/2022/wrf/lib ../liblib/.libs/libnetcdf.so /home/soporte/tmp/2022/wrf/lib/libhdf5_hl.so /home/soporte/tmp/2022/wrf/lib/libhdf5.so -lm -lz /home/soporte/tmp/2022/wrf/lib/libcurl.so -pthread -Wl,-rpath -Wl,/home/soporte/tmp/2022/wrf/lib
# /bin/bash ../libtool  --tag=CC   --mode=link icc  -O3 -fno-strict-aliasing  -L/home/soporte/tmp/2022/wrf/lib -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o tst_enum_data tst_enum_data.o ../liblib/libnetcdf.la -lhdf5_hl -lhdf5 -lm -lz -lcurl
# /bin/bash ../libtool  --tag=CC   --mode=link icc  -O3 -fno-strict-aliasing  -L/home/soporte/tmp/2022/wrf/lib -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o tst_opaque_data tst_opaque_data.o ../liblib/libnetcdf.la -lhdf5_hl -lhdf5 -lm -lz -lcurl
# /bin/bash ../libtool  --tag=CC   --mode=link icc  -O3 -fno-strict-aliasing  -L/home/soporte/tmp/2022/wrf/lib -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o tst_string_data tst_string_data.o ../liblib/libnetcdf.la -lhdf5_hl -lhdf5 -lm -lz -lcurl
# /bin/bash ../libtool  --tag=CC   --mode=link icc  -O3 -fno-strict-aliasing  -L/home/soporte/tmp/2022/wrf/lib -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o tst_vlen_data tst_vlen_data.o ../liblib/libnetcdf.la -lhdf5_hl -lhdf5 -lm -lz -lcurl
# libtool: link: icc -O3 -fno-strict-aliasing -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o .libs/tst_enum_data tst_enum_data.o  -L/home/soporte/tmp/2022/wrf/lib ../liblib/.libs/libnetcdf.so /home/soporte/tmp/2022/wrf/lib/libhdf5_hl.so /home/soporte/tmp/2022/wrf/lib/libhdf5.so -lm -lz /home/soporte/tmp/2022/wrf/lib/libcurl.so -pthread -Wl,-rpath -Wl,/home/soporte/tmp/2022/wrf/lib
# ...
# mv -f $depbase.Tpo $depbase.Po
# depbase=`echo pres_temp_4D_wr.o | sed 's|[^/]*$|.deps/&|;s|\.o$||'`;\
# icc -DHAVE_CONFIG_H -I. -I../..  -I../../include -I../../include -I../../oc2 -I../../include -I../../liblib -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT pres_temp_4D_wr.o -MD -MP -MF $depbase.Tpo -c -o pres_temp_4D_wr.o pres_temp_4D_wr.c &&\
# mv -f $depbase.Tpo $depbase.Po
# depbase=`echo pres_temp_4D_rd.o | sed 's|[^/]*$|.deps/&|;s|\.o$||'`;\
# icc -DHAVE_CONFIG_H -I. -I../..  -I../../include -I../../include -I../../oc2 -I../../include -I../../liblib -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT pres_temp_4D_rd.o -MD -MP -MF $depbase.Tpo -c -o pres_temp_4D_rd.o pres_temp_4D_rd.c &&\
# mv -f $depbase.Tpo $depbase.Po
# depbase=`echo format.o | sed 's|[^/]*$|.deps/&|;s|\.o$||'`;\
# icc -DHAVE_CONFIG_H -I. -I../..  -I../../include -I../../include -I../../oc2 -I../../include -I../../liblib -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT format.o -MD -MP -MF $depbase.Tpo -c -o format.o format.c &&\
# mv -f $depbase.Tpo $depbase.Po
# depbase=`echo sfc_pres_temp_more.o | sed 's|[^/]*$|.deps/&|;s|\.o$||'`;\
# icc -DHAVE_CONFIG_H -I. -I../..  -I../../include -I../../include -I../../oc2 -I../../include -I../../liblib -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT sfc_pres_temp_more.o -MD -MP -MF $depbase.Tpo -c -o sfc_pres_temp_more.o sfc_pres_temp_more.c &&\
# mv -f $depbase.Tpo $depbase.Po
# depbase=`echo simple.o | sed 's|[^/]*$|.deps/&|;s|\.o$||'`;\
# icc -DHAVE_CONFIG_H -I. -I../..  -I../../include -I../../include -I../../oc2 -I../../include -I../../liblib -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT simple.o -MD -MP -MF $depbase.Tpo -c -o simple.o simple.c &&\
# mv -f $depbase.Tpo $depbase.Po
# depbase=`echo simple_nc4_wr.o | sed 's|[^/]*$|.deps/&|;s|\.o$||'`;\
# icc -DHAVE_CONFIG_H -I. -I../..  -I../../include -I../../include -I../../oc2 -I../../include -I../../liblib -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT simple_nc4_wr.o -MD -MP -MF $depbase.Tpo -c -o simple_nc4_wr.o simple_nc4_wr.c &&\
# mv -f $depbase.Tpo $depbase.Po
# depbase=`echo simple_nc4_rd.o | sed 's|[^/]*$|.deps/&|;s|\.o$||'`;\
# icc -DHAVE_CONFIG_H -I. -I../..  -I../../include -I../../include -I../../oc2 -I../../include -I../../liblib -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT simple_nc4_rd.o -MD -MP -MF $depbase.Tpo -c -o simple_nc4_rd.o simple_nc4_rd.c &&\
# mv -f $depbase.Tpo $depbase.Po
# depbase=`echo simple_xy_nc4_wr.o | sed 's|[^/]*$|.deps/&|;s|\.o$||'`;\
# icc -DHAVE_CONFIG_H -I. -I../..  -I../../include -I../../include -I../../oc2 -I../../include -I../../liblib -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT simple_xy_nc4_wr.o -MD -MP -MF $depbase.Tpo -c -o simple_xy_nc4_wr.o simple_xy_nc4_wr.c &&\
# mv -f $depbase.Tpo $depbase.Po
# depbase=`echo simple_xy_nc4_rd.o | sed 's|[^/]*$|.deps/&|;s|\.o$||'`;\
# icc -DHAVE_CONFIG_H -I. -I../..  -I../../include -I../../include -I../../oc2 -I../../include -I../../liblib -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT simple_xy_nc4_rd.o -MD -MP -MF $depbase.Tpo -c -o simple_xy_nc4_rd.o simple_xy_nc4_rd.c &&\
# mv -f $depbase.Tpo $depbase.Po
# depbase=`echo filter_example.o | sed 's|[^/]*$|.deps/&|;s|\.o$||'`;\
# icc -DHAVE_CONFIG_H -I. -I../..  -I../../include -I../../include -I../../oc2 -I../../include -I../../liblib -I/home/soporte/tmp/2022/wrf/include  -O3 -fno-strict-aliasing -MT filter_example.o -MD -MP -MF $depbase.Tpo -c -o filter_example.o filter_example.c &&\
# mv -f $depbase.Tpo $depbase.Po
# /bin/bash ../../libtool  --tag=CC   --mode=link icc  -O3 -fno-strict-aliasing  ../../liblib/libnetcdf.la -lm -L/home/soporte/tmp/2022/wrf/lib -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o simple_xy_wr simple_xy_wr.o  -lhdf5_hl -lhdf5 -lm -lz -lcurl
# /bin/bash ../../libtool  --tag=CC   --mode=link icc  -O3 -fno-strict-aliasing  ../../liblib/libnetcdf.la -lm -L/home/soporte/tmp/2022/wrf/lib -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o simple_xy_rd simple_xy_rd.o  -lhdf5_hl -lhdf5 -lm -lz -lcurl
# /bin/bash ../../libtool  --tag=CC   --mode=link icc  -O3 -fno-strict-aliasing  ../../liblib/libnetcdf.la -lm -L/home/soporte/tmp/2022/wrf/lib -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o sfc_pres_temp_wr sfc_pres_temp_wr.o  -lhdf5_hl -lhdf5 -lm -lz -lcurl
# libtool: link: icc -O3 -fno-strict-aliasing -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o .libs/simple_xy_wr simple_xy_wr.o  ../../liblib/.libs/libnetcdf.so -L/home/soporte/tmp/2022/wrf/lib /home/soporte/tmp/2022/wrf/lib/libhdf5_hl.so /home/soporte/tmp/2022/wrf/lib/libhdf5.so -lm -lz /home/soporte/tmp/2022/wrf/lib/libcurl.so -pthread -Wl,-rpath -Wl,/home/soporte/tmp/2022/wrf/lib
# libtool: link: icc -O3 -fno-strict-aliasing -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o .libs/simple_xy_rd simple_xy_rd.o  ../../liblib/.libs/libnetcdf.so -L/home/soporte/tmp/2022/wrf/lib /home/soporte/tmp/2022/wrf/lib/libhdf5_hl.so /home/soporte/tmp/2022/wrf/lib/libhdf5.so -lm -lz /home/soporte/tmp/2022/wrf/lib/libcurl.so -pthread -Wl,-rpath -Wl,/home/soporte/tmp/2022/wrf/lib
# /bin/bash ../../libtool  --tag=CC   --mode=link icc  -O3 -fno-strict-aliasing  ../../liblib/libnetcdf.la -lm -L/home/soporte/tmp/2022/wrf/lib -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o sfc_pres_temp_rd sfc_pres_temp_rd.o  -lhdf5_hl -lhdf5 -lm -lz -lcurl
# libtool: link: icc -O3 -fno-strict-aliasing -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o .libs/sfc_pres_temp_wr sfc_pres_temp_wr.o  ../../liblib/.libs/libnetcdf.so -L/home/soporte/tmp/2022/wrf/lib /home/soporte/tmp/2022/wrf/lib/libhdf5_hl.so /home/soporte/tmp/2022/wrf/lib/libhdf5.so -lm -lz /home/soporte/tmp/2022/wrf/lib/libcurl.so -pthread -Wl,-rpath -Wl,/home/soporte/tmp/2022/wrf/lib
# libtool: link: icc -O3 -fno-strict-aliasing -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o .libs/sfc_pres_temp_rd sfc_pres_temp_rd.o  ../../liblib/.libs/libnetcdf.so -L/home/soporte/tmp/2022/wrf/lib /home/soporte/tmp/2022/wrf/lib/libhdf5_hl.so /home/soporte/tmp/2022/wrf/lib/libhdf5.so -lm -lz /home/soporte/tmp/2022/wrf/lib/libcurl.so -pthread -Wl,-rpath -Wl,/home/soporte/tmp/2022/wrf/lib
# /bin/bash ../../libtool  --tag=CC   --mode=link icc  -O3 -fno-strict-aliasing  ../../liblib/libnetcdf.la -lm -L/home/soporte/tmp/2022/wrf/lib -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o pres_temp_4D_wr pres_temp_4D_wr.o  -lhdf5_hl -lhdf5 -lm -lz -lcurl
# /bin/bash ../../libtool  --tag=CC   --mode=link icc  -O3 -fno-strict-aliasing  ../../liblib/libnetcdf.la -lm -L/home/soporte/tmp/2022/wrf/lib -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o pres_temp_4D_rd pres_temp_4D_rd.o  -lhdf5_hl -lhdf5 -lm -lz -lcurl
# /bin/bash ../../libtool  --tag=CC   --mode=link icc  -O3 -fno-strict-aliasing  ../../liblib/libnetcdf.la -lm -L/home/soporte/tmp/2022/wrf/lib -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o format format.o  -lhdf5_hl -lhdf5 -lm -lz -lcurl
# libtool: link: icc -O3 -fno-strict-aliasing -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o .libs/pres_temp_4D_rd pres_temp_4D_rd.o  ../../liblib/.libs/libnetcdf.so -L/home/soporte/tmp/2022/wrf/lib /home/soporte/tmp/2022/wrf/lib/libhdf5_hl.so /home/soporte/tmp/2022/wrf/lib/libhdf5.so -lm -lz /home/soporte/tmp/2022/wrf/lib/libcurl.so -pthread -Wl,-rpath -Wl,/home/soporte/tmp/2022/wrf/lib
# libtool: link: icc -O3 -fno-strict-aliasing -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o .libs/pres_temp_4D_wr pres_temp_4D_wr.o  ../../liblib/.libs/libnetcdf.so -L/home/soporte/tmp/2022/wrf/lib /home/soporte/tmp/2022/wrf/lib/libhdf5_hl.so /home/soporte/tmp/2022/wrf/lib/libhdf5.so -lm -lz /home/soporte/tmp/2022/wrf/lib/libcurl.so -pthread -Wl,-rpath -Wl,/home/soporte/tmp/2022/wrf/lib
# /bin/bash ../../libtool  --tag=CC   --mode=link icc  -O3 -fno-strict-aliasing  ../../liblib/libnetcdf.la -lm -L/home/soporte/tmp/2022/wrf/lib -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o sfc_pres_temp_more sfc_pres_temp_more.o  -lhdf5_hl -lhdf5 -lm -lz -lcurl
# libtool: link: icc -O3 -fno-strict-aliasing -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o .libs/format format.o  ../../liblib/.libs/libnetcdf.so -L/home/soporte/tmp/2022/wrf/lib /home/soporte/tmp/2022/wrf/lib/libhdf5_hl.so /home/soporte/tmp/2022/wrf/lib/libhdf5.so -lm -lz /home/soporte/tmp/2022/wrf/lib/libcurl.so -pthread -Wl,-rpath -Wl,/home/soporte/tmp/2022/wrf/lib
# libtool: link: icc -O3 -fno-strict-aliasing -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o .libs/sfc_pres_temp_more sfc_pres_temp_more.o  ../../liblib/.libs/libnetcdf.so -L/home/soporte/tmp/2022/wrf/lib /home/soporte/tmp/2022/wrf/lib/libhdf5_hl.so /home/soporte/tmp/2022/wrf/lib/libhdf5.so -lm -lz /home/soporte/tmp/2022/wrf/lib/libcurl.so -pthread -Wl,-rpath -Wl,/home/soporte/tmp/2022/wrf/lib
# /bin/bash ../../libtool  --tag=CC   --mode=link icc  -O3 -fno-strict-aliasing  ../../liblib/libnetcdf.la -lm -L/home/soporte/tmp/2022/wrf/lib -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o simple simple.o  -lhdf5_hl -lhdf5 -lm -lz -lcurl
# /bin/bash ../../libtool  --tag=CC   --mode=link icc  -O3 -fno-strict-aliasing  ../../liblib/libnetcdf.la -lm -L/home/soporte/tmp/2022/wrf/lib -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o simple_nc4_wr simple_nc4_wr.o  -lhdf5_hl -lhdf5 -lm -lz -lcurl
# /bin/bash ../../libtool  --tag=CC   --mode=link icc  -O3 -fno-strict-aliasing  ../../liblib/libnetcdf.la -lm -L/home/soporte/tmp/2022/wrf/lib -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o simple_nc4_rd simple_nc4_rd.o  -lhdf5_hl -lhdf5 -lm -lz -lcurl
# /bin/bash ../../libtool  --tag=CC   --mode=link icc  -O3 -fno-strict-aliasing  ../../liblib/libnetcdf.la -lm -L/home/soporte/tmp/2022/wrf/lib -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o simple_xy_nc4_wr simple_xy_nc4_wr.o  -lhdf5_hl -lhdf5 -lm -lz -lcurl
# libtool: link: icc -O3 -fno-strict-aliasing -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o .libs/simple_nc4_wr simple_nc4_wr.o  ../../liblib/.libs/libnetcdf.so -L/home/soporte/tmp/2022/wrf/lib /home/soporte/tmp/2022/wrf/lib/libhdf5_hl.so /home/soporte/tmp/2022/wrf/lib/libhdf5.so -lm -lz /home/soporte/tmp/2022/wrf/lib/libcurl.so -pthread -Wl,-rpath -Wl,/home/soporte/tmp/2022/wrf/lib
# libtool: link: icc -O3 -fno-strict-aliasing -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o .libs/simple simple.o  ../../liblib/.libs/libnetcdf.so -L/home/soporte/tmp/2022/wrf/lib /home/soporte/tmp/2022/wrf/lib/libhdf5_hl.so /home/soporte/tmp/2022/wrf/lib/libhdf5.so -lm -lz /home/soporte/tmp/2022/wrf/lib/libcurl.so -pthread -Wl,-rpath -Wl,/home/soporte/tmp/2022/wrf/lib
# libtool: link: icc -O3 -fno-strict-aliasing -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o .libs/simple_nc4_rd simple_nc4_rd.o  ../../liblib/.libs/libnetcdf.so -L/home/soporte/tmp/2022/wrf/lib /home/soporte/tmp/2022/wrf/lib/libhdf5_hl.so /home/soporte/tmp/2022/wrf/lib/libhdf5.so -lm -lz /home/soporte/tmp/2022/wrf/lib/libcurl.so -pthread -Wl,-rpath -Wl,/home/soporte/tmp/2022/wrf/lib
# libtool: link: icc -O3 -fno-strict-aliasing -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o .libs/simple_xy_nc4_wr simple_xy_nc4_wr.o  ../../liblib/.libs/libnetcdf.so -L/home/soporte/tmp/2022/wrf/lib /home/soporte/tmp/2022/wrf/lib/libhdf5_hl.so /home/soporte/tmp/2022/wrf/lib/libhdf5.so -lm -lz /home/soporte/tmp/2022/wrf/lib/libcurl.so -pthread -Wl,-rpath -Wl,/home/soporte/tmp/2022/wrf/lib
# /bin/bash ../../libtool  --tag=CC   --mode=link icc  -O3 -fno-strict-aliasing  ../../liblib/libnetcdf.la -lm -L/home/soporte/tmp/2022/wrf/lib -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o simple_xy_nc4_rd simple_xy_nc4_rd.o  -lhdf5_hl -lhdf5 -lm -lz -lcurl
# /bin/bash ../../libtool  --tag=CC   --mode=link icc  -O3 -fno-strict-aliasing  ../../liblib/libnetcdf.la -lm -L/home/soporte/tmp/2022/wrf/lib -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o filter_example filter_example.o  -lhdf5_hl -lhdf5 -lm -lz -lcurl
# libtool: link: icc -O3 -fno-strict-aliasing -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o .libs/filter_example filter_example.o  ../../liblib/.libs/libnetcdf.so -L/home/soporte/tmp/2022/wrf/lib /home/soporte/tmp/2022/wrf/lib/libhdf5_hl.so /home/soporte/tmp/2022/wrf/lib/libhdf5.so -lm -lz /home/soporte/tmp/2022/wrf/lib/libcurl.so -pthread -Wl,-rpath -Wl,/home/soporte/tmp/2022/wrf/lib
# libtool: link: icc -O3 -fno-strict-aliasing -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o .libs/simple_xy_nc4_rd simple_xy_nc4_rd.o  ../../liblib/.libs/libnetcdf.so -L/home/soporte/tmp/2022/wrf/lib /home/soporte/tmp/2022/wrf/lib/libhdf5_hl.so /home/soporte/tmp/2022/wrf/lib/libhdf5.so -lm -lz /home/soporte/tmp/2022/wrf/lib/libcurl.so -pthread -Wl,-rpath -Wl,/home/soporte/tmp/2022/wrf/lib
# make[3]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/examples/C'
# make  check-TESTS
# make[3]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/examples/C'
# make[4]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/examples/C'
# PASS: simple
# PASS: sfc_pres_temp_more
# PASS: format
# PASS: run_filter.sh
# PASS: run_examples4.sh
# PASS: run_examples.sh
# ============================================================================
# Testsuite summary for netCDF 4.8.1
# ============================================================================
# # TOTAL: 6
# # PASS:  6
# # SKIP:  0
# # XFAIL: 0
# # FAIL:  0
# # XPASS: 0
# # ERROR: 0
# ============================================================================
# make[4]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/examples/C'
# make[3]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/examples/C'
# make[2]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/examples/C'
# Making check in CDL
# make[2]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/examples/CDL'
# make  check-TESTS
# make[3]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/examples/CDL'
# make[4]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/examples/CDL'
# PASS: do_comps.sh
# ============================================================================
# Testsuite summary for netCDF 4.8.1
# ============================================================================
# # TOTAL: 1
# # PASS:  1
# # SKIP:  0
# # XFAIL: 0
# # FAIL:  0
# # XPASS: 0
# # ERROR: 0
# ============================================================================
# make[4]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/examples/CDL'
# make[3]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/examples/CDL'
# make[2]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/examples/CDL'
# make[2]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/examples'
# make[2]: No se hace nada para 'check-am'.
# make[2]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/examples'
# make[1]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/examples'
# make[1]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1'
# make[1]: No se hace nada para 'check-am'.
# make[1]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1'
# 	Command being timed: "make -j4 check"
# 	User time (seconds): 218.01
# 	System time (seconds): 53.75
# 	Percent of CPU this job got: 225%
# 	Elapsed (wall clock) time (h:mm:ss or m:ss): 2:00.31
# 	Average shared text size (kbytes): 0
# 	Average unshared data size (kbytes): 0
# 	Average stack size (kbytes): 0
# 	Average total size (kbytes): 0
# 	Maximum resident set size (kbytes): 470404
# 	Average resident set size (kbytes): 0
# 	Major (requiring I/O) page faults: 2382
# 	Minor (reclaiming a frame) page faults: 17050656
# 	Voluntary context switches: 195262
# 	Involuntary context switches: 4532
# 	Swaps: 0
# 	File system inputs: 67672
# 	File system outputs: 766544
# 	Socket messages sent: 0
# 	Socket messages received: 0
# 	Signals delivered: 0
# 	Page size (bytes): 4096
# 	Exit status: 0

# %%
# %%bash -l
# pwd
# SETVARS_ARGS="--config=/opt/software/apps/intel/oneapi/config.txt"
# source /opt/software/apps/intel/oneapi/setvars.sh
# cd build/netcdf-c-4.8.1
# make install
# Out:
# /LUSTRE/tmp/soporte/compila-WRF
#
# :: initializing oneAPI environment ...
#    bash: BASH_VERSION = 5.1.4(1)-release
#    args: Using "SETVARS_ARGS" for setvars.sh arguments: --config=/opt/software/apps/intel/oneapi/config.txt
# :: compiler -- latest
# :: mpi -- latest
# :: oneAPI environment initialized ::
#
# Making install in include
# make[1]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/include'
# make[2]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/include'
# make[2]: No se hace nada para 'install-exec-am'.
#  /usr/bin/mkdir -p '/home/soporte/tmp/2022/wrf/include'
#  /usr/bin/install -c -m 644 netcdf.h netcdf_meta.h netcdf_mem.h netcdf_aux.h netcdf_filter.h netcdf_filter_build.h netcdf_dispatch.h '/home/soporte/tmp/2022/wrf/include'
# make[2]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/include'
# make[1]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/include'
# Making install in h5_test
# make[1]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/h5_test'
# make[2]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/h5_test'
# make[2]: No se hace nada para 'install-exec-am'.
# make[2]: No se hace nada para 'install-data-am'.
# make[2]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/h5_test'
# make[1]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/h5_test'
# Making install in libdispatch
# make[1]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/libdispatch'
# make[2]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/libdispatch'
# make[2]: No se hace nada para 'install-exec-am'.
# make[2]: No se hace nada para 'install-data-am'.
# make[2]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/libdispatch'
# make[1]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/libdispatch'
# Making install in libsrc
# make[1]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/libsrc'
# make[2]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/libsrc'
# make[2]: No se hace nada para 'install-exec-am'.
#  /usr/bin/mkdir -p '/home/soporte/tmp/2022/wrf/share/man/man3'
#  /usr/bin/install -c -m 644 netcdf.3 '/home/soporte/tmp/2022/wrf/share/man/man3'
# make[2]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/libsrc'
# make[1]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/libsrc'
# Making install in libsrc4
# make[1]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/libsrc4'
# make[2]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/libsrc4'
# make[2]: No se hace nada para 'install-exec-am'.
# make[2]: No se hace nada para 'install-data-am'.
# make[2]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/libsrc4'
# make[1]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/libsrc4'
# Making install in libhdf5
# make[1]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/libhdf5'
# make[2]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/libhdf5'
# make[2]: No se hace nada para 'install-exec-am'.
# make[2]: No se hace nada para 'install-data-am'.
# make[2]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/libhdf5'
# make[1]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/libhdf5'
# Making install in oc2
# make[1]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/oc2'
# make[2]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/oc2'
# make[2]: No se hace nada para 'install-exec-am'.
# make[2]: No se hace nada para 'install-data-am'.
# make[2]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/oc2'
# make[1]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/oc2'
# Making install in libdap2
# make[1]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/libdap2'
# make[2]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/libdap2'
# make[2]: No se hace nada para 'install-exec-am'.
# make[2]: No se hace nada para 'install-data-am'.
# make[2]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/libdap2'
# make[1]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/libdap2'
# Making install in libdap4
# make[1]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/libdap4'
# make[2]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/libdap4'
# make[2]: No se hace nada para 'install-exec-am'.
# make[2]: No se hace nada para 'install-data-am'.
# make[2]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/libdap4'
# make[1]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/libdap4'
# Making install in libnczarr
# make[1]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/libnczarr'
# make[2]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/libnczarr'
# make[2]: No se hace nada para 'install-exec-am'.
# make[2]: No se hace nada para 'install-data-am'.
# make[2]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/libnczarr'
# make[1]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/libnczarr'
# Making install in liblib
# make[1]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/liblib'
# make[2]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/liblib'
#  /usr/bin/mkdir -p '/home/soporte/tmp/2022/wrf/lib'
#  /bin/bash ../libtool   --mode=install /usr/bin/install -c   libnetcdf.la '/home/soporte/tmp/2022/wrf/lib'
# libtool: install: /usr/bin/install -c .libs/libnetcdf.so.19.0.1 /home/soporte/tmp/2022/wrf/lib/libnetcdf.so.19.0.1
# libtool: install: (cd /home/soporte/tmp/2022/wrf/lib && { ln -s -f libnetcdf.so.19.0.1 libnetcdf.so.19 || { rm -f libnetcdf.so.19 && ln -s libnetcdf.so.19.0.1 libnetcdf.so.19; }; })
# libtool: install: (cd /home/soporte/tmp/2022/wrf/lib && { ln -s -f libnetcdf.so.19.0.1 libnetcdf.so || { rm -f libnetcdf.so && ln -s libnetcdf.so.19.0.1 libnetcdf.so; }; })
# libtool: install: /usr/bin/install -c .libs/libnetcdf.lai /home/soporte/tmp/2022/wrf/lib/libnetcdf.la
# libtool: install: /usr/bin/install -c .libs/libnetcdf.a /home/soporte/tmp/2022/wrf/lib/libnetcdf.a
# libtool: install: chmod 644 /home/soporte/tmp/2022/wrf/lib/libnetcdf.a
# libtool: install: ranlib /home/soporte/tmp/2022/wrf/lib/libnetcdf.a
# libtool: finish: PATH="/opt/software/apps/intel/oneapi/mpi/2021.5.1//libfabric/bin:/opt/software/apps/intel/oneapi/mpi/2021.5.1//bin:/opt/software/apps/intel/oneapi/compiler/2022.0.2/linux/lib/oclfpga/bin:/opt/software/apps/intel/oneapi/compiler/2022.0.2/linux/bin/intel64:/opt/software/apps/intel/oneapi/compiler/2022.0.2/linux/bin:/opt/software/apps/slurm/slurm/bin:/usr/local/bin:/usr/bin:/bin:/usr/local/games:/usr/games:/home/soporte/bin:/sbin" ldconfig -n /home/soporte/tmp/2022/wrf/lib
# ----------------------------------------------------------------------
# Libraries have been installed in:
#    /home/soporte/tmp/2022/wrf/lib
#
# If you ever happen to want to link against installed libraries
# in a given directory, LIBDIR, you must either use libtool, and
# specify the full pathname of the library, or use the '-LLIBDIR'
# flag during linking and do at least one of the following:
#    - add LIBDIR to the 'LD_LIBRARY_PATH' environment variable
#      during execution
#    - add LIBDIR to the 'LD_RUN_PATH' environment variable
#      during linking
#    - use the '-Wl,-rpath -Wl,LIBDIR' linker flag
#    - have your system administrator add LIBDIR to '/etc/ld.so.conf'
#
# See any operating system documentation about shared libraries for
# more information, such as the ld(1) and ld.so(8) manual pages.
# ----------------------------------------------------------------------
# make[2]: No se hace nada para 'install-data-am'.
# make[2]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/liblib'
# make[1]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/liblib'
# Making install in ncgen3
# make[1]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/ncgen3'
# make[2]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/ncgen3'
#  /usr/bin/mkdir -p '/home/soporte/tmp/2022/wrf/bin'
#   /bin/bash ../libtool   --mode=install /usr/bin/install -c ncgen3 '/home/soporte/tmp/2022/wrf/bin'
# libtool: install: /usr/bin/install -c .libs/ncgen3 /home/soporte/tmp/2022/wrf/bin/ncgen3
#  /usr/bin/mkdir -p '/home/soporte/tmp/2022/wrf/share/man/man1'
#  /usr/bin/install -c -m 644 ncgen3.1 '/home/soporte/tmp/2022/wrf/share/man/man1'
# make[2]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/ncgen3'
# make[1]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/ncgen3'
# Making install in ncgen
# make[1]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/ncgen'
# make[2]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/ncgen'
#  /usr/bin/mkdir -p '/home/soporte/tmp/2022/wrf/bin'
#   /bin/bash ../libtool   --mode=install /usr/bin/install -c ncgen '/home/soporte/tmp/2022/wrf/bin'
# libtool: install: /usr/bin/install -c .libs/ncgen /home/soporte/tmp/2022/wrf/bin/ncgen
#  /usr/bin/mkdir -p '/home/soporte/tmp/2022/wrf/share/man/man1'
#  /usr/bin/install -c -m 644 ncgen.1 '/home/soporte/tmp/2022/wrf/share/man/man1'
# make[2]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/ncgen'
# make[1]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/ncgen'
# Making install in ncdump
# make[1]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/ncdump'
# Making install in cdl
# make[2]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/ncdump/cdl'
# make[3]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/ncdump/cdl'
# make[3]: No se hace nada para 'install-exec-am'.
# make[3]: No se hace nada para 'install-data-am'.
# make[3]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/ncdump/cdl'
# make[2]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/ncdump/cdl'
# Making install in expected
# make[2]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/ncdump/expected'
# make[3]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/ncdump/expected'
# make[3]: No se hace nada para 'install-exec-am'.
# make[3]: No se hace nada para 'install-data-am'.
# make[3]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/ncdump/expected'
# make[2]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/ncdump/expected'
# make[2]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/ncdump'
# make[3]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/ncdump'
#  /usr/bin/mkdir -p '/home/soporte/tmp/2022/wrf/bin'
#   /bin/bash ../libtool   --mode=install /usr/bin/install -c ncdump nccopy nc4print ocprint '/home/soporte/tmp/2022/wrf/bin'
# libtool: install: /usr/bin/install -c .libs/ncdump /home/soporte/tmp/2022/wrf/bin/ncdump
# libtool: install: /usr/bin/install -c .libs/nccopy /home/soporte/tmp/2022/wrf/bin/nccopy
# libtool: install: /usr/bin/install -c .libs/nc4print /home/soporte/tmp/2022/wrf/bin/nc4print
# libtool: install: /usr/bin/install -c .libs/ocprint /home/soporte/tmp/2022/wrf/bin/ocprint
#  /usr/bin/mkdir -p '/home/soporte/tmp/2022/wrf/share/man/man1'
#  /usr/bin/install -c -m 644 ncdump.1 nccopy.1 '/home/soporte/tmp/2022/wrf/share/man/man1'
# make[3]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/ncdump'
# make[2]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/ncdump'
# make[1]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/ncdump'
# Making install in plugins
# make[1]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/plugins'
# make  install-am
# make[2]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/plugins'
# make[3]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/plugins'
#  /usr/bin/mkdir -p '/home/soporte/tmp/2022/wrf/lib'
#  /bin/bash ../libtool   --mode=install /usr/bin/install -c   libh5bzip2.la '/home/soporte/tmp/2022/wrf/lib'
# libtool: install: /usr/bin/install -c .libs/libh5bzip2.so /home/soporte/tmp/2022/wrf/lib/libh5bzip2.so
# libtool: install: /usr/bin/install -c .libs/libh5bzip2.lai /home/soporte/tmp/2022/wrf/lib/libh5bzip2.la
# make[3]: No se hace nada para 'install-data-am'.
# make[3]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/plugins'
# make[2]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/plugins'
# make[1]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/plugins'
# Making install in unit_test
# make[1]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/unit_test'
# make[2]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/unit_test'
# make[2]: No se hace nada para 'install-exec-am'.
# make[2]: No se hace nada para 'install-data-am'.
# make[2]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/unit_test'
# make[1]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/unit_test'
# Making install in nctest
# make[1]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/nctest'
# make[2]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/nctest'
# make[2]: No se hace nada para 'install-exec-am'.
# make[2]: No se hace nada para 'install-data-am'.
# make[2]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/nctest'
# make[1]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/nctest'
# Making install in nc_test
# make[1]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/nc_test'
# make[2]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/nc_test'
# make[2]: No se hace nada para 'install-exec-am'.
# make[2]: No se hace nada para 'install-data-am'.
# make[2]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/nc_test'
# make[1]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/nc_test'
# Making install in nc_test4
# make[1]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/nc_test4'
# make[2]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/nc_test4'
# make[2]: No se hace nada para 'install-exec-am'.
# make[2]: No se hace nada para 'install-data-am'.
# make[2]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/nc_test4'
# make[1]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/nc_test4'
# Making install in ncdap_test
# make[1]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/ncdap_test'
# echo "#DODSRC" >.dodsrc
# echo "HTTP.READ.BUFFERSIZE=max" >>.dodsrc
# echo "HTTP.KEEPALIVE=60/60" >>.dodsrc
# make  install-recursive
# make[2]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/ncdap_test'
# Making install in testdata3
# make[3]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/ncdap_test/testdata3'
# make[4]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/ncdap_test/testdata3'
# make[4]: No se hace nada para 'install-exec-am'.
# make[4]: No se hace nada para 'install-data-am'.
# make[4]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/ncdap_test/testdata3'
# make[3]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/ncdap_test/testdata3'
# Making install in expected3
# make[3]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/ncdap_test/expected3'
# make[4]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/ncdap_test/expected3'
# make[4]: No se hace nada para 'install-exec-am'.
# make[4]: No se hace nada para 'install-data-am'.
# make[4]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/ncdap_test/expected3'
# make[3]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/ncdap_test/expected3'
# Making install in expectremote3
# make[3]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/ncdap_test/expectremote3'
# make[4]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/ncdap_test/expectremote3'
# make[4]: No se hace nada para 'install-exec-am'.
# make[4]: No se hace nada para 'install-data-am'.
# make[4]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/ncdap_test/expectremote3'
# make[3]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/ncdap_test/expectremote3'
# make[3]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/ncdap_test'
# make[4]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/ncdap_test'
# make[4]: No se hace nada para 'install-exec-am'.
# make[4]: No se hace nada para 'install-data-am'.
# make[4]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/ncdap_test'
# make[3]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/ncdap_test'
# make[2]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/ncdap_test'
# make[1]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/ncdap_test'
# Making install in dap4_test
# make[1]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/dap4_test'
# make  install-am
# make[2]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/dap4_test'
# make[3]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/dap4_test'
# make[3]: No se hace nada para 'install-exec-am'.
# make[3]: No se hace nada para 'install-data-am'.
# make[3]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/dap4_test'
# make[2]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/dap4_test'
# make[1]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/dap4_test'
# Making install in nczarr_test
# make[1]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/nczarr_test'
# make[2]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/nczarr_test'
# make[2]: No se hace nada para 'install-exec-am'.
# make[2]: No se hace nada para 'install-data-am'.
# make[2]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/nczarr_test'
# make[1]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/nczarr_test'
# Making install in docs
# make[1]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/docs'
# Making install in images
# make[2]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/docs/images'
# make[3]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/docs/images'
# make[3]: No se hace nada para 'install-exec-am'.
# make[3]: No se hace nada para 'install-data-am'.
# make[3]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/docs/images'
# make[2]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/docs/images'
# make[2]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/docs'
# make[3]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/docs'
# make[3]: No se hace nada para 'install-exec-am'.
# make[3]: No se hace nada para 'install-data-am'.
# make[3]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/docs'
# make[2]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/docs'
# make[1]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/docs'
# Making install in examples
# make[1]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/examples'
# Making install in C
# make[2]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/examples/C'
# make[3]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/examples/C'
# make[3]: No se hace nada para 'install-exec-am'.
# make[3]: No se hace nada para 'install-data-am'.
# make[3]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/examples/C'
# make[2]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/examples/C'
# Making install in CDL
# make[2]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/examples/CDL'
# make[3]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/examples/CDL'
# make[3]: No se hace nada para 'install-exec-am'.
# make[3]: No se hace nada para 'install-data-am'.
# make[3]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/examples/CDL'
# make[2]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/examples/CDL'
# make[2]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/examples'
# make[3]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/examples'
# make[3]: No se hace nada para 'install-exec-am'.
# make[3]: No se hace nada para 'install-data-am'.
# make[3]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/examples'
# make[2]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/examples'
# make[1]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/examples'
# make[1]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1'
# make[2]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1'
#  /usr/bin/mkdir -p '/home/soporte/tmp/2022/wrf/bin'
#  /usr/bin/install -c nc-config '/home/soporte/tmp/2022/wrf/bin'
#  /usr/bin/mkdir -p '/home/soporte/tmp/2022/wrf/lib/pkgconfig'
#  /usr/bin/install -c -m 644 netcdf.pc '/home/soporte/tmp/2022/wrf/lib/pkgconfig'
#  /usr/bin/mkdir -p '/home/soporte/tmp/2022/wrf/lib'
#  /usr/bin/install -c -m 644 libnetcdf.settings '/home/soporte/tmp/2022/wrf/lib'
# make  install-data-hook
# make[3]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1'
#
# +-------------------------------------------------------------+
# | Congratulations! You have successfully installed netCDF!    |
# |                                                             |
# | You can use script "nc-config" to find out the relevant     |
# | compiler options to build your application. Enter           |
# |                                                             |
# |     nc-config --help                                        |
# |                                                             |
# | for additional information.                                 |
# |                                                             |
# | CAUTION:                                                    |
# |                                                             |
# | If you have not already run "make check", then we strongly  |
# | recommend you do so. It does not take very long.            |
# |                                                             |
# | Before using netCDF to store important data, test your      |
# | build with "make check".                                    |
# |                                                             |
# | NetCDF is tested nightly on many platforms at Unidata       |
# | but your platform is probably different in some ways.       |
# |                                                             |
# | If any tests fail, please see the netCDF web site:          |
# | http://www.unidata.ucar.edu/software/netcdf/                |
# |                                                             |
# | NetCDF is developed and maintained at the Unidata Program   |
# | Center. Unidata provides a broad array of data and software |
# | tools for use in geoscience education and research.         |
# | http://www.unidata.ucar.edu                                 |
# +-------------------------------------------------------------+
#
# make[3]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1'
# make[2]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1'
# make[1]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1'
# libtool: warning: remember to run 'libtool --finish /LUSTRE/tmp/soporte/compila-WRF/build/netcdf-c-4.8.1/plugins'

# %% [markdown]
# ## Contenido del directorio  $HOME/tmp/2022/wrf

# %%
# %%bash
#
# tree -d $HOME/tmp/2022/wrf
# Out:
# /home/soporte/tmp/2022/wrf
# ├── bin
# ├── include
# │   ├── curl
# │   ├── jasper
# │   └── libpng16
# ├── lib
# │   └── pkgconfig
# └── share
#     ├── aclocal
#     ├── hdf5_examples
#     │   ├── c
#     │   ├── fortran
#     │   └── hl
#     │       ├── c
#     │       └── fortran
#     └── man
#         ├── man1
#         ├── man3
#         └── man5
#
# 19 directories

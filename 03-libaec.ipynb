# %% [markdown]
# # libaec

# %% [markdown]
# ## Configuración del código fuente

# %%
# %%bash -l
# #Inicializar entorno para el uso de compiladores INTEL
# pwd
# source /opt/software/apps/intel/oneapi/setvars.sh --config=oneapi.conf
#
# #Definir variables para el uso de los compiladores de intel
# #para la configuración del código fuente
# export CC=icc FC=ifort F77=ifort F90=ifort CXX=icpc
# export CFLAGS=" -O3 -fPIC"
# export CPPFLAGS="-I$HOME/tmp/2022/wrf/include"
# export LDFLAGS="-L$HOME/tmp/2022/wrf/lib -Wl,-rpath=$HOME/tmp/2022/wrf/lib"
#
# #Crear el directorio build  si  NO existe
# test ! -e build && mkdir -v build
# cd build
#
# #Desempaquetar código fuente de zlib
# tar xzf ../src/libaec-1.0.6.tar.gz
# cd libaec-1.0.6
#
# #Configurar el código fuentes usando los compiladores de intel
# #previamente se definieron las variables de entorno
# #CC, FC, F77, F90, CFLAGS
#
# #Se indica mediante la opción --prefix  el directorio de instalación
# ./configure --prefix=$HOME/tmp/2022/wrf
# Out:
# /LUSTRE/tmp/soporte/2022
#
# :: initializing oneAPI environment ...
#    bash: BASH_VERSION = 5.1.4(1)-release
#    args: Using "$@" for setvars.sh arguments: --config=oneapi.conf
# :: compiler -- latest
# :: mpi -- latest
# :: oneAPI environment initialized ::
#
# checking build system type... x86_64-pc-linux-gnu
# checking host system type... x86_64-pc-linux-gnu
# checking how to print strings... printf
# checking for gcc... icc
# checking whether the C compiler works... yes
# checking for C compiler default output file name... a.out
# checking for suffix of executables...
# checking whether we are cross compiling... no
# checking for suffix of object files... o
# checking whether we are using the GNU C compiler... yes
# checking whether icc accepts -g... yes
# checking for icc option to accept ISO C89... none needed
# checking whether icc understands -c and -o together... yes
# checking for a sed that does not truncate output... /usr/bin/sed
# checking for grep that handles long lines and -e... /usr/bin/grep
# checking for egrep... /usr/bin/grep -E
# checking for fgrep... /usr/bin/grep -F
# checking for ld used by icc... /usr/bin/ld
# checking if the linker (/usr/bin/ld) is GNU ld... yes
# checking for BSD- or MS-compatible name lister (nm)... /usr/bin/nm -B
# checking the name lister (/usr/bin/nm -B) interface... BSD nm
# checking whether ln -s works... yes
# checking the maximum length of command line arguments... 3458764513820540925
# checking how to convert x86_64-pc-linux-gnu file names to x86_64-pc-linux-gnu format... func_convert_file_noop
# checking how to convert x86_64-pc-linux-gnu file names to toolchain format... func_convert_file_noop
# checking for /usr/bin/ld option to reload object files... -r
# checking for objdump... objdump
# checking how to recognize dependent libraries... pass_all
# checking for dlltool... no
# checking how to associate runtime and link libraries... printf %s\n
# checking for ar... ar
# checking for archiver @FILE support... @
# checking for strip... strip
# checking for ranlib... ranlib
# checking for gawk... gawk
# checking command to parse /usr/bin/nm -B output from icc object... ok
# checking for sysroot... no
# checking for a working dd... /usr/bin/dd
# checking how to truncate binary pipes... /usr/bin/dd bs=4096 count=1
# checking for mt... mt
# checking if mt is a manifest tool... no
# checking how to run the C preprocessor... icc -E
# checking for ANSI C header files... yes
# checking for sys/types.h... yes
# checking for sys/stat.h... yes
# checking for stdlib.h... yes
# checking for string.h... yes
# checking for memory.h... yes
# checking for strings.h... yes
# checking for inttypes.h... yes
# checking for stdint.h... yes
# checking for unistd.h... yes
# checking for dlfcn.h... yes
# checking for objdir... .libs
# checking if icc supports -fno-rtti -fno-exceptions... yes
# checking for icc option to produce PIC... -fPIC -DPIC
# checking if icc PIC flag -fPIC -DPIC works... yes
# checking if icc static flag -static works... yes
# checking if icc supports -c -o file.o... yes
# checking if icc supports -c -o file.o... (cached) yes
# checking whether the icc linker (/usr/bin/ld -m elf_x86_64) supports shared libraries... yes
# checking whether -lc should be explicitly linked in... no
# checking dynamic linker characteristics... GNU/Linux ld.so
# checking how to hardcode library paths into programs... immediate
# checking whether stripping libraries is possible... yes
# checking if libtool supports shared libraries... yes
# checking whether to build shared libraries... yes
# checking whether to build static libraries... yes
# checking whether the -Werror option is usable... yes
# checking for simple visibility declarations... yes
# checking for a BSD-compatible install... /usr/bin/install -c
# checking whether build environment is sane... yes
# checking for a thread-safe mkdir -p... /usr/bin/mkdir -p
# checking whether make sets $(MAKE)... yes
# checking whether make supports the include directive... yes (GNU style)
# checking whether make supports nested variables... yes
# checking dependency style of icc... gcc3
# checking whether to enable maintainer-specific portions of Makefiles... yes
# checking for icc option to accept ISO C99... none needed
# checking for ANSI C header files... (cached) yes
# checking whether byte ordering is bigendian... no
# checking for inline... inline
# checking for int64_t... yes
# checking for size_t... yes
# checking for uint32_t... yes
# checking for uint64_t... yes
# checking for uint8_t... yes
# checking for inline... (cached) inline
# checking for C/C++ restrict keyword... __restrict
# checking for memset... yes
# checking for strstr... yes
# checking for snprintf... yes
# checking whether __builtin_clzll is declared... yes
# checking that generated files are newer than configure... done
# configure: creating ./config.status
# config.status: creating Makefile
# config.status: creating src/Makefile
# config.status: creating tests/Makefile
# config.status: creating config/config.h
# config.status: executing libtool commands
# config.status: executing depfiles commands

# %% [markdown]
# ## Construcción o compilación de la biblioteca
#
# Se construye la biblioteca zlib con el comando __make__ y posteriormente se realizan pruebas de uso con el comando __make check__, por último se instala la biblioteca con el comando __make install__ en el directorio indicado con la opción  __--prefix__ durante el proceso de configuración.

# %%
# %%bash -l
# pwd
# source /opt/software/apps/intel/oneapi/setvars.sh --config=oneapi.conf
#
# #Ingresar al directorio del código fuente previamente desempaquetado
# #y configurado.
# #Utilizar la herramienta make para la construcción de la biblioteca zlib
# cd build/libaec-1.0.6
# make && make install
# Out:
# /LUSTRE/tmp/soporte/2022
#
# :: initializing oneAPI environment ...
#    bash: BASH_VERSION = 5.1.4(1)-release
#    args: Using "$@" for setvars.sh arguments: --config=oneapi.conf
# :: compiler -- latest
# :: mpi -- latest
# :: oneAPI environment initialized ::
#
# Making all in src
# make[1]: se entra en el directorio '/LUSTRE/tmp/soporte/2022/build/libaec-1.0.6/src'
# icc -DHAVE_CONFIG_H -I. -I../config  -I../include -DBUILDING_LIBAEC  -fvisibility=hidden -O3 -fPIC -MT aec.o -MD -MP -MF .deps/aec.Tpo -c -o aec.o aec.c
# mv -f .deps/aec.Tpo .deps/aec.Po
# /bin/bash ../libtool  --tag=CC   --mode=compile icc -DHAVE_CONFIG_H -I. -I../config  -I../include -DBUILDING_LIBAEC  -fvisibility=hidden -O3 -fPIC -MT encode.lo -MD -MP -MF .deps/encode.Tpo -c -o encode.lo encode.c
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I../config -I../include -DBUILDING_LIBAEC -fvisibility=hidden -O3 -fPIC -MT encode.lo -MD -MP -MF .deps/encode.Tpo -c encode.c  -fPIC -DPIC -o .libs/encode.o
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I../config -I../include -DBUILDING_LIBAEC -fvisibility=hidden -O3 -fPIC -MT encode.lo -MD -MP -MF .deps/encode.Tpo -c encode.c -o encode.o >/dev/null 2>&1
# mv -f .deps/encode.Tpo .deps/encode.Plo
# /bin/bash ../libtool  --tag=CC   --mode=compile icc -DHAVE_CONFIG_H -I. -I../config  -I../include -DBUILDING_LIBAEC  -fvisibility=hidden -O3 -fPIC -MT encode_accessors.lo -MD -MP -MF .deps/encode_accessors.Tpo -c -o encode_accessors.lo encode_accessors.c
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I../config -I../include -DBUILDING_LIBAEC -fvisibility=hidden -O3 -fPIC -MT encode_accessors.lo -MD -MP -MF .deps/encode_accessors.Tpo -c encode_accessors.c  -fPIC -DPIC -o .libs/encode_accessors.o
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I../config -I../include -DBUILDING_LIBAEC -fvisibility=hidden -O3 -fPIC -MT encode_accessors.lo -MD -MP -MF .deps/encode_accessors.Tpo -c encode_accessors.c -o encode_accessors.o >/dev/null 2>&1
# mv -f .deps/encode_accessors.Tpo .deps/encode_accessors.Plo
# /bin/bash ../libtool  --tag=CC   --mode=compile icc -DHAVE_CONFIG_H -I. -I../config  -I../include -DBUILDING_LIBAEC  -fvisibility=hidden -O3 -fPIC -MT decode.lo -MD -MP -MF .deps/decode.Tpo -c -o decode.lo decode.c
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I../config -I../include -DBUILDING_LIBAEC -fvisibility=hidden -O3 -fPIC -MT decode.lo -MD -MP -MF .deps/decode.Tpo -c decode.c  -fPIC -DPIC -o .libs/decode.o
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I../config -I../include -DBUILDING_LIBAEC -fvisibility=hidden -O3 -fPIC -MT decode.lo -MD -MP -MF .deps/decode.Tpo -c decode.c -o decode.o >/dev/null 2>&1
# mv -f .deps/decode.Tpo .deps/decode.Plo
# /bin/bash ../libtool  --tag=CC   --mode=link icc -fvisibility=hidden -O3 -fPIC -version-info 0:12:0 -no-undefined  -o libaec.la -rpath /home/soporte/tmp/2022/wrf/lib encode.lo encode_accessors.lo decode.lo
# libtool: link: icc -shared  -fPIC -DPIC  .libs/encode.o .libs/encode_accessors.o .libs/decode.o    -O3   -Wl,-soname -Wl,libaec.so.0 -o .libs/libaec.so.0.0.12
# libtool: link: (cd ".libs" && rm -f "libaec.so.0" && ln -s "libaec.so.0.0.12" "libaec.so.0")
# libtool: link: (cd ".libs" && rm -f "libaec.so" && ln -s "libaec.so.0.0.12" "libaec.so")
# libtool: link: ar cru .libs/libaec.a  encode.o encode_accessors.o decode.o
# libtool: link: ranlib .libs/libaec.a
# libtool: link: ( cd ".libs" && rm -f "libaec.la" && ln -s "../libaec.la" "libaec.la" )
# /bin/bash ../libtool  --tag=CC   --mode=link icc -fvisibility=hidden -O3 -fPIC   -o aec aec.o libaec.la
# libtool: link: icc -fvisibility=hidden -O3 -fPIC -o .libs/aec aec.o  ./.libs/libaec.so -Wl,-rpath -Wl,/home/soporte/tmp/2022/wrf/lib
# icc -DHAVE_CONFIG_H -I. -I../config  -I../include -DBUILDING_LIBAEC  -fvisibility=hidden -O3 -fPIC -MT utime.o -MD -MP -MF .deps/utime.Tpo -c -o utime.o utime.c
# mv -f .deps/utime.Tpo .deps/utime.Po
# /bin/bash ../libtool  --tag=CC   --mode=link icc -fvisibility=hidden -O3 -fPIC   -o utime utime.o
# libtool: link: icc -fvisibility=hidden -O3 -fPIC -o utime utime.o
# /bin/bash ../libtool  --tag=CC   --mode=compile icc -DHAVE_CONFIG_H -I. -I../config  -I../include -DBUILDING_LIBAEC  -fvisibility=hidden -O3 -fPIC -MT sz_compat.lo -MD -MP -MF .deps/sz_compat.Tpo -c -o sz_compat.lo sz_compat.c
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I../config -I../include -DBUILDING_LIBAEC -fvisibility=hidden -O3 -fPIC -MT sz_compat.lo -MD -MP -MF .deps/sz_compat.Tpo -c sz_compat.c  -fPIC -DPIC -o .libs/sz_compat.o
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I../config -I../include -DBUILDING_LIBAEC -fvisibility=hidden -O3 -fPIC -MT sz_compat.lo -MD -MP -MF .deps/sz_compat.Tpo -c sz_compat.c -o sz_compat.o >/dev/null 2>&1
# mv -f .deps/sz_compat.Tpo .deps/sz_compat.Plo
# /bin/bash ../libtool  --tag=CC   --mode=link icc -fvisibility=hidden -O3 -fPIC -version-info 2:1:0 -no-undefined  -o libsz.la -rpath /home/soporte/tmp/2022/wrf/lib sz_compat.lo libaec.la
# libtool: link: icc -shared  -fPIC -DPIC  .libs/sz_compat.o   -Wl,-rpath -Wl,/LUSTRE/tmp/soporte/2022/build/libaec-1.0.6/src/.libs -Wl,-rpath -Wl,/home/soporte/tmp/2022/wrf/lib ./.libs/libaec.so  -O3   -Wl,-soname -Wl,libsz.so.2 -o .libs/libsz.so.2.0.1
# libtool: link: (cd ".libs" && rm -f "libsz.so.2" && ln -s "libsz.so.2.0.1" "libsz.so.2")
# libtool: link: (cd ".libs" && rm -f "libsz.so" && ln -s "libsz.so.2.0.1" "libsz.so")
# libtool: link: ar cru .libs/libsz.a  sz_compat.o
# libtool: link: ranlib .libs/libsz.a
# libtool: link: ( cd ".libs" && rm -f "libsz.la" && ln -s "../libsz.la" "libsz.la" )
# make[1]: se sale del directorio '/LUSTRE/tmp/soporte/2022/build/libaec-1.0.6/src'
# Making all in tests
# make[1]: se entra en el directorio '/LUSTRE/tmp/soporte/2022/build/libaec-1.0.6/tests'
# make[1]: No se hace nada para 'all'.
# make[1]: se sale del directorio '/LUSTRE/tmp/soporte/2022/build/libaec-1.0.6/tests'
# make[1]: se entra en el directorio '/LUSTRE/tmp/soporte/2022/build/libaec-1.0.6'
# make[1]: No se hace nada para 'all-am'.
# make[1]: se sale del directorio '/LUSTRE/tmp/soporte/2022/build/libaec-1.0.6'
# Making check in src
# make[1]: se entra en el directorio '/LUSTRE/tmp/soporte/2022/build/libaec-1.0.6/src'
# make[1]: No se hace nada para 'check'.
# make[1]: se sale del directorio '/LUSTRE/tmp/soporte/2022/build/libaec-1.0.6/src'
# Making check in tests
# make[1]: se entra en el directorio '/LUSTRE/tmp/soporte/2022/build/libaec-1.0.6/tests'
# make  check_code_options check_buffer_sizes check_long_fs check_szcomp libcheck_aec.la
# make[2]: se entra en el directorio '/LUSTRE/tmp/soporte/2022/build/libaec-1.0.6/tests'
# icc -DHAVE_CONFIG_H -I. -I../config  -I../include   -O3 -fPIC -MT check_code_options.o -MD -MP -MF .deps/check_code_options.Tpo -c -o check_code_options.o check_code_options.c
# mv -f .deps/check_code_options.Tpo .deps/check_code_options.Po
# /bin/bash ../libtool  --tag=CC   --mode=compile icc -DHAVE_CONFIG_H -I. -I../config  -I../include   -O3 -fPIC -MT check_aec.lo -MD -MP -MF .deps/check_aec.Tpo -c -o check_aec.lo check_aec.c
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I../config -I../include -O3 -fPIC -MT check_aec.lo -MD -MP -MF .deps/check_aec.Tpo -c check_aec.c  -fPIC -DPIC -o .libs/check_aec.o
# libtool: compile:  icc -DHAVE_CONFIG_H -I. -I../config -I../include -O3 -fPIC -MT check_aec.lo -MD -MP -MF .deps/check_aec.Tpo -c check_aec.c -o check_aec.o >/dev/null 2>&1
# mv -f .deps/check_aec.Tpo .deps/check_aec.Plo
# /bin/bash ../libtool  --tag=CC   --mode=link icc  -O3 -fPIC   -o libcheck_aec.la  check_aec.lo
# libtool: link: ar cru .libs/libcheck_aec.a .libs/check_aec.o
# libtool: link: ranlib .libs/libcheck_aec.a
# libtool: link: ( cd ".libs" && rm -f "libcheck_aec.la" && ln -s "../libcheck_aec.la" "libcheck_aec.la" )
# /bin/bash ../libtool  --tag=CC   --mode=link icc  -O3 -fPIC   -o check_code_options check_code_options.o libcheck_aec.la ../src/libaec.la
# libtool: link: icc -O3 -fPIC -o .libs/check_code_options check_code_options.o  ./.libs/libcheck_aec.a ../src/.libs/libaec.so -Wl,-rpath -Wl,/home/soporte/tmp/2022/wrf/lib
# icc -DHAVE_CONFIG_H -I. -I../config  -I../include   -O3 -fPIC -MT check_buffer_sizes.o -MD -MP -MF .deps/check_buffer_sizes.Tpo -c -o check_buffer_sizes.o check_buffer_sizes.c
# mv -f .deps/check_buffer_sizes.Tpo .deps/check_buffer_sizes.Po
# /bin/bash ../libtool  --tag=CC   --mode=link icc  -O3 -fPIC   -o check_buffer_sizes check_buffer_sizes.o libcheck_aec.la ../src/libaec.la
# libtool: link: icc -O3 -fPIC -o .libs/check_buffer_sizes check_buffer_sizes.o  ./.libs/libcheck_aec.a ../src/.libs/libaec.so -Wl,-rpath -Wl,/home/soporte/tmp/2022/wrf/lib
# icc -DHAVE_CONFIG_H -I. -I../config  -I../include   -O3 -fPIC -MT check_long_fs.o -MD -MP -MF .deps/check_long_fs.Tpo -c -o check_long_fs.o check_long_fs.c
# mv -f .deps/check_long_fs.Tpo .deps/check_long_fs.Po
# /bin/bash ../libtool  --tag=CC   --mode=link icc  -O3 -fPIC   -o check_long_fs check_long_fs.o libcheck_aec.la ../src/libaec.la
# libtool: link: icc -O3 -fPIC -o .libs/check_long_fs check_long_fs.o  ./.libs/libcheck_aec.a ../src/.libs/libaec.so -Wl,-rpath -Wl,/home/soporte/tmp/2022/wrf/lib
# icc -DHAVE_CONFIG_H -I. -I../config  -I../include   -O3 -fPIC -MT check_szcomp.o -MD -MP -MF .deps/check_szcomp.Tpo -c -o check_szcomp.o check_szcomp.c
# mv -f .deps/check_szcomp.Tpo .deps/check_szcomp.Po
# /bin/bash ../libtool  --tag=CC   --mode=link icc  -O3 -fPIC   -o check_szcomp check_szcomp.o ../src/libsz.la
# libtool: link: icc -O3 -fPIC -o .libs/check_szcomp check_szcomp.o  ../src/.libs/libsz.so /LUSTRE/tmp/soporte/2022/build/libaec-1.0.6/src/.libs/libaec.so -Wl,-rpath -Wl,/home/soporte/tmp/2022/wrf/lib
# make[2]: 'libcheck_aec.la' está actualizado.
# make[2]: se sale del directorio '/LUSTRE/tmp/soporte/2022/build/libaec-1.0.6/tests'
# make  check-TESTS
# make[2]: se entra en el directorio '/LUSTRE/tmp/soporte/2022/build/libaec-1.0.6/tests'
# make[3]: se entra en el directorio '/LUSTRE/tmp/soporte/2022/build/libaec-1.0.6/tests'
# PASS: check_code_options
# PASS: check_buffer_sizes
# PASS: check_long_fs
# PASS: sampledata.sh
# PASS: szcomp.sh
# ============================================================================
# Testsuite summary for libaec 1.0.6
# ============================================================================
# # TOTAL: 5
# # PASS:  5
# # SKIP:  0
# # XFAIL: 0
# # FAIL:  0
# # XPASS: 0
# # ERROR: 0
# ============================================================================
# make[3]: se sale del directorio '/LUSTRE/tmp/soporte/2022/build/libaec-1.0.6/tests'
# make[2]: se sale del directorio '/LUSTRE/tmp/soporte/2022/build/libaec-1.0.6/tests'
# make[1]: se sale del directorio '/LUSTRE/tmp/soporte/2022/build/libaec-1.0.6/tests'
# make[1]: se entra en el directorio '/LUSTRE/tmp/soporte/2022/build/libaec-1.0.6'
# make[1]: No se hace nada para 'check-am'.
# make[1]: se sale del directorio '/LUSTRE/tmp/soporte/2022/build/libaec-1.0.6'
# Making install in src
# make[1]: se entra en el directorio '/LUSTRE/tmp/soporte/2022/build/libaec-1.0.6/src'
# make[2]: se entra en el directorio '/LUSTRE/tmp/soporte/2022/build/libaec-1.0.6/src'
#  /usr/bin/mkdir -p '/home/soporte/tmp/2022/wrf/lib'
#  /bin/bash ../libtool   --mode=install /usr/bin/install -c   libaec.la libsz.la '/home/soporte/tmp/2022/wrf/lib'
# libtool: install: /usr/bin/install -c .libs/libaec.so.0.0.12 /home/soporte/tmp/2022/wrf/lib/libaec.so.0.0.12
# libtool: install: (cd /home/soporte/tmp/2022/wrf/lib && { ln -s -f libaec.so.0.0.12 libaec.so.0 || { rm -f libaec.so.0 && ln -s libaec.so.0.0.12 libaec.so.0; }; })
# libtool: install: (cd /home/soporte/tmp/2022/wrf/lib && { ln -s -f libaec.so.0.0.12 libaec.so || { rm -f libaec.so && ln -s libaec.so.0.0.12 libaec.so; }; })
# libtool: install: /usr/bin/install -c .libs/libaec.lai /home/soporte/tmp/2022/wrf/lib/libaec.la
# libtool: install: (cd /LUSTRE/tmp/soporte/2022/build/libaec-1.0.6/src; /bin/bash "/LUSTRE/tmp/soporte/2022/build/libaec-1.0.6/libtool"  --tag CC --mode=relink icc -fvisibility=hidden -O3 -fPIC -version-info 2:1:0 -no-undefined -o libsz.la -rpath /home/soporte/tmp/2022/wrf/lib sz_compat.lo libaec.la )
# libtool: relink: icc -shared  -fPIC -DPIC  .libs/sz_compat.o   -Wl,-rpath -Wl,/home/soporte/tmp/2022/wrf/lib -L/home/soporte/tmp/2022/wrf/lib -laec  -O3   -Wl,-soname -Wl,libsz.so.2 -o .libs/libsz.so.2.0.1
# libtool: install: /usr/bin/install -c .libs/libsz.so.2.0.1T /home/soporte/tmp/2022/wrf/lib/libsz.so.2.0.1
# libtool: install: (cd /home/soporte/tmp/2022/wrf/lib && { ln -s -f libsz.so.2.0.1 libsz.so.2 || { rm -f libsz.so.2 && ln -s libsz.so.2.0.1 libsz.so.2; }; })
# libtool: install: (cd /home/soporte/tmp/2022/wrf/lib && { ln -s -f libsz.so.2.0.1 libsz.so || { rm -f libsz.so && ln -s libsz.so.2.0.1 libsz.so; }; })
# libtool: install: /usr/bin/install -c .libs/libsz.lai /home/soporte/tmp/2022/wrf/lib/libsz.la
# libtool: install: /usr/bin/install -c .libs/libaec.a /home/soporte/tmp/2022/wrf/lib/libaec.a
# libtool: install: chmod 644 /home/soporte/tmp/2022/wrf/lib/libaec.a
# libtool: install: ranlib /home/soporte/tmp/2022/wrf/lib/libaec.a
# libtool: install: /usr/bin/install -c .libs/libsz.a /home/soporte/tmp/2022/wrf/lib/libsz.a
# libtool: install: chmod 644 /home/soporte/tmp/2022/wrf/lib/libsz.a
# libtool: install: ranlib /home/soporte/tmp/2022/wrf/lib/libsz.a
# libtool: finish: PATH="/opt/software/apps/intel/oneapi/mpi/2021.5.1//libfabric/bin:/opt/software/apps/intel/oneapi/mpi/2021.5.1//bin:/opt/software/apps/intel/oneapi/compiler/2022.0.2/linux/lib/oclfpga/bin:/opt/software/apps/intel/oneapi/compiler/2022.0.2/linux/bin/intel64:/opt/software/apps/intel/oneapi/compiler/2022.0.2/linux/bin:/opt/software/apps/slurm/slurm/bin:/usr/local/bin:/usr/bin:/bin:/usr/local/games:/usr/games:/home/soporte/bin:/sbin" ldconfig -n /home/soporte/tmp/2022/wrf/lib
# ----------------------------------------------------------------------
# Libraries have been installed in:
#    /home/soporte/tmp/2022/wrf/lib
#
# If you ever happen to want to link against installed libraries
# in a given directory, LIBDIR, you must either use libtool, and
# specify the full pathname of the library, or use the '-LLIBDIR'
# flag during linking and do at least one of the following:
#    - add LIBDIR to the 'LD_LIBRARY_PATH' environment variable
#      during execution
#    - add LIBDIR to the 'LD_RUN_PATH' environment variable
#      during linking
#    - use the '-Wl,-rpath -Wl,LIBDIR' linker flag
#    - have your system administrator add LIBDIR to '/etc/ld.so.conf'
#
# See any operating system documentation about shared libraries for
# more information, such as the ld(1) and ld.so(8) manual pages.
# ----------------------------------------------------------------------
#  /usr/bin/mkdir -p '/home/soporte/tmp/2022/wrf/bin'
#   /bin/bash ../libtool   --mode=install /usr/bin/install -c aec '/home/soporte/tmp/2022/wrf/bin'
# libtool: install: /usr/bin/install -c .libs/aec /home/soporte/tmp/2022/wrf/bin/aec
#  /usr/bin/mkdir -p '/home/soporte/tmp/2022/wrf/include'
#  /usr/bin/install -c -m 644 ../include/libaec.h ../include/szlib.h '/home/soporte/tmp/2022/wrf/include'
#  /usr/bin/mkdir -p '/home/soporte/tmp/2022/wrf/share/man/man1'
#  /usr/bin/install -c -m 644 aec.1 '/home/soporte/tmp/2022/wrf/share/man/man1'
# make[2]: se sale del directorio '/LUSTRE/tmp/soporte/2022/build/libaec-1.0.6/src'
# make[1]: se sale del directorio '/LUSTRE/tmp/soporte/2022/build/libaec-1.0.6/src'
# Making install in tests
# make[1]: se entra en el directorio '/LUSTRE/tmp/soporte/2022/build/libaec-1.0.6/tests'
# make[2]: se entra en el directorio '/LUSTRE/tmp/soporte/2022/build/libaec-1.0.6/tests'
# make[2]: No se hace nada para 'install-exec-am'.
# make[2]: No se hace nada para 'install-data-am'.
# make[2]: se sale del directorio '/LUSTRE/tmp/soporte/2022/build/libaec-1.0.6/tests'
# make[1]: se sale del directorio '/LUSTRE/tmp/soporte/2022/build/libaec-1.0.6/tests'
# make[1]: se entra en el directorio '/LUSTRE/tmp/soporte/2022/build/libaec-1.0.6'
# make[2]: se entra en el directorio '/LUSTRE/tmp/soporte/2022/build/libaec-1.0.6'
# make[2]: No se hace nada para 'install-exec-am'.
# make[2]: No se hace nada para 'install-data-am'.
# make[2]: se sale del directorio '/LUSTRE/tmp/soporte/2022/build/libaec-1.0.6'
# make[1]: se sale del directorio '/LUSTRE/tmp/soporte/2022/build/libaec-1.0.6'
# ar: `u' modifier ignored since `D' is the default (see `U')
# ar: `u' modifier ignored since `D' is the default (see `U')
# ar: `u' modifier ignored since `D' is the default (see `U')
# libtool: warning: relinking 'libsz.la'

# %% [markdown]
# ## Contenido del directorio  $HOME/tmp/2022/wrf

# %%
# %%bash
#
# tree $HOME/tmp/2022/wrf
# Out:
# /home/soporte/tmp/2022/wrf
# ├── bin
# │   └── aec
# ├── include
# │   ├── libaec.h
# │   ├── szlib.h
# │   ├── zconf.h
# │   └── zlib.h
# ├── lib
# │   ├── libaec.a
# │   ├── libaec.la
# │   ├── libaec.so -> libaec.so.0.0.12
# │   ├── libaec.so.0 -> libaec.so.0.0.12
# │   ├── libaec.so.0.0.12
# │   ├── libsz.a
# │   ├── libsz.la
# │   ├── libsz.so -> libsz.so.2.0.1
# │   ├── libsz.so.2 -> libsz.so.2.0.1
# │   ├── libsz.so.2.0.1
# │   ├── libz.a
# │   ├── libz.so -> libz.so.1.2.12
# │   ├── libz.so.1 -> libz.so.1.2.12
# │   ├── libz.so.1.2.12
# │   └── pkgconfig
# │       └── zlib.pc
# └── share
#     └── man
#         ├── man1
#         │   └── aec.1
#         └── man3
#             └── zlib.3
#
# 8 directories, 22 files

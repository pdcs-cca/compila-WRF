# %% [markdown]
# # hdf5

# %% [markdown]
# ## Configuración del código fuente

# %%
# %%bash -l
# #Inicializar entorno para el uso de compiladores INTEL
# pwd
# SETVARS_ARGS="--config=/opt/software/apps/intel/oneapi/config.txt"
# source /opt/software/apps/intel/oneapi/setvars.sh
#
# #Definir variables para el uso de los compiladores de intel
# #para la configuración del código fuente
# export CC=icc FC=ifort F77=ifort F90=ifort CXX=icpc
# export CFLAGS=" -O3"
# export CPPFLAGS="-I$HOME/tmp/2022/wrf/include"
# export LDFLAGS="-L$HOME/tmp/2022/wrf/lib -Wl,-rpath=$HOME/tmp/2022/wrf/lib"
#
# #Crear el directorio build  si  NO existe
# test ! -e build && mkdir -v build
# cd build
#
# #Desempaquetar código fuente
# tar xzf ../src/hdf5-1.10.8.tar.gz
# cd hdf5-1.10.8
#
# #Configurar el código fuentes usando los compiladores de intel
# #previamente se definieron las variables de entorno
# #CC, FC, F77, F90, CFLAGS
#
# #Se indica mediante la opción --prefix  el directorio de instalación
# ./configure --enable-fortran --with-zlib=$HOME/tmp/2022/wrf --with-szlib=$HOME/tmp/2022/wrf  --prefix=$HOME/tmp/2022/wrf
# Out:
# /LUSTRE/tmp/soporte/compila-WRF
#
# :: initializing oneAPI environment ...
#    bash: BASH_VERSION = 5.1.4(1)-release
#    args: Using "SETVARS_ARGS" for setvars.sh arguments: --config=/opt/software/apps/intel/oneapi/config.txt
# :: compiler -- latest
# :: mpi -- latest
# :: oneAPI environment initialized ::
#
# checking for a BSD-compatible install... /usr/bin/install -c
# checking whether build environment is sane... yes
# checking for a thread-safe mkdir -p... /usr/bin/mkdir -p
# checking for gawk... gawk
# checking whether make sets $(MAKE)... yes
# checking whether make supports nested variables... yes
# checking whether make supports nested variables... (cached) yes
# checking whether to enable maintainer-specific portions of Makefiles... no
# checking build system type... x86_64-unknown-linux-gnu
# checking host system type... x86_64-unknown-linux-gnu
# checking shell variables initial values... done
# checking if basename works... yes
# checking if xargs works... yes
# checking for cached host... none
# checking for config x86_64-unknown-linux-gnu... no
# checking for config x86_64-unknown-linux-gnu... no
# checking for config unknown-linux-gnu... no
# checking for config unknown-linux-gnu... no
# checking for config x86_64-linux-gnu... no
# checking for config x86_64-linux-gnu... no
# checking for config x86_64-unknown... no
# checking for config linux-gnu... found
# compiler 'icc' is Intel icc-2021.5.0
# compiler 'ifort' is Intel ifort-2021.5.0
# compiler 'icpc' is Intel icpc-2021.5.0
# checking for config ./config/site-specific/host-tlaloc... no
# checking for clang sanitizer checks... checking build mode... production
# checking for gcc... icc
# checking whether the C compiler works... yes
# checking for C compiler default output file name... a.out
# checking for suffix of executables...
# checking whether we are cross compiling... no
# checking for suffix of object files... o
# checking whether we are using the GNU C compiler... yes
# checking whether icc accepts -g... yes
# checking for icc option to accept ISO C89... none needed
# checking whether icc understands -c and -o together... yes
# checking for style of include used by make... GNU
# checking dependency style of icc... gcc3
# checking if unsupported combinations of configure options are allowed... no
# checking how to run the C preprocessor... icc -E
# checking for grep that handles long lines and -e... /usr/bin/grep
# checking for egrep... /usr/bin/grep -E
# checking for ANSI C header files... yes
# checking for sys/types.h... yes
# checking for sys/stat.h... yes
# checking for stdlib.h... yes
# checking for string.h... yes
# checking for memory.h... yes
# checking for strings.h... yes
# checking for inttypes.h... yes
# checking for stdint.h... yes
# checking for unistd.h... yes
# checking for off_t... yes
# checking for size_t... yes
# checking for ssize_t... yes
# checking for ptrdiff_t... yes
# checking whether byte ordering is bigendian... no
# checking size of char... 1
# checking size of short... 2
# checking size of int... 4
# checking size of unsigned... 4
# checking size of long... 8
# checking size of long long... 8
# checking size of __int64... 8
# checking size of float... 4
# checking size of double... 8
# checking size of long double... 16
# checking size of __float128... 16
# checking size of _Quad... 0
# checking quadmath.h usability... yes
# checking quadmath.h presence... yes
# checking for quadmath.h... yes
# checking maximum decimal precision for C... 33
# checking if Fortran interface enabled... yes
# checking whether we are using the GNU Fortran compiler... no
# checking whether ifort accepts -g... yes
# checking for Fortran flag to compile .f90 files... none
# checking whether we are using the GNU Fortran compiler... (cached) no
# checking whether ifort accepts -g... (cached) yes
# checking what ifort does with modules... module.mod
# checking how ifort finds modules... -I
# checking if Fortran compiler version compatible with Fortran 2003 HDF... yes
# checking how to get verbose linking output from ifort... -v
# checking for Fortran libraries of ifort...  -L/home/soporte/tmp/2022/wrf/lib -L/opt/software/apps/intel/oneapi/mpi/2021.5.1//libfabric/lib -L/opt/software/apps/intel/oneapi/mpi/2021.5.1//lib/release -L/opt/software/apps/intel/oneapi/mpi/2021.5.1//lib -L/opt/software/apps/intel/oneapi/compiler/2022.0.2/linux/compiler/lib/intel64_lin -L/opt/software/apps/intel/oneapi/compiler/2022.0.2/linux/lib -L/opt/software/apps/intel/oneapi/compiler/2022.0.2/linux/bin/intel64/../../compiler/lib/intel64_lin -L/opt/software/apps/intel/oneapi/mpi/2021.5.1//libfabric/lib/../lib/ -L/opt/software/apps/intel/oneapi/mpi/2021.5.1//lib/../lib/ -L/opt/software/apps/intel/oneapi/compiler/2022.0.2/linux/lib/../lib/ -L/usr/lib/gcc/x86_64-linux-gnu/10/ -L/usr/lib/gcc/x86_64-linux-gnu/10/../../../x86_64-linux-gnu/ -L/usr/lib/gcc/x86_64-linux-gnu/10/../../../../lib64 -L/usr/lib/gcc/x86_64-linux-gnu/10/../../../../lib/ -L/lib/x86_64-linux-gnu/ -L/lib/../lib64 -L/lib/../lib/ -L/usr/lib/x86_64-linux-gnu/ -L/usr/lib/../lib64 -L/usr/lib/../lib/ -L/opt/software/apps/intel/oneapi/mpi/2021.5.1//libfabric/lib/ -L/opt/software/apps/intel/oneapi/mpi/2021.5.1//lib/release/ -L/opt/software/apps/intel/oneapi/mpi/2021.5.1//lib/ -L/opt/software/apps/intel/oneapi/compiler/2022.0.2/linux/compiler/lib/intel64_lin/ -L/opt/software/apps/intel/oneapi/compiler/2022.0.2/linux/lib/ -L/usr/lib/gcc/x86_64-linux-gnu/10/../../../ -L/lib64 -L/lib/ -L/usr/lib64 -L/usr/lib -lifport -lifcoremt -limf -lsvml -lm -lipgo -lirc -lpthread -lirc_s -ldl
# checking for dummy main to link with Fortran libraries... none
# checking for Fortran name-mangling scheme... lower case, underscore, no extra underscore
# checking if Fortran compiler supports intrinsic SIZEOF... yes
# checking if Fortran compiler supports intrinsic C_SIZEOF... yes
# checking if Fortran compiler supports intrinsic STORAGE_SIZE... yes
# checking if Fortran compiler supports intrinsic module ISO_FORTRAN_ENV... yes
# checking for Number of Fortran INTEGER KINDs... 4
# checking for Fortran INTEGER KINDs... {1,2,4,8}
# checking for Fortran REAL KINDs... {4,8,16}
# checking for Fortran REALs maximum decimal precision... 33
# checking sizeof of native KINDS...
# checking for Number of Fortran INTEGER KINDs... 4
# checking for Fortran INTEGER KINDs... {1,2,4,8}
# checking for Fortran REAL KINDs... {4,8,16}
# checking for Fortran REALs maximum decimal precision... 33
# checking sizeof of available INTEGER KINDs... {1,2,4,8}
# checking sizeof of available REAL KINDs... {4,8,16}
# checking if Fortran compiler supports intrinsic C_LONG_DOUBLE... yes
# checking if Fortran C_LONG_DOUBLE is different from C_DOUBLE... yes
# checking for Fortran interoperable KINDS with C... {4,8,16}
# checking whether we are using the GNU C++ compiler... yes
# checking whether icpc accepts -g... yes
# checking dependency style of icpc... gcc3
# checking how to run the C++ preprocessor... icpc -E
# checking if c++ interface enabled... no
# checking if the high-level library is enabled... yes
# checking if the high-level tools are enabled... no
# checking for ar... ar
# checking whether make sets $(MAKE)... (cached) yes
# checking for tr... /usr/bin/tr
# checking if srcdir= and time commands work together... yes
# checking if Java JNI interface enabled... no
# checking if shared Fortran libraries are supported... yes
# checking if building tests is disabled... no
# checking if building tools is disabled... no
# checking if building doxygen is enabled... no
# Doxygen support is disabled
# checking how to print strings... printf
# checking for a sed that does not truncate output... /usr/bin/sed
# checking for fgrep... /usr/bin/grep -F
# checking for ld used by icc... /usr/bin/ld
# checking if the linker (/usr/bin/ld) is GNU ld... yes
# checking for BSD- or MS-compatible name lister (nm)... /usr/bin/nm -B
# checking the name lister (/usr/bin/nm -B) interface... BSD nm
# checking whether ln -s works... yes
# checking the maximum length of command line arguments... 3458764513820540925
# checking how to convert x86_64-unknown-linux-gnu file names to x86_64-unknown-linux-gnu format... func_convert_file_noop
# checking how to convert x86_64-unknown-linux-gnu file names to toolchain format... func_convert_file_noop
# checking for /usr/bin/ld option to reload object files... -r
# checking for objdump... objdump
# checking how to recognize dependent libraries... pass_all
# checking for dlltool... no
# checking how to associate runtime and link libraries... printf %s\n
# checking for archiver @FILE support... @
# checking for strip... strip
# checking for ranlib... ranlib
# checking command to parse /usr/bin/nm -B output from icc object... ok
# checking for sysroot... no
# checking for a working dd... /usr/bin/dd
# checking how to truncate binary pipes... /usr/bin/dd bs=4096 count=1
# checking for mt... mt
# checking if mt is a manifest tool... no
# checking for dlfcn.h... yes
# checking for objdir... .libs
# checking if icc supports -fno-rtti -fno-exceptions... yes
# checking for icc option to produce PIC... -fPIC -DPIC
# checking if icc PIC flag -fPIC -DPIC works... yes
# checking if icc static flag -static works... yes
# checking if icc supports -c -o file.o... yes
# checking if icc supports -c -o file.o... (cached) yes
# checking whether the icc linker (/usr/bin/ld -m elf_x86_64) supports shared libraries... yes
# checking whether -lc should be explicitly linked in... no
# checking dynamic linker characteristics... GNU/Linux ld.so
# checking how to hardcode library paths into programs... immediate
# checking for shl_load... no
# checking for shl_load in -ldld... no
# checking for dlopen... yes
# checking whether a program can dlopen itself... yes
# checking whether a statically linked program can dlopen itself... no
# checking whether stripping libraries is possible... yes
# checking if libtool supports shared libraries... yes
# checking whether to build shared libraries... yes
# checking whether to build static libraries... yes
# checking if libtool supports shared libraries... yes
# checking whether to build shared libraries... yes
# checking whether to build static libraries... yes
# checking for ifort option to produce PIC... -fPIC
# checking if ifort PIC flag -fPIC works... yes
# checking if ifort static flag -static works... yes
# checking if ifort supports -c -o file.o... yes
# checking if ifort supports -c -o file.o... (cached) yes
# checking whether the ifort linker (/usr/bin/ld -m elf_x86_64) supports shared libraries... yes
# checking dynamic linker characteristics... (cached) GNU/Linux ld.so
# checking how to hardcode library paths into programs... immediate
# checking if we should install only statically linked executables... no
# checking if -Wl,-rpath should be used to link shared libs in nondefault directories... yes
# checking for ceil in -lm... yes
# checking for dlopen in -ldl... yes
# checking for ANSI C header files... (cached) yes
# checking whether time.h and sys/time.h may both be included... yes
# checking dirent.h usability... yes
# checking dirent.h presence... yes
# checking for dirent.h... yes
# checking features.h usability... yes
# checking features.h presence... yes
# checking for features.h... yes
# checking pwd.h usability... yes
# checking pwd.h presence... yes
# checking for pwd.h... yes
# checking setjmp.h usability... yes
# checking setjmp.h presence... yes
# checking for setjmp.h... yes
# checking stdbool.h usability... yes
# checking stdbool.h presence... yes
# checking for stdbool.h... yes
# checking stddef.h usability... yes
# checking stddef.h presence... yes
# checking for stddef.h... yes
# checking for unistd.h... (cached) yes
# checking sys/file.h usability... yes
# checking sys/file.h presence... yes
# checking for sys/file.h... yes
# checking sys/ioctl.h usability... yes
# checking sys/ioctl.h presence... yes
# checking for sys/ioctl.h... yes
# checking sys/resource.h usability... yes
# checking sys/resource.h presence... yes
# checking for sys/resource.h... yes
# checking for sys/stat.h... (cached) yes
# checking sys/time.h usability... yes
# checking sys/time.h presence... yes
# checking for sys/time.h... yes
# checking for sys/types.h... (cached) yes
# checking for stdint.h... (cached) yes
# checking io.h usability... no
# checking io.h presence... no
# checking for io.h... no
# checking winsock2.h usability... no
# checking winsock2.h presence... no
# checking for winsock2.h... no
# checking sys/timeb.h usability... yes
# checking sys/timeb.h presence... yes
# checking for sys/timeb.h... yes
# checking arpa/inet.h usability... yes
# checking arpa/inet.h presence... yes
# checking for arpa/inet.h... yes
# checking netdb.h usability... yes
# checking netdb.h presence... yes
# checking for netdb.h... yes
# checking netinet/in.h usability... yes
# checking netinet/in.h presence... yes
# checking for netinet/in.h... yes
# checking sys/socket.h usability... yes
# checking sys/socket.h presence... yes
# checking for sys/socket.h... yes
# checking if libtool needs -no-undefined flag to build shared libraries... no
# checking for _FILE_OFFSET_BITS value needed for large files... no
# checking size of int8_t... 1
# checking size of uint8_t... 1
# checking size of int_least8_t... 1
# checking size of uint_least8_t... 1
# checking size of int_fast8_t... 1
# checking size of uint_fast8_t... 1
# checking size of int16_t... 2
# checking size of uint16_t... 2
# checking size of int_least16_t... 2
# checking size of uint_least16_t... 2
# checking size of int_fast16_t... 8
# checking size of uint_fast16_t... 8
# checking size of int32_t... 4
# checking size of uint32_t... 4
# checking size of int_least32_t... 4
# checking size of uint_least32_t... 4
# checking size of int_fast32_t... 8
# checking size of uint_fast32_t... 8
# checking size of int64_t... 8
# checking size of uint64_t... 8
# checking size of int_least64_t... 8
# checking size of uint_least64_t... 8
# checking size of int_fast64_t... 8
# checking size of uint_fast64_t... 8
# checking size of size_t... 8
# checking size of ssize_t... 8
# checking size of ptrdiff_t... 8
# checking size of off_t... 8
# checking size of bool... 1
# checking size of time_t... 8
# checking if dev_t is scalar... yes
# checking for dmalloc library... suppressed
# checking zlib.h usability... yes
# checking zlib.h presence... yes
# checking for zlib.h... yes
# checking for compress2 in -lz... yes
# checking for compress2... yes
# checking for SZ_BufftoBuffCompress in -lsz... yes
# checking szlib.h usability... yes
# checking szlib.h presence... yes
# checking for szlib.h... yes
# checking for szlib encoder... no
# checking for thread safe support... no
# checking whether CLOCK_MONOTONIC is declared... yes
# checking for tm_gmtoff in struct tm... yes
# checking for global timezone variable... no
# checking for st_blocks in struct stat... yes
# checking for _getvideoconfig... no
# checking for gettextinfo... no
# checking for GetConsoleScreenBufferInfo... no
# checking for getpwuid... no
# checking for _scrsize... no
# checking for ioctl... no
# checking for struct videoconfig... no
# checking for struct text_info... no
# checking for TIOCGWINSZ... yes
# checking for TIOCGETD... yes
# checking for library containing clock_gettime... no
# checking for alarm... no
# checking for asprintf... no
# checking for clock_gettime... no
# checking for difftime... no
# checking for fcntl... no
# checking for flock... no
# checking for fork... no
# checking for frexpf... no
# checking for frexpl... no
# checking for gethostname... no
# checking for getrusage... no
# checking for gettimeofday... no
# checking for lstat... no
# checking for rand_r... no
# checking for random... no
# checking for setsysinfo... no
# checking for signal... no
# checking for longjmp... no
# checking for setjmp... no
# checking for siglongjmp... no
# checking for sigsetjmp... no
# checking for sigprocmask... no
# checking for snprintf... no
# checking for srandom... no
# checking for strdup... no
# checking for symlink... no
# checking for system... no
# checking for strtoll... no
# checking for strtoull... no
# checking for tmpfile... no
# checking for vasprintf... no
# checking for vsnprintf... no
# checking for waitpid... no
# checking for roundf... no
# checking for lroundf... no
# checking for llroundf... no
# checking for round... no
# checking for lround... no
# checking for llround... no
# checking for an ANSI C-conforming const... yes
# checking if the compiler understands  __inline__... yes
# checking if the compiler understands __inline... yes
# checking if the compiler understands inline... yes
# checking for __attribute__ extension... yes
# checking for __func__ extension... yes
# checking for __FUNCTION__ extension... yes
# checking for C99 designated initialization support... yes
# checking how to print long long... %unknownd and %unknownu
# checking enable build diagnostics... no
# checking enable debugging symbols... no
# checking enable asserts... no
# checking enable developer warnings... no
# checking enable warnings as errors... no
# checking profiling... no
# checking optimization level... high
# checking enable file locking... best-effort
# checking for internal debug output... none
# checking whether function stack tracking is enabled... no
# checking for API tracing... no
# checking whether a memory checking tool will be used... no
# checking whether internal memory allocation sanity checking is used... no
# checking for parallel support files... skipped
# checking whether O_DIRECT is declared... yes
# checking for posix_memalign... no
# checking if the direct I/O virtual file driver (VFD) is enabled... no
# checking if the Mirror virtual file driver (VFD) is enabled... no
# checking if the Read-Only S3 virtual file driver (VFD) is enabled... no
# checking for libhdfs... suppressed
# checking for custom examples path definition... ${prefix}/share/hdf5_examples
# checking for custom plugin default path definition... /usr/local/hdf5/lib/plugin
# checking whether exception handling functions is checked during data conversions... yes
# checking whether data accuracy is guaranteed during data conversions... yes
# checking if the machine has window style path name... no
# checking if using special algorithm to convert long double to (unsigned) long values... no
# checking if using special algorithm to convert (unsigned) long to long double values... no
# checking if correctly converting long double to (unsigned) long long values... no
# checking if correctly converting (unsigned) long long to long double values... no
# checking if the system is IBM ppc64le and cannot correctly convert some long double values... no
# checking additional programs should be built... no
# checking if deprecated public symbols are available... yes
# checking which version of public symbols to use by default... v110
# checking whether to perform strict file format checks... no
# checking for pread... no
# checking for pwrite... no
# checking whether to use pread/pwrite instead of read/write in certain VFDs... no
# checking whether to have library information embedded in the executables... yes
# checking if alignment restrictions are strictly enforced... yes
# configure: creating ./config.lt
# config.lt: creating libtool
# checking that generated files are newer than configure... done
# configure: creating ./config.status
# config.status: creating src/libhdf5.settings
# config.status: creating Makefile
# config.status: creating doxygen/Doxyfile
# config.status: creating src/Makefile
# config.status: creating test/Makefile
# config.status: creating test/H5srcdir_str.h
# config.status: creating test/testabort_fail.sh
# config.status: creating test/testcheck_version.sh
# config.status: creating test/testerror.sh
# config.status: creating test/testexternal_env.sh
# config.status: creating test/testflushrefresh.sh
# config.status: creating test/testlibinfo.sh
# config.status: creating test/testlinks_env.sh
# config.status: creating test/testswmr.sh
# config.status: creating test/testvds_env.sh
# config.status: creating test/testvdsswmr.sh
# config.status: creating test/test_filter_plugin.sh
# config.status: creating test/test_mirror.sh
# config.status: creating test/test_usecases.sh
# config.status: creating testpar/Makefile
# config.status: creating testpar/testpflush.sh
# config.status: creating utils/Makefile
# config.status: creating utils/mirror_vfd/Makefile
# config.status: creating tools/Makefile
# config.status: creating tools/lib/Makefile
# config.status: creating tools/libtest/Makefile
# config.status: creating tools/src/Makefile
# config.status: creating tools/src/h5dump/Makefile
# config.status: creating tools/src/h5import/Makefile
# config.status: creating tools/src/h5diff/Makefile
# config.status: creating tools/src/h5jam/Makefile
# config.status: creating tools/src/h5repack/Makefile
# config.status: creating tools/src/h5ls/Makefile
# config.status: creating tools/src/h5copy/Makefile
# config.status: creating tools/src/misc/Makefile
# config.status: creating tools/src/h5stat/Makefile
# config.status: creating tools/test/Makefile
# config.status: creating tools/test/h5dump/Makefile
# config.status: creating tools/test/h5dump/h5dump_plugin.sh
# config.status: creating tools/test/h5dump/testh5dump.sh
# config.status: creating tools/test/h5dump/testh5dumppbits.sh
# config.status: creating tools/test/h5dump/testh5dumpvds.sh
# config.status: creating tools/test/h5dump/testh5dumpxml.sh
# config.status: creating tools/test/h5ls/Makefile
# config.status: creating tools/test/h5ls/h5ls_plugin.sh
# config.status: creating tools/test/h5ls/testh5ls.sh
# config.status: creating tools/test/h5ls/testh5lsvds.sh
# config.status: creating tools/test/h5import/Makefile
# config.status: creating tools/test/h5import/h5importtestutil.sh
# config.status: creating tools/test/h5diff/Makefile
# config.status: creating tools/test/h5diff/h5diff_plugin.sh
# config.status: creating tools/test/h5diff/testh5diff.sh
# config.status: creating tools/test/h5diff/testph5diff.sh
# config.status: creating tools/src/h5format_convert/Makefile
# config.status: creating tools/test/h5format_convert/Makefile
# config.status: creating tools/test/h5format_convert/testh5fc.sh
# config.status: creating tools/test/h5jam/Makefile
# config.status: creating tools/test/h5jam/testh5jam.sh
# config.status: creating tools/test/h5repack/Makefile
# config.status: creating tools/test/h5repack/h5repack.sh
# config.status: creating tools/test/h5repack/h5repack_plugin.sh
# config.status: creating tools/test/h5copy/Makefile
# config.status: creating tools/test/h5copy/testh5copy.sh
# config.status: creating tools/test/misc/Makefile
# config.status: creating tools/test/misc/testh5clear.sh
# config.status: creating tools/test/misc/testh5mkgrp.sh
# config.status: creating tools/test/misc/testh5repart.sh
# config.status: creating tools/test/misc/vds/Makefile
# config.status: creating tools/test/h5stat/Makefile
# config.status: creating tools/test/h5stat/testh5stat.sh
# config.status: creating tools/src/h5perf/Makefile
# config.status: creating tools/test/perform/Makefile
# config.status: creating examples/Makefile
# config.status: creating examples/run-c-ex.sh
# config.status: creating examples/testh5cc.sh
# config.status: creating bin/h5cc
# config.status: creating bin/Makefile
# config.status: creating c++/Makefile
# config.status: creating c++/src/Makefile
# config.status: creating c++/src/h5c++
# config.status: creating c++/test/Makefile
# config.status: creating c++/test/H5srcdir_str.h
# config.status: creating c++/examples/Makefile
# config.status: creating c++/examples/run-c++-ex.sh
# config.status: creating c++/examples/testh5c++.sh
# config.status: creating fortran/Makefile
# config.status: creating fortran/src/h5fc
# config.status: creating fortran/src/Makefile
# config.status: creating fortran/src/H5fort_type_defines.h
# config.status: creating fortran/test/Makefile
# config.status: creating fortran/testpar/Makefile
# config.status: creating fortran/examples/Makefile
# config.status: creating fortran/examples/run-fortran-ex.sh
# config.status: creating fortran/examples/testh5fc.sh
# config.status: creating java/Makefile
# config.status: creating java/src/Makefile
# config.status: creating java/src/jni/Makefile
# config.status: creating java/test/Makefile
# config.status: creating java/test/junit.sh
# config.status: creating java/examples/Makefile
# config.status: creating java/examples/intro/Makefile
# config.status: creating java/examples/intro/JavaIntroExample.sh
# config.status: creating java/examples/datasets/Makefile
# config.status: creating java/examples/datasets/JavaDatasetExample.sh
# config.status: creating java/examples/datatypes/Makefile
# config.status: creating java/examples/datatypes/JavaDatatypeExample.sh
# config.status: creating java/examples/groups/Makefile
# config.status: creating java/examples/groups/JavaGroupExample.sh
# config.status: creating hl/Makefile
# config.status: creating hl/src/Makefile
# config.status: creating hl/test/Makefile
# config.status: creating hl/test/H5srcdir_str.h
# config.status: creating hl/tools/Makefile
# config.status: creating hl/tools/gif2h5/Makefile
# config.status: creating hl/tools/gif2h5/h52giftest.sh
# config.status: creating hl/tools/h5watch/Makefile
# config.status: creating hl/tools/h5watch/testh5watch.sh
# config.status: creating hl/examples/Makefile
# config.status: creating hl/examples/run-hlc-ex.sh
# config.status: creating hl/c++/Makefile
# config.status: creating hl/c++/src/Makefile
# config.status: creating hl/c++/test/Makefile
# config.status: creating hl/c++/examples/Makefile
# config.status: creating hl/c++/examples/run-hlc++-ex.sh
# config.status: creating hl/fortran/Makefile
# config.status: creating hl/fortran/src/Makefile
# config.status: creating hl/fortran/test/Makefile
# config.status: creating hl/fortran/examples/Makefile
# config.status: creating hl/fortran/examples/run-hlfortran-ex.sh
# config.status: creating src/H5config.h
# config.status: creating fortran/src/H5config_f.inc
# config.status: executing pubconf commands
# creating src/H5pubconf.h
# Post process src/libhdf5.settings
# config.status: executing depfiles commands
# config.status: executing libtool commands
# config.status: executing .classes commands
# 	    SUMMARY OF THE HDF5 CONFIGURATION
# 	    =================================
#
# General Information:
# -------------------
#                    HDF5 Version: 1.10.8
#                   Configured on: Sun Apr 17 16:44:45 CDT 2022
#                   Configured by: soporte@tlaloc
#                     Host system: x86_64-unknown-linux-gnu
#               Uname information: Linux tlaloc 5.10.0-12-amd64 #1 SMP Debian 5.10.103-1 (2022-03-07) x86_64 GNU/Linux
#                        Byte sex: little-endian
#              Installation point: /home/soporte/tmp/2022/wrf
#
# Compiling Options:
# ------------------
#                      Build Mode: production
#               Debugging Symbols: no
#                         Asserts: no
#                       Profiling: no
#              Optimization Level: high
#
# Linking Options:
# ----------------
#                       Libraries: static, shared
#   Statically Linked Executables:
#                         LDFLAGS: -L/home/soporte/tmp/2022/wrf/lib -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib
#                      H5_LDFLAGS:
#                      AM_LDFLAGS:  -L/home/soporte/tmp/2022/wrf/lib -L/home/soporte/tmp/2022/wrf/lib
#                 Extra libraries: -lsz -lz -ldl -lm
#                        Archiver: ar
#                        AR_FLAGS: cr
#                          Ranlib: ranlib
#
# Languages:
# ----------
#                               C: yes
#                      C Compiler: /opt/software/apps/intel/oneapi/compiler/2022.0.2/linux/bin/intel64/icc ( Intel(R) C Intel(R) 64 Compiler Version 2021.5.0 Build 20211109_000000)
#                        CPPFLAGS: -I/home/soporte/tmp/2022/wrf/include
#                     H5_CPPFLAGS: -D_GNU_SOURCE -D_POSIX_C_SOURCE=200809L   -DNDEBUG -UH5_DEBUG_API
#                     AM_CPPFLAGS:  -I/home/soporte/tmp/2022/wrf/include -I/home/soporte/tmp/2022/wrf/include
#                         C Flags:  -O3
#                      H5 C Flags:   -std=c99 -Wall -Wcomment -Wdeprecated -Wextra-tokens -Wformat -Wformat-security -Wmain -Wmissing-declarations -Wmissing-prototypes -Wp64 -Wpointer-arith -Wreturn-type -Wshadow -Wstrict-prototypes -Wtrigraphs -Wuninitialized -Wunknown-pragmas -Wunused-function -Wunused-variable -Wwrite-strings -Wic-pointer -Wsign-compare   -Wl,-s   -O3 @H5_ECFLAGS@
#                      AM C Flags:
#                Shared C Library: yes
#                Static C Library: yes
#
#
#                         Fortran: yes
#                Fortran Compiler: /opt/software/apps/intel/oneapi/compiler/2022.0.2/linux/bin/intel64/ifort ( Intel(R) Fortran Intel(R) 64 Compiler Version 2021.5.0 Build 20211109_000000)
#                   Fortran Flags:
#                H5 Fortran Flags:  -stand:f03 -free -warn:all    -O3
#                AM Fortran Flags:
#          Shared Fortran Library: yes
#          Static Fortran Library: yes
#
#                             C++: no
#
#                            Java: no
#
#
# Features:
# ---------
#                    Parallel HDF5: no
# Parallel Filtered Dataset Writes: no
#               Large Parallel I/O: no
#               High-level library: yes
#                 Build HDF5 Tests: yes
#                 Build HDF5 Tools: yes
#                     Threadsafety: no
#              Default API mapping: v110
#   With deprecated public symbols: yes
#           I/O filters (external): deflate(zlib),szip(no encoder)
#                              MPE: no
#                       Direct VFD: no
#                       Mirror VFD: no
#               (Read-Only) S3 VFD: no
#             (Read-Only) HDFS VFD: no
#                          dmalloc: no
#   Packages w/ extra debug output: none
#                      API tracing: no
#             Using memory checker: no
#  Memory allocation sanity checks: no
#           Function stack tracing: no
#                 Use file locking: best-effort
#        Strict file format checks: no
#     Optimization instrumentation: no

# %% [markdown]
# ## Construcción o compilación de la biblioteca
#
# Se construye la biblioteca  con el comando __make__ y posteriormente se realizan pruebas de uso con el comando __make check__, por último se instala la biblioteca con el comando __make install__ en el directorio indicado con la opción  __--prefix__ durante el proceso de configuración.

# %%
# %%bash -l
# pwd
# SETVARS_ARGS="--config=/opt/software/apps/intel/oneapi/config.txt"
# source /opt/software/apps/intel/oneapi/setvars.sh
#
# #Ingresar al directorio del código fuente previamente desempaquetado
# #y configurado.
# #Utilizar la herramienta make para la construcción de la biblioteca
# cd build/hdf5-1.10.8
# \time -v make
# Out:
# /LUSTRE/tmp/soporte/compila-WRF
#
# :: initializing oneAPI environment ...
#    bash: BASH_VERSION = 5.1.4(1)-release
#    args: Using "SETVARS_ARGS" for setvars.sh arguments: --config=/opt/software/apps/intel/oneapi/config.txt
# :: compiler -- latest
# :: mpi -- latest
# :: oneAPI environment initialized ::
#
# Making all in src
# make[1]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/src'
# make  all-am
# make[2]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/src'
#   CC       H5.lo
#   CC       H5checksum.lo
#   CC       H5dbg.lo
#   CC       H5system.lo
#   CC       H5timer.lo
#   CC       H5trace.lo
#   CC       H5A.lo
#   CC       H5Abtree2.lo
#   CC       H5Adense.lo
#   CC       H5Adeprec.lo
#   CC       H5Aint.lo
#   CC       H5Atest.lo
#   CC       H5AC.lo
#   CC       H5ACdbg.lo
#   CC       H5ACproxy_entry.lo
#   CC       H5B.lo
#   CC       H5Bcache.lo
#   CC       H5Bdbg.lo
#   CC       H5B2.lo
#   CC       H5B2cache.lo
#   CC       H5B2dbg.lo
#   CC       H5B2hdr.lo
#   CC       H5B2int.lo
#   CC       H5B2internal.lo
#   CC       H5B2leaf.lo
#   CC       H5B2stat.lo
#   CC       H5B2test.lo
#   CC       H5C.lo
#   CC       H5Cdbg.lo
#   CC       H5Cepoch.lo
#   CC       H5Cimage.lo
#   CC       H5Clog.lo
#   CC       H5Clog_json.lo
#   CC       H5Clog_trace.lo
#   CC       H5Cprefetched.lo
#   CC       H5Cquery.lo
#   CC       H5Ctag.lo
#   CC       H5Ctest.lo
#   CC       H5CS.lo
#   CC       H5CX.lo
#   CC       H5D.lo
#   CC       H5Dbtree.lo
#   CC       H5Dbtree2.lo
#   CC       H5Dchunk.lo
#   CC       H5Dcompact.lo
#   CC       H5Dcontig.lo
#   CC       H5Ddbg.lo
#   CC       H5Ddeprec.lo
#   CC       H5Dearray.lo
#   CC       H5Defl.lo
#   CC       H5Dfarray.lo
#   CC       H5Dfill.lo
#   CC       H5Dint.lo
#   CC       H5Dio.lo
#   CC       H5Dlayout.lo
#   CC       H5Dnone.lo
#   CC       H5Doh.lo
#   CC       H5Dscatgath.lo
#   CC       H5Dselect.lo
#   CC       H5Dsingle.lo
#   CC       H5Dtest.lo
#   CC       H5Dvirtual.lo
#   CC       H5E.lo
#   CC       H5Edeprec.lo
#   CC       H5Eint.lo
#   CC       H5EA.lo
#   CC       H5EAcache.lo
#   CC       H5EAdbg.lo
#   CC       H5EAdblkpage.lo
#   CC       H5EAdblock.lo
#   CC       H5EAhdr.lo
#   CC       H5EAiblock.lo
#   CC       H5EAint.lo
#   CC       H5EAsblock.lo
#   CC       H5EAstat.lo
#   CC       H5EAtest.lo
#   CC       H5F.lo
#   CC       H5Faccum.lo
#   CC       H5Fcwfs.lo
#   CC       H5Fdbg.lo
#   CC       H5Fdeprec.lo
#   CC       H5Fefc.lo
#   CC       H5Ffake.lo
#   CC       H5Fint.lo
#   CC       H5Fio.lo
#   CC       H5Fmount.lo
#   CC       H5Fquery.lo
#   CC       H5Fsfile.lo
#   CC       H5Fspace.lo
#   CC       H5Fsuper.lo
#   CC       H5Fsuper_cache.lo
#   CC       H5Ftest.lo
#   CC       H5FA.lo
#   CC       H5FAcache.lo
#   CC       H5FAdbg.lo
#   CC       H5FAdblock.lo
#   CC       H5FAdblkpage.lo
#   CC       H5FAhdr.lo
#   CC       H5FAint.lo
#   CC       H5FAstat.lo
#   CC       H5FAtest.lo
#   CC       H5FD.lo
#   CC       H5FDcore.lo
#   CC       H5FDfamily.lo
#   CC       H5FDhdfs.lo
#   CC       H5FDint.lo
#   CC       H5FDlog.lo
#   CC       H5FDmulti.lo
#   CC       H5FDsec2.lo
#   CC       H5FDspace.lo
#   CC       H5FDsplitter.lo
#   CC       H5FDstdio.lo
#   CC       H5FDtest.lo
#   CC       H5FL.lo
#   CC       H5FO.lo
#   CC       H5FS.lo
#   CC       H5FScache.lo
#   CC       H5FSdbg.lo
#   CC       H5FSint.lo
#   CC       H5FSsection.lo
#   CC       H5FSstat.lo
#   CC       H5FStest.lo
#   CC       H5G.lo
#   CC       H5Gbtree2.lo
#   CC       H5Gcache.lo
#   CC       H5Gcompact.lo
#   CC       H5Gdense.lo
#   CC       H5Gdeprec.lo
#   CC       H5Gent.lo
#   CC       H5Gint.lo
#   CC       H5Glink.lo
#   CC       H5Gloc.lo
#   CC       H5Gname.lo
#   CC       H5Gnode.lo
#   CC       H5Gobj.lo
#   CC       H5Goh.lo
#   CC       H5Groot.lo
#   CC       H5Gstab.lo
#   CC       H5Gtest.lo
#   CC       H5Gtraverse.lo
#   CC       H5HF.lo
#   CC       H5HFbtree2.lo
#   CC       H5HFcache.lo
#   CC       H5HFdbg.lo
#   CC       H5HFdblock.lo
#   CC       H5HFdtable.lo
#   CC       H5HFhdr.lo
#   CC       H5HFhuge.lo
#   CC       H5HFiblock.lo
#   CC       H5HFiter.lo
#   CC       H5HFman.lo
#   CC       H5HFsection.lo
#   CC       H5HFspace.lo
#   CC       H5HFstat.lo
#   CC       H5HFtest.lo
#   CC       H5HFtiny.lo
#   CC       H5HG.lo
#   CC       H5HGcache.lo
#   CC       H5HGdbg.lo
#   CC       H5HGquery.lo
#   CC       H5HL.lo
#   CC       H5HLcache.lo
#   CC       H5HLdbg.lo
#   CC       H5HLint.lo
#   CC       H5HLprfx.lo
#   CC       H5HLdblk.lo
#   CC       H5HP.lo
#   CC       H5I.lo
#   CC       H5Idbg.lo
#   CC       H5Iint.lo
#   CC       H5Itest.lo
#   CC       H5L.lo
#   CC       H5Lexternal.lo
#   CC       H5make_libsettings.o
#   CCLD     H5make_libsettings
# LD_LIBRARY_PATH="$LD_LIBRARY_PATH`echo -L/home/soporte/tmp/2022/wrf/lib -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib |                  \
# 	sed -e 's/-L/:/g' -e 's/ //g'`"                               \
#  ./H5make_libsettings > H5lib_settings.c  ||                               \
#     (test $HDF5_Make_Ignore && echo "*** Error ignored") ||          \
#     (rm -f H5lib_settings.c ; exit 1)
#   CC       H5lib_settings.lo
#   CC       H5MF.lo
#   CC       H5MFaggr.lo
#   CC       H5MFdbg.lo
#   CC       H5MFsection.lo
#   CC       H5MM.lo
#   CC       H5MP.lo
#   CC       H5MPtest.lo
#   CC       H5O.lo
#   CC       H5Odeprec.lo
#   CC       H5Oainfo.lo
#   CC       H5Oalloc.lo
#   CC       H5Oattr.lo
#   CC       H5Oattribute.lo
#   CC       H5Obogus.lo
#   CC       H5Obtreek.lo
#   CC       H5Ocache.lo
#   CC       H5Ocache_image.lo
#   CC       H5Ochunk.lo
#   CC       H5Ocont.lo
#   CC       H5Ocopy.lo
#   CC       H5Odbg.lo
#   CC       H5Odrvinfo.lo
#   CC       H5Odtype.lo
#   CC       H5Oefl.lo
#   CC       H5Ofill.lo
#   CC       H5Oflush.lo
#   CC       H5Ofsinfo.lo
#   CC       H5Oginfo.lo
#   CC       H5Oint.lo
#   CC       H5Olayout.lo
#   CC       H5Olinfo.lo
#   CC       H5Olink.lo
#   CC       H5Omessage.lo
#   CC       H5Omtime.lo
#   CC       H5Oname.lo
#   CC       H5Onull.lo
#   CC       H5Opline.lo
#   CC       H5Orefcount.lo
#   CC       H5Osdspace.lo
#   CC       H5Oshared.lo
#   CC       H5Oshmesg.lo
#   CC       H5Ostab.lo
#   CC       H5Otest.lo
#   CC       H5Ounknown.lo
#   CC       H5P.lo
#   CC       H5Pacpl.lo
#   CC       H5Pdapl.lo
#   CC       H5Pdcpl.lo
#   CC       H5Pdeprec.lo
#   CC       H5Pdxpl.lo
#   CC       H5Pencdec.lo
#   CC       H5Pfapl.lo
#   CC       H5Pfcpl.lo
#   CC       H5Pfmpl.lo
#   CC       H5Pgcpl.lo
#   CC       H5Pint.lo
#   CC       H5Plapl.lo
#   CC       H5Plcpl.lo
#   CC       H5Pocpl.lo
#   CC       H5Pocpypl.lo
#   CC       H5Pstrcpl.lo
#   CC       H5Ptest.lo
#   CC       H5PB.lo
#   CC       H5PL.lo
#   CC       H5PLint.lo
#   CC       H5PLpath.lo
#   CC       H5PLplugin_cache.lo
#   CC       H5R.lo
#   CC       H5Rint.lo
#   CC       H5Rdeprec.lo
#   CC       H5UC.lo
#   CC       H5RS.lo
#   CC       H5S.lo
#   CC       H5Sall.lo
#   CC       H5Sdbg.lo
#   CC       H5Shyper.lo
#   CC       H5Snone.lo
#   CC       H5Spoint.lo
#   CC       H5Sselect.lo
#   CC       H5Stest.lo
#   CC       H5SL.lo
#   CC       H5SM.lo
#   CC       H5SMbtree2.lo
#   CC       H5SMcache.lo
#   CC       H5SMmessage.lo
#   CC       H5SMtest.lo
#   CC       H5T.lo
#   CC       H5Tarray.lo
#   CC       H5Tbit.lo
#   CC       H5Tcommit.lo
#   CC       H5Tcompound.lo
#   CC       H5Tconv.lo
#   CC       H5Tcset.lo
#   CC       H5Tdbg.lo
#   CC       H5Tdeprec.lo
#   CC       H5Tenum.lo
#   CC       H5Tfields.lo
#   CC       H5Tfixed.lo
#   CC       H5Tfloat.lo
#   CC       H5detect.o
#   CCLD     H5detect
# LD_LIBRARY_PATH="$LD_LIBRARY_PATH`echo -L/home/soporte/tmp/2022/wrf/lib -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib |                  \
# 	sed -e 's/-L/:/g' -e 's/ //g'`"                               \
#  ./H5detect > H5Tinit.c  ||                               \
#     (test $HDF5_Make_Ignore && echo "*** Error ignored") ||          \
#     (rm -f H5Tinit.c ; exit 1)
#   CC       H5Tinit.lo
#   CC       H5Tnative.lo
#   CC       H5Toffset.lo
#   CC       H5Toh.lo
#   CC       H5Topaque.lo
#   CC       H5Torder.lo
#   CC       H5Tpad.lo
#   CC       H5Tprecis.lo
#   CC       H5Tstrpad.lo
#   CC       H5Tvisit.lo
#   CC       H5Tvlen.lo
#   CC       H5TS.lo
#   CC       H5VM.lo
#   CC       H5WB.lo
#   CC       H5Z.lo
#   CC       H5Zdeflate.lo
#   CC       H5Zfletcher32.lo
#   CC       H5Znbit.lo
#   CC       H5Zshuffle.lo
#   CC       H5Zscaleoffset.lo
#   CC       H5Zszip.lo
#   CC       H5Ztrans.lo
#   CCLD     libhdf5.la
# make[2]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/src'
# make[1]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/src'
# Making all in test
# make[1]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/test'
#   CC       h5test.lo
#   CC       testframe.lo
#   CC       cache_common.lo
#   CC       swmr_common.lo
#   CC       external_common.lo
#   CCLD     libh5test.la
#   CC       filter_plugin1_dsets.lo
#   CCLD     libfilter_plugin1_dsets.la
#   CC       filter_plugin2_dsets.lo
#   CCLD     libfilter_plugin2_dsets.la
#   CC       filter_plugin3_dsets.lo
#   CCLD     libfilter_plugin3_dsets.la
#   CC       filter_plugin4_groups.lo
#   CCLD     libfilter_plugin4_groups.la
#   CC       testhdf5.o
#   CC       tarray.o
#   CC       tattr.o
#   CC       tchecksum.o
#   CC       tconfig.o
#   CC       tfile.o
#   CC       tgenprop.o
#   CC       th5o.o
#   CC       th5s.o
#   CC       tcoords.o
#   CC       theap.o
#   CC       tid.o
#   CC       titerate.o
#   CC       tmeta.o
#   CC       tmisc.o
#   CC       trefer.o
#   CC       trefstr.o
#   CC       tselect.o
#   CC       tskiplist.o
#   CC       tsohm.o
#   CC       ttime.o
#   CC       tunicode.o
#   CC       tvlstr.o
#   CC       tvltypes.o
#   CCLD     testhdf5
#   CC       cache.o
#   CCLD     cache
#   CC       cache_api.o
#   CCLD     cache_api
#   CC       cache_image.o
#   CC       genall5.o
#   CCLD     cache_image
#   CC       cache_tagging.o
#   CCLD     cache_tagging
#   CC       lheap.o
#   CCLD     lheap
#   CC       ohdr.o
#   CCLD     ohdr
#   CC       stab.o
#   CCLD     stab
#   CC       gheap.o
#   CCLD     gheap
#   CC       evict_on_close.o
#   CCLD     evict_on_close
#   CC       farray.o
#   CCLD     farray
#   CC       earray.o
#   CCLD     earray
#   CC       btree2.o
#   CCLD     btree2
#   CC       fheap.o
#   CCLD     fheap
#   CC       pool.o
#   CCLD     pool
#   CC       accum.o
#   CCLD     accum
#   CC       hyperslab.o
#   CCLD     hyperslab
#   CC       istore.o
#   CCLD     istore
#   CC       bittests.o
#   CCLD     bittests
#   CC       dt_arith.o
#   CCLD     dt_arith
#   CC       page_buffer.o
#   CCLD     page_buffer
#   CC       dtypes.o
#   CCLD     dtypes
#   CC       dsets.o
#   CCLD     dsets
#   CC       chunk_info.o
#   CCLD     chunk_info
#   CC       cmpd_dset.o
#   CCLD     cmpd_dset
#   CC       cmpd_dtransform.o
#   CCLD     cmpd_dtransform
#   CC       filter_fail.o
#   CCLD     filter_fail
#   CC       extend.o
#   CCLD     extend
#   CC       direct_chunk.o
#   CCLD     direct_chunk
#   CC       external.o
#   CCLD     external
#   CC       efc.o
#   CCLD     efc
#   CC       objcopy.o
#   CCLD     objcopy
#   CC       links.o
#   CCLD     links
#   CC       unlink.o
#   CCLD     unlink
#   CC       twriteorder.o
#   CCLD     twriteorder
#   CC       big.o
#   CCLD     big
#   CC       mtime.o
#   CCLD     mtime
#   CC       fillval.o
#   CCLD     fillval
#   CC       mount.o
#   CCLD     mount
#   CC       flush1.o
#   CCLD     flush1
#   CC       flush2.o
#   CCLD     flush2
#   CC       app_ref.o
#   CCLD     app_ref
#   CC       enum.o
#   CCLD     enum
#   CC       set_extent.o
#   CCLD     set_extent
#   CC       ttsafe.o
#   CC       ttsafe_dcreate.o
#   CC       ttsafe_error.o
#   CC       ttsafe_cancel.o
#   CC       ttsafe_acreate.o
#   CC       ttsafe_attr_vlen.o
#   CCLD     ttsafe
#   CC       enc_dec_plist.o
#   CCLD     enc_dec_plist
#   CC       enc_dec_plist_cross_platform.o
#   CCLD     enc_dec_plist_cross_platform
#   CC       getname.o
#   CCLD     getname
#   CC       vfd.o
#   CCLD     vfd
#   CC       ros3.o
#   CCLD     ros3
#   CC       s3comms.o
#   CCLD     s3comms
#   CC       hdfs.o
#   CCLD     hdfs
#   CC       ntypes.o
#   CCLD     ntypes
#   CC       dangle.o
#   CCLD     dangle
#   CC       dtransform.o
#   CCLD     dtransform
#   CC       reserved.o
#   CCLD     reserved
#   CC       cross_read.o
#   CCLD     cross_read
#   CC       freespace.o
#   CCLD     freespace
#   CC       mf.o
#   CCLD     mf
#   CC       vds.o
#   CCLD     vds
#   CC       file_image.o
#   CCLD     file_image
#   CC       unregister.o
#   CCLD     unregister
#   CC       cache_logging.o
#   CCLD     cache_logging
#   CC       cork.o
#   CCLD     cork
#   CC       swmr.o
#   CCLD     swmr
#   CC       thread_id.o
#   CCLD     thread_id
#   CC       timer.o
#   CCLD     timer
#   CC       version_bounds_1_10.o
#   CCLD     version_bounds_1_10
#   CC       error_test.o
#   CCLD     error_test
#   CC       err_compat.o
#   CCLD     err_compat
#   CC       tcheck_version.o
#   CCLD     tcheck_version
#   CC       testmeta.o
#   CCLD     testmeta
#   CC       accum_swmr_reader.o
#   CCLD     accum_swmr_reader
#   CC       atomic_writer.o
#   CCLD     atomic_writer
#   CC       atomic_reader.o
#   CCLD     atomic_reader
#   CC       external_env.o
#   CCLD     external_env
#   CC       links_env.o
#   CCLD     links_env
#   CC       filenotclosed.o
#   CCLD     filenotclosed
#   CC       del_many_dense_attrs.o
#   CCLD     del_many_dense_attrs
#   CC       flushrefresh.o
#   CCLD     flushrefresh
#   CC       use_append_chunk.o
#   CC       use_common.o
#   CCLD     use_append_chunk
#   CC       use_append_chunk_mirror.o
#   CCLD     use_append_chunk_mirror
#   CC       use_append_mchunks.o
#   CCLD     use_append_mchunks
#   CC       use_disable_mdc_flushes.o
#   CCLD     use_disable_mdc_flushes
#   CC       swmr_generator.o
#   CCLD     swmr_generator
#   CC       swmr_start_write.o
#   CCLD     swmr_start_write
#   CC       swmr_reader.o
#   CCLD     swmr_reader
#   CC       swmr_writer.o
#   CCLD     swmr_writer
#   CC       swmr_remove_reader.o
#   CCLD     swmr_remove_reader
#   CC       swmr_remove_writer.o
#   CCLD     swmr_remove_writer
#   CC       swmr_addrem_writer.o
#   CCLD     swmr_addrem_writer
#   CC       swmr_sparse_reader.o
#   CCLD     swmr_sparse_reader
#   CC       swmr_sparse_writer.o
#   CCLD     swmr_sparse_writer
#   CC       swmr_check_compat_vfd.o
#   CCLD     swmr_check_compat_vfd
#   CC       vds_env.o
#   CCLD     vds_env
#   CC       vds_swmr_gen.o
#   CCLD     vds_swmr_gen
#   CC       vds_swmr_reader.o
#   CCLD     vds_swmr_reader
#   CC       vds_swmr_writer.o
#   CCLD     vds_swmr_writer
#   CC       mirror_vfd.o
#   CCLD     mirror_vfd
#   CC       filter_plugin.o
#   CCLD     filter_plugin
# make[1]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/test'
# Making all in bin
# make[1]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/bin'
# make[1]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/bin'
# Making all in utils
# make[1]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/utils'
# Making all in mirror_vfd
# make[2]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/utils/mirror_vfd'
#   CC       mirror_server.o
#   CC       mirror_writer.o
#   CC       mirror_remote.o
#   CCLD     mirror_server
#   CC       mirror_server_stop.o
#   CCLD     mirror_server_stop
# make[2]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/utils/mirror_vfd'
# make[2]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/utils'
# make[2]: No se hace nada para 'all-am'.
# make[2]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/utils'
# make[1]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/utils'
# Making all in tools
# make[1]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools'
# Making all in lib
# make[2]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/lib'
#   CC       h5tools.lo
#   CC       h5tools_dump.lo
#   CC       h5tools_str.lo
#   CC       h5tools_utils.lo
#   CC       h5diff.lo
#   CC       h5diff_array.lo
#   CC       h5diff_attr.lo
#   CC       h5diff_dset.lo
#   CC       h5diff_util.lo
#   CC       h5trav.lo
#   CC       h5tools_filters.lo
#   CC       h5tools_ref.lo
#   CC       h5tools_type.lo
#   CC       io_timer.lo
#   CCLD     libh5tools.la
# make[2]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/lib'
# Making all in src
# make[2]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/src'
# Making all in h5diff
# make[3]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/src/h5diff'
#   CC       h5diff_main.o
#   CC       h5diff_common.o
#   CCLD     h5diff
# make[3]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/src/h5diff'
# Making all in h5ls
# make[3]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/src/h5ls'
#   CC       h5ls.o
#   CCLD     h5ls
# make[3]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/src/h5ls'
# Making all in h5dump
# make[3]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/src/h5dump'
#   CC       h5dump.o
#   CC       h5dump_ddl.o
#   CC       h5dump_xml.o
#   CCLD     h5dump
# make[3]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/src/h5dump'
# Making all in misc
# make[3]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/src/misc'
#   CC       h5debug.o
#   CCLD     h5debug
#   CC       h5repart.o
#   CCLD     h5repart
#   CC       h5mkgrp.o
#   CCLD     h5mkgrp
#   CC       h5clear.o
#   CCLD     h5clear
# make[3]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/src/misc'
# Making all in h5import
# make[3]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/src/h5import'
#   CC       h5import.o
#   CCLD     h5import
# make[3]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/src/h5import'
# Making all in h5repack
# make[3]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/src/h5repack'
#   CC       h5repack.lo
#   CC       h5repack_copy.lo
#   CC       h5repack_filters.lo
#   CC       h5repack_opttable.lo
#   CC       h5repack_parse.lo
#   CC       h5repack_refs.lo
#   CC       h5repack_verify.lo
#   CCLD     libh5repack.la
#   CC       h5repack_main.o
#   CCLD     h5repack
# make[3]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/src/h5repack'
# Making all in h5jam
# make[3]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/src/h5jam'
#   CC       h5jam.o
#   CCLD     h5jam
#   CC       h5unjam.o
#   CCLD     h5unjam
# make[3]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/src/h5jam'
# Making all in h5copy
# make[3]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/src/h5copy'
#   CC       h5copy.o
#   CCLD     h5copy
# make[3]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/src/h5copy'
# Making all in h5format_convert
# make[3]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/src/h5format_convert'
#   CC       h5format_convert.o
#   CCLD     h5format_convert
# make[3]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/src/h5format_convert'
# Making all in h5stat
# make[3]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/src/h5stat'
#   CC       h5stat.o
#   CCLD     h5stat
# make[3]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/src/h5stat'
# Making all in h5perf
# make[3]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/src/h5perf'
#   CC       sio_perf.o
#   CC       sio_engine.o
#   CCLD     h5perf_serial
# make[3]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/src/h5perf'
# make[3]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/src'
# make[3]: No se hace nada para 'all-am'.
# make[3]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/src'
# make[2]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/src'
# Making all in test
# make[2]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/test'
# Making all in h5diff
# make[3]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/test/h5diff'
#   CC       dynlib_diff.lo
#   CCLD     libdynlibdiff.la
#   CC       h5diffgentest.o
#   CCLD     h5diffgentest
# make[3]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/test/h5diff'
# Making all in h5ls
# make[3]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/test/h5ls'
#   CC       dynlib_ls.lo
#   CCLD     libdynlibls.la
# make[3]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/test/h5ls'
# Making all in h5dump
# make[3]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/test/h5dump'
#   CC       dynlib_dump.lo
#   CCLD     libdynlibdump.la
#   CC       h5dumpgentest.o
#   CCLD     h5dumpgentest
#   CC       binread.o
#   CCLD     binread
# make[3]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/test/h5dump'
# Making all in misc
# make[3]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/test/misc'
# Making all in vds
# make[4]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/test/misc/vds'
#   CC       UC_1_one_dim_gen.o
#   CCLD     UC_1_one_dim_gen
#   CC       UC_2_two_dims_gen.o
#   CCLD     UC_2_two_dims_gen
#   CC       UC_3_gaps_gen.o
#   CCLD     UC_3_gaps_gen
#   CC       UC_4_printf_gen.o
#   CCLD     UC_4_printf_gen
#   CC       UC_5_stride_gen.o
#   CCLD     UC_5_stride_gen
# make[4]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/test/misc/vds'
# make[4]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/test/misc'
#   CC       h5repart_gentest.o
#   CCLD     h5repart_gentest
#   CC       h5clear_gentest.o
#   CCLD     h5clear_gentest
#   CC       talign.o
#   CCLD     talign
#   CC       repart_test.o
#   CCLD     repart_test
#   CC       clear_open_chk.o
#   CCLD     clear_open_chk
# make[4]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/test/misc'
# make[3]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/test/misc'
# Making all in h5import
# make[3]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/test/h5import'
#   CC       h5importtest.o
#   CCLD     h5importtest
# make[3]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/test/h5import'
# Making all in h5repack
# make[3]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/test/h5repack'
#   CC       dynlib_rpk.lo
#   CCLD     libdynlibadd.la
#   CC       dynlib_vrpk.lo
#   CCLD     libdynlibvers.la
#   CC       h5repacktst.o
#   CCLD     h5repacktst
#   CC       testh5repack_detect_szip.o
#   CCLD     testh5repack_detect_szip
#   CC       h5repackgentest.o
#   CCLD     h5repackgentest
# make[3]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/test/h5repack'
# Making all in h5jam
# make[3]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/test/h5jam'
#   CC       tellub.o
#   CCLD     tellub
#   CC       h5jamgentest.o
#   CCLD     h5jamgentest
#   CC       getub.o
#   CCLD     getub
# make[3]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/test/h5jam'
# Making all in h5copy
# make[3]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/test/h5copy'
#   CC       h5copygentest.o
#   CCLD     h5copygentest
# make[3]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/test/h5copy'
# Making all in h5format_convert
# make[3]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/test/h5format_convert'
#   CC       h5fc_gentest.o
#   CCLD     h5fc_gentest
#   CC       h5fc_chk_idx.o
#   CCLD     h5fc_chk_idx
# make[3]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/test/h5format_convert'
# Making all in h5stat
# make[3]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/test/h5stat'
#   CC       h5stat_gentest.o
#   CCLD     h5stat_gentest
# make[3]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/test/h5stat'
# Making all in perform
# make[3]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/test/perform'
#   CC       iopipe.o
#   CCLD     iopipe
#   CC       chunk.o
#   CCLD     chunk
#   CC       chunk_cache.o
#   CCLD     chunk_cache
#   CC       overhead.o
#   CCLD     overhead
#   CC       zip_perf.o
#   CCLD     zip_perf
#   CC       perf_meta.o
#   CCLD     perf_meta
# make[3]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/test/perform'
# make[3]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/test'
# make[3]: No se hace nada para 'all-am'.
# make[3]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/test'
# make[2]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/test'
# Making all in libtest
# make[2]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/libtest'
#   CC       h5tools_test_utils.o
#   CCLD     h5tools_test_utils
# make[2]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/libtest'
# make[2]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools'
# make[2]: No se hace nada para 'all-am'.
# make[2]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools'
# make[1]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools'
# Making all in .
# make[1]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8'
# make[1]: No se hace nada para 'all-am'.
# make[1]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8'
# Making all in fortran
# make[1]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/fortran'
# Making all in src
# make[2]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/fortran/src'
#   CC       H5match_types.o
#   CCLD     H5match_types
# ./H5match_types
# make  all-am
# make[3]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/fortran/src'
#   PPFC     H5fortran_types.lo
# libtool: compile:  ifort -I. -I../../src -stand:f03 -free -warn:all -O3 -I../../src -I../../fortran/src -c H5fortran_types.F90  -fPIC -o .libs/H5fortran_types.o
# libtool: compile:  ifort -I. -I../../src -stand:f03 -free -warn:all -O3 -I../../src -I../../fortran/src -c H5fortran_types.F90 -o H5fortran_types.o >/dev/null 2>&1
#   PPFC     H5f90global.lo
# libtool: compile:  ifort -I. -I../../src -stand:f03 -free -warn:all -O3 -I../../src -I../../fortran/src -c H5f90global.F90  -fPIC -o .libs/H5f90global.o
# libtool: compile:  ifort -I. -I../../src -stand:f03 -free -warn:all -O3 -I../../src -I../../fortran/src -c H5f90global.F90 -o H5f90global.o >/dev/null 2>&1
#   PPFC     H5Fff.lo
# libtool: compile:  ifort -I. -I../../src -stand:f03 -free -warn:all -O3 -I../../src -I../../fortran/src -c H5Fff.F90  -fPIC -o .libs/H5Fff.o
# libtool: compile:  ifort -I. -I../../src -stand:f03 -free -warn:all -O3 -I../../src -I../../fortran/src -c H5Fff.F90 -o H5Fff.o >/dev/null 2>&1
#   PPFC     H5_ff.lo
# libtool: compile:  ifort -I. -I../../src -stand:f03 -free -warn:all -O3 -I../../src -I../../fortran/src -c H5_ff.F90  -fPIC -o .libs/H5_ff.o
# libtool: compile:  ifort -I. -I../../src -stand:f03 -free -warn:all -O3 -I../../src -I../../fortran/src -c H5_ff.F90 -o H5_ff.o >/dev/null 2>&1
#   PPFC     H5Aff.lo
# libtool: compile:  ifort -I. -I../../src -stand:f03 -free -warn:all -O3 -I../../src -I../../fortran/src -c H5Aff.F90  -fPIC -o .libs/H5Aff.o
# libtool: compile:  ifort -I. -I../../src -stand:f03 -free -warn:all -O3 -I../../src -I../../fortran/src -c H5Aff.F90 -o H5Aff.o >/dev/null 2>&1
#   PPFC     H5Dff.lo
# libtool: compile:  ifort -I. -I../../src -stand:f03 -free -warn:all -O3 -I../../src -I../../fortran/src -c H5Dff.F90  -fPIC -o .libs/H5Dff.o
# libtool: compile:  ifort -I. -I../../src -stand:f03 -free -warn:all -O3 -I../../src -I../../fortran/src -c H5Dff.F90 -o H5Dff.o >/dev/null 2>&1
#   PPFC     H5Eff.lo
# libtool: compile:  ifort -I. -I../../src -stand:f03 -free -warn:all -O3 -I../../src -I../../fortran/src -c H5Eff.F90  -fPIC -o .libs/H5Eff.o
# libtool: compile:  ifort -I. -I../../src -stand:f03 -free -warn:all -O3 -I../../src -I../../fortran/src -c H5Eff.F90 -o H5Eff.o >/dev/null 2>&1
#   PPFC     H5Gff.lo
# libtool: compile:  ifort -I. -I../../src -stand:f03 -free -warn:all -O3 -I../../src -I../../fortran/src -c H5Gff.F90  -fPIC -o .libs/H5Gff.o
# libtool: compile:  ifort -I. -I../../src -stand:f03 -free -warn:all -O3 -I../../src -I../../fortran/src -c H5Gff.F90 -o H5Gff.o >/dev/null 2>&1
#   PPFC     H5Iff.lo
# libtool: compile:  ifort -I. -I../../src -stand:f03 -free -warn:all -O3 -I../../src -I../../fortran/src -c H5Iff.F90  -fPIC -o .libs/H5Iff.o
# libtool: compile:  ifort -I. -I../../src -stand:f03 -free -warn:all -O3 -I../../src -I../../fortran/src -c H5Iff.F90 -o H5Iff.o >/dev/null 2>&1
#   PPFC     H5Lff.lo
# libtool: compile:  ifort -I. -I../../src -stand:f03 -free -warn:all -O3 -I../../src -I../../fortran/src -c H5Lff.F90  -fPIC -o .libs/H5Lff.o
# libtool: compile:  ifort -I. -I../../src -stand:f03 -free -warn:all -O3 -I../../src -I../../fortran/src -c H5Lff.F90 -o H5Lff.o >/dev/null 2>&1
#   PPFC     H5Off.lo
# libtool: compile:  ifort -I. -I../../src -stand:f03 -free -warn:all -O3 -I../../src -I../../fortran/src -c H5Off.F90  -fPIC -o .libs/H5Off.o
# libtool: compile:  ifort -I. -I../../src -stand:f03 -free -warn:all -O3 -I../../src -I../../fortran/src -c H5Off.F90 -o H5Off.o >/dev/null 2>&1
#   PPFC     H5fortkit.lo
# libtool: compile:  ifort -I. -I../../src -stand:f03 -free -warn:all -O3 -I../../src -I../../fortran/src -c H5fortkit.F90  -fPIC -o .libs/H5fortkit.o
# libtool: compile:  ifort -I. -I../../src -stand:f03 -free -warn:all -O3 -I../../src -I../../fortran/src -c H5fortkit.F90 -o H5fortkit.o >/dev/null 2>&1
#   PPFC     H5Pff.lo
# libtool: compile:  ifort -I. -I../../src -stand:f03 -free -warn:all -O3 -I../../src -I../../fortran/src -c H5Pff.F90  -fPIC -o .libs/H5Pff.o
# libtool: compile:  ifort -I. -I../../src -stand:f03 -free -warn:all -O3 -I../../src -I../../fortran/src -c H5Pff.F90 -o H5Pff.o >/dev/null 2>&1
#   PPFC     H5Rff.lo
# libtool: compile:  ifort -I. -I../../src -stand:f03 -free -warn:all -O3 -I../../src -I../../fortran/src -c H5Rff.F90  -fPIC -o .libs/H5Rff.o
# libtool: compile:  ifort -I. -I../../src -stand:f03 -free -warn:all -O3 -I../../src -I../../fortran/src -c H5Rff.F90 -o H5Rff.o >/dev/null 2>&1
#   PPFC     H5Sff.lo
# libtool: compile:  ifort -I. -I../../src -stand:f03 -free -warn:all -O3 -I../../src -I../../fortran/src -c H5Sff.F90  -fPIC -o .libs/H5Sff.o
# libtool: compile:  ifort -I. -I../../src -stand:f03 -free -warn:all -O3 -I../../src -I../../fortran/src -c H5Sff.F90 -o H5Sff.o >/dev/null 2>&1
#   PPFC     H5Tff.lo
# libtool: compile:  ifort -I. -I../../src -stand:f03 -free -warn:all -O3 -I../../src -I../../fortran/src -c H5Tff.F90  -fPIC -o .libs/H5Tff.o
# libtool: compile:  ifort -I. -I../../src -stand:f03 -free -warn:all -O3 -I../../src -I../../fortran/src -c H5Tff.F90 -o H5Tff.o >/dev/null 2>&1
#   PPFC     H5Zff.lo
# libtool: compile:  ifort -I. -I../../src -stand:f03 -free -warn:all -O3 -I../../src -I../../fortran/src -c H5Zff.F90  -fPIC -o .libs/H5Zff.o
# libtool: compile:  ifort -I. -I../../src -stand:f03 -free -warn:all -O3 -I../../src -I../../fortran/src -c H5Zff.F90 -o H5Zff.o >/dev/null 2>&1
# ifort  -I. -I../../src     -stand:f03 -free -warn:all    -O3 -I../../src -I../../fortran/src  -c -o H5_buildiface.o H5_buildiface.F90
#   FCLD     H5_buildiface
# ./H5_buildiface
#   PPFC     H5_gen.lo
# libtool: compile:  ifort -I. -I../../src -stand:f03 -free -warn:all -O3 -I../../src -I../../fortran/src -c H5_gen.F90  -fPIC -o .libs/H5_gen.o
# libtool: compile:  ifort -I. -I../../src -stand:f03 -free -warn:all -O3 -I../../src -I../../fortran/src -c H5_gen.F90 -o H5_gen.o >/dev/null 2>&1
#   CC       H5f90kit.lo
#   CC       H5_f.lo
#   CC       H5Af.lo
#   CC       H5Df.lo
#   CC       H5Ef.lo
#   CC       H5Ff.lo
#   CC       H5Gf.lo
#   CC       H5If.lo
#   CC       H5Lf.lo
#   CC       H5Of.lo
#   CC       H5Pf.lo
#   CC       H5Rf.lo
#   CC       H5Sf.lo
#   CC       H5Tf.lo
#   CC       H5Zf.lo
#   PPFC     HDF5.lo
# libtool: compile:  ifort -I. -I../../src -stand:f03 -free -warn:all -O3 -I../../src -I../../fortran/src -c HDF5.F90  -fPIC -o .libs/HDF5.o
# libtool: compile:  ifort -I. -I../../src -stand:f03 -free -warn:all -O3 -I../../src -I../../fortran/src -c HDF5.F90 -o HDF5.o >/dev/null 2>&1
#   FCLD     libhdf5_fortran.la
# make[3]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/fortran/src'
# make[2]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/fortran/src'
# Making all in test
# make[2]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/fortran/test'
# ifort  -I. -I../../src -I../../fortran/src     -stand:f03 -free -warn:all    -O3 -I../../fortran/src -I../../fortran/src  -c -o H5_test_buildiface.o H5_test_buildiface.F90
#   FCLD     H5_test_buildiface
# ./H5_test_buildiface
#   PPFC     tf_gen.lo
# libtool: compile:  ifort -I. -I../../src -I../../fortran/src -stand:f03 -free -warn:all -O3 -I../../fortran/src -I../../fortran/src -c tf_gen.F90  -fPIC -o .libs/tf_gen.o
# libtool: compile:  ifort -I. -I../../src -I../../fortran/src -stand:f03 -free -warn:all -O3 -I../../fortran/src -I../../fortran/src -c tf_gen.F90 -o tf_gen.o >/dev/null 2>&1
#   PPFC     tf.lo
# libtool: compile:  ifort -I. -I../../src -I../../fortran/src -stand:f03 -free -warn:all -O3 -I../../fortran/src -I../../fortran/src -c tf.F90  -fPIC -o .libs/tf.o
# libtool: compile:  ifort -I. -I../../src -I../../fortran/src -stand:f03 -free -warn:all -O3 -I../../fortran/src -I../../fortran/src -c tf.F90 -o tf.o >/dev/null 2>&1
#   CC       t.lo
#   FCLD     libh5test_fortran.la
# ifort  -I. -I../../src -I../../fortran/src     -stand:f03 -free -warn:all    -O3 -I../../fortran/src -I../../fortran/src  -c -o tH5F.o tH5F.F90
# ifort  -I. -I../../src -I../../fortran/src     -stand:f03 -free -warn:all    -O3 -I../../fortran/src -I../../fortran/src  -c -o tH5D.o tH5D.F90
# ifort  -I. -I../../src -I../../fortran/src     -stand:f03 -free -warn:all    -O3 -I../../fortran/src -I../../fortran/src  -c -o tH5R.o tH5R.F90
# ifort  -I. -I../../src -I../../fortran/src     -stand:f03 -free -warn:all    -O3 -I../../fortran/src -I../../fortran/src  -c -o tH5S.o tH5S.F90
# ifort  -I. -I../../src -I../../fortran/src     -stand:f03 -free -warn:all    -O3 -I../../fortran/src -I../../fortran/src  -c -o tH5T.o tH5T.F90
# ifort  -I. -I../../src -I../../fortran/src     -stand:f03 -free -warn:all    -O3 -I../../fortran/src -I../../fortran/src  -c -o tH5VL.o tH5VL.F90
# ifort  -I. -I../../src -I../../fortran/src     -stand:f03 -free -warn:all    -O3 -I../../fortran/src -I../../fortran/src  -c -o tH5Z.o tH5Z.F90
# ifort  -I. -I../../src -I../../fortran/src     -stand:f03 -free -warn:all    -O3 -I../../fortran/src -I../../fortran/src  -c -o tH5Sselect.o tH5Sselect.F90
# ifort  -I. -I../../src -I../../fortran/src     -stand:f03 -free -warn:all    -O3 -I../../fortran/src -I../../fortran/src  -c -o tH5P.o tH5P.F90
# ifort  -I. -I../../src -I../../fortran/src     -stand:f03 -free -warn:all    -O3 -I../../fortran/src -I../../fortran/src  -c -o tH5A.o tH5A.F90
# ifort  -I. -I../../src -I../../fortran/src     -stand:f03 -free -warn:all    -O3 -I../../fortran/src -I../../fortran/src  -c -o tH5I.o tH5I.F90
# ifort  -I. -I../../src -I../../fortran/src     -stand:f03 -free -warn:all    -O3 -I../../fortran/src -I../../fortran/src  -c -o tH5G.o tH5G.F90
# ifort  -I. -I../../src -I../../fortran/src     -stand:f03 -free -warn:all    -O3 -I../../fortran/src -I../../fortran/src  -c -o tH5E.o tH5E.F90
# ifort  -I. -I../../src -I../../fortran/src     -stand:f03 -free -warn:all    -O3 -I../../fortran/src -I../../fortran/src  -c -o tHDF5.o tHDF5.F90
# ifort  -I. -I../../src -I../../fortran/src     -stand:f03 -free -warn:all    -O3 -I../../fortran/src -I../../fortran/src  -c -o fortranlib_test.o fortranlib_test.F90
#   FCLD     fortranlib_test
# ifort  -I. -I../../src -I../../fortran/src     -stand:f03 -free -warn:all    -O3 -I../../fortran/src -I../../fortran/src  -c -o fflush1.o fflush1.F90
#   FCLD     fflush1
# ifort  -I. -I../../src -I../../fortran/src     -stand:f03 -free -warn:all    -O3 -I../../fortran/src -I../../fortran/src  -c -o fflush2.o fflush2.F90
#   FCLD     fflush2
# ifort  -I. -I../../src -I../../fortran/src     -stand:f03 -free -warn:all    -O3 -I../../fortran/src -I../../fortran/src  -c -o tH5O.o tH5O.F90
# ifort  -I. -I../../src -I../../fortran/src     -stand:f03 -free -warn:all    -O3 -I../../fortran/src -I../../fortran/src  -c -o tH5A_1_8.o tH5A_1_8.F90
# ifort  -I. -I../../src -I../../fortran/src     -stand:f03 -free -warn:all    -O3 -I../../fortran/src -I../../fortran/src  -c -o tH5G_1_8.o tH5G_1_8.F90
# ifort  -I. -I../../src -I../../fortran/src     -stand:f03 -free -warn:all    -O3 -I../../fortran/src -I../../fortran/src  -c -o tH5MISC_1_8.o tH5MISC_1_8.F90
# ifort  -I. -I../../src -I../../fortran/src     -stand:f03 -free -warn:all    -O3 -I../../fortran/src -I../../fortran/src  -c -o tHDF5_1_8.o tHDF5_1_8.F90
# ifort  -I. -I../../src -I../../fortran/src     -stand:f03 -free -warn:all    -O3 -I../../fortran/src -I../../fortran/src  -c -o fortranlib_test_1_8.o fortranlib_test_1_8.F90
#   FCLD     fortranlib_test_1_8
# ifort  -I. -I../../src -I../../fortran/src     -stand:f03 -free -warn:all    -O3 -I../../fortran/src -I../../fortran/src  -c -o tH5E_F03.o tH5E_F03.F90
# ifort  -I. -I../../src -I../../fortran/src     -stand:f03 -free -warn:all    -O3 -I../../fortran/src -I../../fortran/src  -c -o tH5F_F03.o tH5F_F03.F90
# ifort  -I. -I../../src -I../../fortran/src     -stand:f03 -free -warn:all    -O3 -I../../fortran/src -I../../fortran/src  -c -o tH5L_F03.o tH5L_F03.F90
# ifort  -I. -I../../src -I../../fortran/src     -stand:f03 -free -warn:all    -O3 -I../../fortran/src -I../../fortran/src  -c -o tH5O_F03.o tH5O_F03.F90
# ifort  -I. -I../../src -I../../fortran/src     -stand:f03 -free -warn:all    -O3 -I../../fortran/src -I../../fortran/src  -c -o tH5P_F03.o tH5P_F03.F90
# ifort  -I. -I../../src -I../../fortran/src     -stand:f03 -free -warn:all    -O3 -I../../fortran/src -I../../fortran/src  -c -o tH5T_F03.o tH5T_F03.F90
# ifort  -I. -I../../src -I../../fortran/src     -stand:f03 -free -warn:all    -O3 -I../../fortran/src -I../../fortran/src  -c -o tHDF5_F03.o tHDF5_F03.F90
# ifort  -I. -I../../src -I../../fortran/src     -stand:f03 -free -warn:all    -O3 -I../../fortran/src -I../../fortran/src  -c -o fortranlib_test_F03.o fortranlib_test_F03.F90
#   FCLD     fortranlib_test_F03
# make[2]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/fortran/test'
# make[2]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/fortran'
# make[2]: No se hace nada para 'all-am'.
# make[2]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/fortran'
# make[1]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/fortran'
# Making all in hl
# make[1]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/hl'
# Making all in src
# make[2]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/hl/src'
#   CC       H5DO.lo
#   CC       H5DS.lo
#   CC       H5IM.lo
#   CC       H5LT.lo
#   CC       H5LTanalyze.lo
#   CC       H5LTparse.lo
#   CC       H5PT.lo
#   CC       H5TB.lo
#   CC       H5LD.lo
#   CCLD     libhdf5_hl.la
# make[2]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/hl/src'
# Making all in test
# make[2]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/hl/test'
#   CC       test_lite.o
#   CCLD     test_lite
#   CC       test_image.o
#   CCLD     test_image
#   CC       test_file_image.o
#   CCLD     test_file_image
#   CC       test_table.o
#   CCLD     test_table
#   CC       test_ds.o
#   CCLD     test_ds
#   CC       test_packet.o
#   CC       test_packet_vlen.o
#   CCLD     test_packet
#   CC       test_ld.o
#   CCLD     test_ld
#   CC       test_dset_append.o
#   CCLD     test_dset_append
#   CC       test_h5do_compat.o
#   CCLD     test_h5do_compat
# make[2]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/hl/test'
# Making all in fortran
# make[2]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/hl/fortran'
# Making all in src
# make[3]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/hl/fortran/src'
#   CC       H5DSfc.lo
#   CC       H5LTfc.lo
#   CC       H5IMfc.lo
#   CC       H5IMcc.lo
#   CC       H5TBfc.lo
#   PPFC     H5DSff.lo
# libtool: compile:  ifort -I. -I../../../src -I../../../fortran/src -stand:f03 -free -warn:all -O3 -I../../../fortran/src -I../../../fortran/src -c H5DSff.F90  -fPIC -o .libs/H5DSff.o
# libtool: compile:  ifort -I. -I../../../src -I../../../fortran/src -stand:f03 -free -warn:all -O3 -I../../../fortran/src -I../../../fortran/src -c H5DSff.F90 -o H5DSff.o >/dev/null 2>&1
#   PPFC     H5LTff.lo
# libtool: compile:  ifort -I. -I../../../src -I../../../fortran/src -stand:f03 -free -warn:all -O3 -I../../../fortran/src -I../../../fortran/src -c H5LTff.F90  -fPIC -o .libs/H5LTff.o
# libtool: compile:  ifort -I. -I../../../src -I../../../fortran/src -stand:f03 -free -warn:all -O3 -I../../../fortran/src -I../../../fortran/src -c H5LTff.F90 -o H5LTff.o >/dev/null 2>&1
#   PPFC     H5TBff.lo
# libtool: compile:  ifort -I. -I../../../src -I../../../fortran/src -stand:f03 -free -warn:all -O3 -I../../../fortran/src -I../../../fortran/src -c H5TBff.F90  -fPIC -o .libs/H5TBff.o
# libtool: compile:  ifort -I. -I../../../src -I../../../fortran/src -stand:f03 -free -warn:all -O3 -I../../../fortran/src -I../../../fortran/src -c H5TBff.F90 -o H5TBff.o >/dev/null 2>&1
#   PPFC     H5IMff.lo
# libtool: compile:  ifort -I. -I../../../src -I../../../fortran/src -stand:f03 -free -warn:all -O3 -I../../../fortran/src -I../../../fortran/src -c H5IMff.F90  -fPIC -o .libs/H5IMff.o
# libtool: compile:  ifort -I. -I../../../src -I../../../fortran/src -stand:f03 -free -warn:all -O3 -I../../../fortran/src -I../../../fortran/src -c H5IMff.F90 -o H5IMff.o >/dev/null 2>&1
# ifort  -I. -I../../../src -I../../../fortran/src     -stand:f03 -free -warn:all    -O3 -I../../../fortran/src -I../../../fortran/src  -c -o H5HL_buildiface.o H5HL_buildiface.F90
#   FCLD     H5HL_buildiface
# ./H5HL_buildiface
#   PPFC     H5LTff_gen.lo
# libtool: compile:  ifort -I. -I../../../src -I../../../fortran/src -stand:f03 -free -warn:all -O3 -I../../../fortran/src -I../../../fortran/src -c H5LTff_gen.F90  -fPIC -o .libs/H5LTff_gen.o
# libtool: compile:  ifort -I. -I../../../src -I../../../fortran/src -stand:f03 -free -warn:all -O3 -I../../../fortran/src -I../../../fortran/src -c H5LTff_gen.F90 -o H5LTff_gen.o >/dev/null 2>&1
#   PPFC     H5TBff_gen.lo
# libtool: compile:  ifort -I. -I../../../src -I../../../fortran/src -stand:f03 -free -warn:all -O3 -I../../../fortran/src -I../../../fortran/src -c H5TBff_gen.F90  -fPIC -o .libs/H5TBff_gen.o
# libtool: compile:  ifort -I. -I../../../src -I../../../fortran/src -stand:f03 -free -warn:all -O3 -I../../../fortran/src -I../../../fortran/src -c H5TBff_gen.F90 -o H5TBff_gen.o >/dev/null 2>&1
#   FCLD     libhdf5hl_fortran.la
# make[3]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/hl/fortran/src'
# Making all in test
# make[3]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/hl/fortran/test'
# ifort  -I. -I../../../src -I../../../fortran/src     -stand:f03 -free -warn:all    -O3 -I../../../fortran/src -I../../../hl/fortran/src -I../../../fortran/test -I../../../fortran/src -I../../../fortran/test -I../../../hl/fortran/src  -c -o tstds.o tstds.F90
#   FCLD     tstds
# ifort  -I. -I../../../src -I../../../fortran/src     -stand:f03 -free -warn:all    -O3 -I../../../fortran/src -I../../../hl/fortran/src -I../../../fortran/test -I../../../fortran/src -I../../../fortran/test -I../../../hl/fortran/src  -c -o tstlite.o tstlite.F90
#   FCLD     tstlite
# ifort  -I. -I../../../src -I../../../fortran/src     -stand:f03 -free -warn:all    -O3 -I../../../fortran/src -I../../../hl/fortran/src -I../../../fortran/test -I../../../fortran/src -I../../../fortran/test -I../../../hl/fortran/src  -c -o tstimage.o tstimage.F90
#   FCLD     tstimage
# ifort  -I. -I../../../src -I../../../fortran/src     -stand:f03 -free -warn:all    -O3 -I../../../fortran/src -I../../../hl/fortran/src -I../../../fortran/test -I../../../fortran/src -I../../../fortran/test -I../../../hl/fortran/src  -c -o tsttable.o tsttable.F90
#   FCLD     tsttable
# make[3]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/hl/fortran/test'
# make[3]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/hl/fortran'
# make[3]: No se hace nada para 'all-am'.
# make[3]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/hl/fortran'
# make[2]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/hl/fortran'
# make[2]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/hl'
# make[2]: No se hace nada para 'all-am'.
# make[2]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/hl'
# make[1]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/hl'
# In file included from H5.c(22):
# H5private.h(539): warning #47: incompatible redefinition of macro "LOCK_SH" (declared at line 237 of "/usr/include/x86_64-linux-gnu/bits/fcntl-linux.h")
#   #define LOCK_SH 0x01
#           ^
#
# In file included from H5.c(22):
# H5private.h(540): warning #47: incompatible redefinition of macro "LOCK_EX" (declared at line 238 of "/usr/include/x86_64-linux-gnu/bits/fcntl-linux.h")
#   #define LOCK_EX 0x02
#           ^
#
# In file included from H5.c(22):
# H5private.h(541): warning #47: incompatible redefinition of macro "LOCK_NB" (declared at line 239 of "/usr/include/x86_64-linux-gnu/bits/fcntl-linux.h")
#   #define LOCK_NB 0x04
#           ^
#
# In file included from H5.c(22):
# H5private.h(542): warning #47: incompatible redefinition of macro "LOCK_UN" (declared at line 241 of "/usr/include/x86_64-linux-gnu/bits/fcntl-linux.h")
#   #define LOCK_UN 0x08
#           ^
#
# In file included from H5Pprivate.h(24),
#                  from H5ACprivate.h(35),
#                  from H5.c(23):
# H5Ppublic.h(6252): warning #1946: trigraph detected and converted
#    *            <td>????????</td>
#                           ^
#
# In file included from H5Pprivate.h(24),
#                  from H5ACprivate.h(35),
#                  from H5.c(23):
# H5Ppublic.h(6255): warning #1946: trigraph detected and converted
#    *            <td>PPPP????</td>
#                           ^
#
# In file included from H5checksum.c(32):
# H5private.h(539): warning #47: incompatible redefinition of macro "LOCK_SH" (declared at line 237 of "/usr/include/x86_64-linux-gnu/bits/fcntl-linux.h")
#   #define LOCK_SH 0x01
#           ^
#
# In file included from H5checksum.c(32):
# H5private.h(540): warning #47: incompatible redefinition of macro "LOCK_EX" (declared at line 238 of "/usr/include/x86_64-linux-gnu/bits/fcntl-linux.h")
#   #define LOCK_EX 0x02
#           ^
#
# In file included from H5checksum.c(32):
# H5private.h(541): warning #47: incompatible redefinition of macro "LOCK_NB" (declared at line 239 of "/usr/include/x86_64-linux-gnu/bits/fcntl-linux.h")
#   #define LOCK_NB 0x04
#           ^
#
# In file included from H5checksum.c(32):
# H5private.h(542): warning #47: incompatible redefinition of macro "LOCK_UN" (declared at line 241 of "/usr/include/x86_64-linux-gnu/bits/fcntl-linux.h")
#   #define LOCK_UN 0x08
#           ^
#
# H5checksum.c(237): warning #2259: non-pointer conversion from "long" to "uint32_t={__uint32_t={unsigned int}}" may lose significant bits
#       FUNC_LEAVE_NOAPI(H5__checksum_crc_update((uint32_t)0xffffffffL, (const uint8_t *)_data, len) ^
#       ^
#
# In file included from H5dbg.c(32):
# H5private.h(539): warning #47: incompatible redefinition of macro "LOCK_SH" (declared at line 237 of "/usr/include/x86_64-linux-gnu/bits/fcntl-linux.h")
#   #define LOCK_SH 0x01
# ...
# !DEC$endif
# -----^
# H5LTff_gen.F90(4305): warning #7025: This directive is not standard F2003.
# !DEC$if defined(BUILD_HDF5_HL_DLL)
# -----^
# H5LTff_gen.F90(4307): warning #7025: This directive is not standard F2003.
# !DEC$endif
# -----^
# H5LTff_gen.F90(4322): warning #7025: This directive is not standard F2003.
# !DEC$if defined(BUILD_HDF5_HL_DLL)
# -----^
# H5LTff_gen.F90(4324): warning #7025: This directive is not standard F2003.
# !DEC$endif
# -----^
# H5LTff_gen.F90(4339): warning #7025: This directive is not standard F2003.
# !DEC$if defined(BUILD_HDF5_HL_DLL)
# -----^
# H5LTff_gen.F90(4341): warning #7025: This directive is not standard F2003.
# !DEC$endif
# -----^
# H5LTff_gen.F90(4356): warning #7025: This directive is not standard F2003.
# !DEC$if defined(BUILD_HDF5_HL_DLL)
# -----^
# H5LTff_gen.F90(4358): warning #7025: This directive is not standard F2003.
# !DEC$endif
# -----^
# H5LTff_gen.F90(4373): warning #7025: This directive is not standard F2003.
# !DEC$if defined(BUILD_HDF5_HL_DLL)
# -----^
# H5LTff_gen.F90(4375): warning #7025: This directive is not standard F2003.
# !DEC$endif
# -----^
# H5LTff_gen.F90(4390): warning #7025: This directive is not standard F2003.
# !DEC$if defined(BUILD_HDF5_HL_DLL)
# -----^
# H5LTff_gen.F90(4392): warning #7025: This directive is not standard F2003.
# !DEC$endif
# -----^
# H5LTff_gen.F90(4407): warning #7025: This directive is not standard F2003.
# !DEC$if defined(BUILD_HDF5_HL_DLL)
# -----^
# H5LTff_gen.F90(4409): warning #7025: This directive is not standard F2003.
# !DEC$endif
# -----^
# H5LTff_gen.F90(4424): warning #7025: This directive is not standard F2003.
# !DEC$if defined(BUILD_HDF5_HL_DLL)
# -----^
# H5LTff_gen.F90(4426): warning #7025: This directive is not standard F2003.
# !DEC$endif
# -----^
# H5LTff_gen.F90(4441): warning #7025: This directive is not standard F2003.
# !DEC$if defined(BUILD_HDF5_HL_DLL)
# -----^
# H5LTff_gen.F90(4443): warning #7025: This directive is not standard F2003.
# !DEC$endif
# -----^
# H5LTff_gen.F90(4458): warning #7025: This directive is not standard F2003.
# !DEC$if defined(BUILD_HDF5_HL_DLL)
# -----^
# H5LTff_gen.F90(4460): warning #7025: This directive is not standard F2003.
# !DEC$endif
# -----^
# H5LTff_gen.F90(4475): warning #7025: This directive is not standard F2003.
# !DEC$if defined(BUILD_HDF5_HL_DLL)
# -----^
# H5LTff_gen.F90(4477): warning #7025: This directive is not standard F2003.
# !DEC$endif
# -----^
# H5LTff_gen.F90(4493): warning #7025: This directive is not standard F2003.
# !DEC$if defined(BUILD_HDF5_HL_DLL)
# -----^
# H5LTff_gen.F90(4495): warning #7025: This directive is not standard F2003.
# !DEC$endif
# -----^
# H5LTff_gen.F90(4511): warning #7025: This directive is not standard F2003.
# !DEC$if defined(BUILD_HDF5_HL_DLL)
# -----^
# H5LTff_gen.F90(4513): warning #7025: This directive is not standard F2003.
# !DEC$endif
# -----^
# H5LTff_gen.F90(4529): warning #7025: This directive is not standard F2003.
# !DEC$if defined(BUILD_HDF5_HL_DLL)
# -----^
# H5LTff_gen.F90(4531): warning #7025: This directive is not standard F2003.
# !DEC$endif
# -----^
# H5LTff_gen.F90(4547): warning #7025: This directive is not standard F2003.
# !DEC$if defined(BUILD_HDF5_HL_DLL)
# -----^
# H5LTff_gen.F90(4549): warning #7025: This directive is not standard F2003.
# !DEC$endif
# -----^
# H5LTff_gen.F90(4565): warning #7025: This directive is not standard F2003.
# !DEC$if defined(BUILD_HDF5_HL_DLL)
# -----^
# H5LTff_gen.F90(4567): warning #7025: This directive is not standard F2003.
# !DEC$endif
# -----^
# H5LTff_gen.F90(4583): warning #7025: This directive is not standard F2003.
# !DEC$if defined(BUILD_HDF5_HL_DLL)
# -----^
# H5LTff_gen.F90(4585): warning #7025: This directive is not standard F2003.
# !DEC$endif
# -----^
# H5LTff_gen.F90(4601): warning #7025: This directive is not standard F2003.
# !DEC$if defined(BUILD_HDF5_HL_DLL)
# -----^
# H5LTff_gen.F90(4603): warning #7025: This directive is not standard F2003.
# !DEC$endif
# -----^
# H5LTff_gen.F90(4619): warning #7025: This directive is not standard F2003.
# !DEC$if defined(BUILD_HDF5_HL_DLL)
# -----^
# H5LTff_gen.F90(4621): warning #7025: This directive is not standard F2003.
# !DEC$endif
# -----^
# H5LTff_gen.F90(4637): warning #7025: This directive is not standard F2003.
# !DEC$if defined(BUILD_HDF5_HL_DLL)
# -----^
# H5LTff_gen.F90(4639): warning #7025: This directive is not standard F2003.
# !DEC$endif
# -----^
# H5LTff_gen.F90(4655): warning #7025: This directive is not standard F2003.
# !DEC$if defined(BUILD_HDF5_HL_DLL)
# -----^
# H5LTff_gen.F90(4657): warning #7025: This directive is not standard F2003.
# !DEC$endif
# -----^
# H5LTff_gen.F90(4673): warning #7025: This directive is not standard F2003.
# !DEC$if defined(BUILD_HDF5_HL_DLL)
# -----^
# H5LTff_gen.F90(4675): warning #7025: This directive is not standard F2003.
# !DEC$endif
# -----^
# H5LTff_gen.F90(4691): warning #7025: This directive is not standard F2003.
# !DEC$if defined(BUILD_HDF5_HL_DLL)
# -----^
# H5LTff_gen.F90(4693): warning #7025: This directive is not standard F2003.
# !DEC$endif
# -----^
# H5LTff_gen.F90(4709): warning #7025: This directive is not standard F2003.
# !DEC$if defined(BUILD_HDF5_HL_DLL)
# -----^
# H5LTff_gen.F90(4711): warning #7025: This directive is not standard F2003.
# !DEC$endif
# -----^
# H5LTff_gen.F90(4727): warning #7025: This directive is not standard F2003.
# !DEC$if defined(BUILD_HDF5_HL_DLL)
# -----^
# H5LTff_gen.F90(4729): warning #7025: This directive is not standard F2003.
# !DEC$endif
# -----^
# H5LTff_gen.F90(4745): warning #7025: This directive is not standard F2003.
# !DEC$if defined(BUILD_HDF5_HL_DLL)
# -----^
# H5LTff_gen.F90(4747): warning #7025: This directive is not standard F2003.
# !DEC$endif
# -----^
# H5LTff_gen.F90(4763): warning #7025: This directive is not standard F2003.
# !DEC$if defined(BUILD_HDF5_HL_DLL)
# -----^
# H5LTff_gen.F90(4765): warning #7025: This directive is not standard F2003.
# !DEC$endif
# -----^
# H5LTff_gen.F90(4781): warning #7025: This directive is not standard F2003.
# !DEC$if defined(BUILD_HDF5_HL_DLL)
# -----^
# H5LTff_gen.F90(4783): warning #7025: This directive is not standard F2003.
# !DEC$endif
# -----^
# H5LTff_gen.F90(4799): warning #7025: This directive is not standard F2003.
# !DEC$if defined(BUILD_HDF5_HL_DLL)
# -----^
# H5LTff_gen.F90(4801): warning #7025: This directive is not standard F2003.
# !DEC$endif
# -----^
# H5LTff_gen.F90(4817): warning #7025: This directive is not standard F2003.
# !DEC$if defined(BUILD_HDF5_HL_DLL)
# -----^
# H5LTff_gen.F90(4819): warning #7025: This directive is not standard F2003.
# !DEC$endif
# -----^
# H5LTff_gen.F90(4835): warning #7025: This directive is not standard F2003.
# !DEC$if defined(BUILD_HDF5_HL_DLL)
# -----^
# H5LTff_gen.F90(4837): warning #7025: This directive is not standard F2003.
# !DEC$endif
# -----^
# H5LTff_gen.F90(4853): warning #7025: This directive is not standard F2003.
# !DEC$if defined(BUILD_HDF5_HL_DLL)
# -----^
# H5LTff_gen.F90(4855): warning #7025: This directive is not standard F2003.
# !DEC$endif
# -----^
# H5LTff_gen.F90(4871): warning #7025: This directive is not standard F2003.
# !DEC$if defined(BUILD_HDF5_HL_DLL)
# -----^
# H5LTff_gen.F90(4873): warning #7025: This directive is not standard F2003.
# !DEC$endif
# -----^
# H5LTff_gen.F90(4889): warning #7025: This directive is not standard F2003.
# !DEC$if defined(BUILD_HDF5_HL_DLL)
# -----^
# H5LTff_gen.F90(4891): warning #7025: This directive is not standard F2003.
# !DEC$endif
# -----^
# H5LTff_gen.F90(4907): warning #7025: This directive is not standard F2003.
# !DEC$if defined(BUILD_HDF5_HL_DLL)
# -----^
# H5LTff_gen.F90(4909): warning #7025: This directive is not standard F2003.
# !DEC$endif
# -----^
# H5LTff_gen.F90(4925): warning #7025: This directive is not standard F2003.
# !DEC$if defined(BUILD_HDF5_HL_DLL)
# -----^
# H5LTff_gen.F90(4927): warning #7025: This directive is not standard F2003.
# !DEC$endif
# -----^
# H5LTff_gen.F90(4943): warning #7025: This directive is not standard F2003.
# !DEC$if defined(BUILD_HDF5_HL_DLL)
# -----^
# H5LTff_gen.F90(4945): warning #7025: This directive is not standard F2003.
# !DEC$endif
# -----^
# H5LTff_gen.F90(4961): warning #7025: This directive is not standard F2003.
# !DEC$if defined(BUILD_HDF5_HL_DLL)
# -----^
# H5LTff_gen.F90(4963): warning #7025: This directive is not standard F2003.
# !DEC$endif
# -----^
# H5LTff_gen.F90(4979): warning #7025: This directive is not standard F2003.
# !DEC$if defined(BUILD_HDF5_HL_DLL)
# -----^
# H5LTff_gen.F90(4981): warning #7025: This directive is not standard F2003.
# !DEC$endif
# -----^
# H5LTff_gen.F90(4997): warning #7025: This directive is not standard F2003.
# !DEC$if defined(BUILD_HDF5_HL_DLL)
# -----^
# H5LTff_gen.F90(4999): warning #7025: This directive is not standard F2003.
# !DEC$endif
# -----^
# H5LTff_gen.F90(5015): warning #7025: This directive is not standard F2003.
# !DEC$if defined(BUILD_HDF5_HL_DLL)
# -----^
# H5LTff_gen.F90(5017): warning #7025: This directive is not standard F2003.
# !DEC$endif
# -----^
# H5LTff_gen.F90(5033): warning #7025: This directive is not standard F2003.
# !DEC$if defined(BUILD_HDF5_HL_DLL)
# -----^
# H5LTff_gen.F90(5035): warning #7025: This directive is not standard F2003.
# !DEC$endif
# -----^
# ifort: command line warning #10158: ignoring option '-warn'; argument must be separate
# H5TBff_gen.F90(60): warning #7025: This directive is not standard F2003.
# !DEC$if defined(BUILD_HDF5_HL_DLL)
# -----^
# H5TBff_gen.F90(62): warning #7025: This directive is not standard F2003.
# !DEC$endif
# -----^
# H5TBff_gen.F90(81): warning #7025: This directive is not standard F2003.
# !DEC$if defined(BUILD_HDF5_HL_DLL)
# -----^
# H5TBff_gen.F90(83): warning #7025: This directive is not standard F2003.
# !DEC$endif
# -----^
# H5TBff_gen.F90(102): warning #7025: This directive is not standard F2003.
# !DEC$if defined(BUILD_HDF5_HL_DLL)
# -----^
# H5TBff_gen.F90(104): warning #7025: This directive is not standard F2003.
# !DEC$endif
# -----^
# H5TBff_gen.F90(123): warning #7025: This directive is not standard F2003.
# !DEC$if defined(BUILD_HDF5_HL_DLL)
# -----^
# H5TBff_gen.F90(125): warning #7025: This directive is not standard F2003.
# !DEC$endif
# -----^
# H5TBff_gen.F90(144): warning #7025: This directive is not standard F2003.
# !DEC$if defined(BUILD_HDF5_HL_DLL)
# -----^
# H5TBff_gen.F90(146): warning #7025: This directive is not standard F2003.
# !DEC$endif
# -----^
# H5TBff_gen.F90(165): warning #7025: This directive is not standard F2003.
# !DEC$if defined(BUILD_HDF5_HL_DLL)
# -----^
# H5TBff_gen.F90(167): warning #7025: This directive is not standard F2003.
# !DEC$endif
# -----^
# H5TBff_gen.F90(186): warning #7025: This directive is not standard F2003.
# !DEC$if defined(BUILD_HDF5_HL_DLL)
# -----^
# H5TBff_gen.F90(188): warning #7025: This directive is not standard F2003.
# !DEC$endif
# -----^
# H5TBff_gen.F90(205): warning #7025: This directive is not standard F2003.
# !DEC$if defined(BUILD_HDF5_HL_DLL)
# -----^
# H5TBff_gen.F90(207): warning #7025: This directive is not standard F2003.
# !DEC$endif
# -----^
# H5TBff_gen.F90(224): warning #7025: This directive is not standard F2003.
# !DEC$if defined(BUILD_HDF5_HL_DLL)
# -----^
# H5TBff_gen.F90(226): warning #7025: This directive is not standard F2003.
# !DEC$endif
# -----^
# H5TBff_gen.F90(243): warning #7025: This directive is not standard F2003.
# !DEC$if defined(BUILD_HDF5_HL_DLL)
# -----^
# H5TBff_gen.F90(245): warning #7025: This directive is not standard F2003.
# !DEC$endif
# -----^
# H5TBff_gen.F90(262): warning #7025: This directive is not standard F2003.
# !DEC$if defined(BUILD_HDF5_HL_DLL)
# -----^
# H5TBff_gen.F90(264): warning #7025: This directive is not standard F2003.
# !DEC$endif
# -----^
# H5TBff_gen.F90(281): warning #7025: This directive is not standard F2003.
# !DEC$if defined(BUILD_HDF5_HL_DLL)
# -----^
# H5TBff_gen.F90(283): warning #7025: This directive is not standard F2003.
# !DEC$endif
# -----^
# H5TBff_gen.F90(300): warning #7025: This directive is not standard F2003.
# !DEC$if defined(BUILD_HDF5_HL_DLL)
# -----^
# H5TBff_gen.F90(302): warning #7025: This directive is not standard F2003.
# !DEC$endif
# -----^
# H5TBff_gen.F90(320): warning #7025: This directive is not standard F2003.
# !DEC$if defined(BUILD_HDF5_HL_DLL)
# -----^
# H5TBff_gen.F90(322): warning #7025: This directive is not standard F2003.
# !DEC$endif
# -----^
# H5TBff_gen.F90(340): warning #7025: This directive is not standard F2003.
# !DEC$if defined(BUILD_HDF5_HL_DLL)
# -----^
# H5TBff_gen.F90(342): warning #7025: This directive is not standard F2003.
# !DEC$endif
# -----^
# ifort: command line warning #10434: option '-nofor_main' use with underscore is deprecated; use '-nofor-main' instead
# ifort: command line warning #10158: ignoring option '-warn'; argument must be separate
# ifort: command line warning #10158: ignoring option '-warn'; argument must be separate
# ifort: command line warning #10158: ignoring option '-warn'; argument must be separate
# tstlite.F90(1790): warning #7416: Fortran 2003 does not allow this intrinsic procedure.   [STORAGE_SIZE]
#     SizeOf_buf_type = STORAGE_SIZE(buf3(1), c_size_t)/STORAGE_SIZE(c_char_'a',c_size_t)
# ----------------------^
# tstlite.F90(1790): warning #7416: Fortran 2003 does not allow this intrinsic procedure.   [STORAGE_SIZE]
#     SizeOf_buf_type = STORAGE_SIZE(buf3(1), c_size_t)/STORAGE_SIZE(c_char_'a',c_size_t)
# ------------------------------------------------------^
# tstlite.F90(1801): warning #7416: Fortran 2003 does not allow this intrinsic procedure.   [STORAGE_SIZE]
#     SizeOf_buf_type = STORAGE_SIZE(bufr3(1), c_size_t)/STORAGE_SIZE(c_char_'a',c_size_t)
# ----------------------^
# tstlite.F90(1801): warning #7416: Fortran 2003 does not allow this intrinsic procedure.   [STORAGE_SIZE]
#     SizeOf_buf_type = STORAGE_SIZE(bufr3(1), c_size_t)/STORAGE_SIZE(c_char_'a',c_size_t)
# -------------------------------------------------------^
# tstlite.F90(1829): warning #7416: Fortran 2003 does not allow this intrinsic procedure.   [STORAGE_SIZE]
#     SizeOf_buf_type = STORAGE_SIZE(buf4(1), c_size_t)/STORAGE_SIZE(c_char_'a',c_size_t)
# ----------------------^
# tstlite.F90(1829): warning #7416: Fortran 2003 does not allow this intrinsic procedure.   [STORAGE_SIZE]
#     SizeOf_buf_type = STORAGE_SIZE(buf4(1), c_size_t)/STORAGE_SIZE(c_char_'a',c_size_t)
# ------------------------------------------------------^
# tstlite.F90(1851): warning #7416: Fortran 2003 does not allow this intrinsic procedure.   [STORAGE_SIZE]
#        SizeOf_buf_type = STORAGE_SIZE(bufr4(1), c_size_t)/STORAGE_SIZE(c_char_'a',c_size_t)
# -------------------------^
# tstlite.F90(1851): warning #7416: Fortran 2003 does not allow this intrinsic procedure.   [STORAGE_SIZE]
#        SizeOf_buf_type = STORAGE_SIZE(bufr4(1), c_size_t)/STORAGE_SIZE(c_char_'a',c_size_t)
# ----------------------------------------------------------^
# ifort: command line warning #10158: ignoring option '-warn'; argument must be separate
# ifort: command line warning #10158: ignoring option '-warn'; argument must be separate
# ifort: command line warning #10158: ignoring option '-warn'; argument must be separate
# ifort: command line warning #10158: ignoring option '-warn'; argument must be separate
# tsttable.F90(561): warning #6379: The structure contains one or more misaligned fields.   [PARTICLE_T]
#   TYPE particle_t
# -------^
# tsttable.F90(104): warning #7416: Fortran 2003 does not allow this intrinsic procedure.   [STORAGE_SIZE]
#   SIZEOF_X = storage_size(bufd(1))/storage_size(c_char_'a')
# -------------^
# tsttable.F90(104): warning #7416: Fortran 2003 does not allow this intrinsic procedure.   [STORAGE_SIZE]
#   SIZEOF_X = storage_size(bufd(1))/storage_size(c_char_'a')
# -----------------------------------^
# ifort: command line warning #10158: ignoring option '-warn'; argument must be separate
# 	Command being timed: "make"
# 	User time (seconds): 515.22
# 	System time (seconds): 70.41
# 	Percent of CPU this job got: 97%
# 	Elapsed (wall clock) time (h:mm:ss or m:ss): 10:03.17
# 	Average shared text size (kbytes): 0
# 	Average unshared data size (kbytes): 0
# 	Average stack size (kbytes): 0
# 	Average total size (kbytes): 0
# 	Maximum resident set size (kbytes): 972812
# 	Average resident set size (kbytes): 0
# 	Major (requiring I/O) page faults: 0
# 	Minor (reclaiming a frame) page faults: 18952351
# 	Voluntary context switches: 154487
# 	Involuntary context switches: 8968
# 	Swaps: 0
# 	File system inputs: 102864
# 	File system outputs: 789544
# 	Socket messages sent: 0
# 	Socket messages received: 0
# 	Signals delivered: 0
# 	Page size (bytes): 4096
# 	Exit status: 0

# %%
# %%bash -l
# pwd
# SETVARS_ARGS="--config=/opt/software/apps/intel/oneapi/config.txt"
# source /opt/software/apps/intel/oneapi/setvars.sh
# cd build/hdf5-1.10.8
# make install
# Out:
# /LUSTRE/tmp/soporte/compila-WRF
#
# :: initializing oneAPI environment ...
#    bash: BASH_VERSION = 5.1.4(1)-release
#    args: Using "SETVARS_ARGS" for setvars.sh arguments: --config=/opt/software/apps/intel/oneapi/config.txt
# :: compiler -- latest
# :: mpi -- latest
# :: oneAPI environment initialized ::
#
# Making install in src
# make[1]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/src'
# make[2]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/src'
#  /usr/bin/mkdir -p '/home/soporte/tmp/2022/wrf/lib'
#  /bin/bash ../libtool   --mode=install /usr/bin/install -c   libhdf5.la '/home/soporte/tmp/2022/wrf/lib'
# libtool: install: /usr/bin/install -c .libs/libhdf5.so.103.3.1 /home/soporte/tmp/2022/wrf/lib/libhdf5.so.103.3.1
# libtool: install: (cd /home/soporte/tmp/2022/wrf/lib && { ln -s -f libhdf5.so.103.3.1 libhdf5.so.103 || { rm -f libhdf5.so.103 && ln -s libhdf5.so.103.3.1 libhdf5.so.103; }; })
# libtool: install: (cd /home/soporte/tmp/2022/wrf/lib && { ln -s -f libhdf5.so.103.3.1 libhdf5.so || { rm -f libhdf5.so && ln -s libhdf5.so.103.3.1 libhdf5.so; }; })
# libtool: install: /usr/bin/install -c .libs/libhdf5.lai /home/soporte/tmp/2022/wrf/lib/libhdf5.la
# libtool: install: /usr/bin/install -c .libs/libhdf5.a /home/soporte/tmp/2022/wrf/lib/libhdf5.a
# libtool: install: chmod 644 /home/soporte/tmp/2022/wrf/lib/libhdf5.a
# libtool: install: ranlib /home/soporte/tmp/2022/wrf/lib/libhdf5.a
# libtool: finish: PATH="/opt/software/apps/intel/oneapi/mpi/2021.5.1//libfabric/bin:/opt/software/apps/intel/oneapi/mpi/2021.5.1//bin:/opt/software/apps/intel/oneapi/compiler/2022.0.2/linux/lib/oclfpga/bin:/opt/software/apps/intel/oneapi/compiler/2022.0.2/linux/bin/intel64:/opt/software/apps/intel/oneapi/compiler/2022.0.2/linux/bin:/opt/software/apps/slurm/slurm/bin:/usr/local/bin:/usr/bin:/bin:/usr/local/games:/usr/games:/home/soporte/bin:/sbin" ldconfig -n /home/soporte/tmp/2022/wrf/lib
# ----------------------------------------------------------------------
# Libraries have been installed in:
#    /home/soporte/tmp/2022/wrf/lib
#
# If you ever happen to want to link against installed libraries
# in a given directory, LIBDIR, you must either use libtool, and
# specify the full pathname of the library, or use the '-LLIBDIR'
# flag during linking and do at least one of the following:
#    - add LIBDIR to the 'LD_LIBRARY_PATH' environment variable
#      during execution
#    - add LIBDIR to the 'LD_RUN_PATH' environment variable
#      during linking
#    - use the '-Wl,-rpath -Wl,LIBDIR' linker flag
#    - have your system administrator add LIBDIR to '/etc/ld.so.conf'
#
# See any operating system documentation about shared libraries for
# more information, such as the ld(1) and ld.so(8) manual pages.
# ----------------------------------------------------------------------
#  /usr/bin/mkdir -p '/home/soporte/tmp/2022/wrf/include'
#  /usr/bin/install -c -m 644 hdf5.h H5api_adpt.h H5overflow.h H5pubconf.h H5public.h H5version.h H5Apublic.h H5ACpublic.h H5Cpublic.h H5Dpublic.h H5Epubgen.h H5Epublic.h H5Fpublic.h H5FDpublic.h H5FDcore.h H5FDdirect.h H5FDfamily.h H5FDhdfs.h H5FDlog.h H5FDmirror.h H5FDmpi.h H5FDmpio.h H5FDmulti.h H5FDros3.h H5FDsec2.h H5FDsplitter.h H5FDstdio.h H5FDwindows.h H5Gpublic.h H5Ipublic.h H5Lpublic.h H5MMpublic.h H5Opublic.h H5Ppublic.h H5PLextern.h H5PLpublic.h H5Rpublic.h H5Spublic.h H5Tpublic.h H5Zpublic.h '/home/soporte/tmp/2022/wrf/include'
#  /usr/bin/mkdir -p '/home/soporte/tmp/2022/wrf/lib'
#  /usr/bin/install -c -m 644 libhdf5.settings '/home/soporte/tmp/2022/wrf/lib'
# make[2]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/src'
# make[1]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/src'
# Making install in test
# make[1]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/test'
# make[2]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/test'
# make[2]: No se hace nada para 'install-exec-am'.
# make[2]: No se hace nada para 'install-data-am'.
# make[2]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/test'
# make[1]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/test'
# Making install in bin
# make[1]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/bin'
# make[2]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/bin'
#  /usr/bin/mkdir -p '/home/soporte/tmp/2022/wrf/bin'
#  /usr/bin/install -c h5redeploy '/home/soporte/tmp/2022/wrf/bin'
# make[2]: No se hace nada para 'install-data-am'.
# make[2]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/bin'
# make[1]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/bin'
# Making install in utils
# make[1]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/utils'
# Making install in mirror_vfd
# make[2]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/utils/mirror_vfd'
# make[3]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/utils/mirror_vfd'
#  /usr/bin/mkdir -p '/home/soporte/tmp/2022/wrf/bin'
#   /bin/bash ../../libtool   --mode=install /usr/bin/install -c mirror_server mirror_server_stop '/home/soporte/tmp/2022/wrf/bin'
# libtool: install: /usr/bin/install -c .libs/mirror_server /home/soporte/tmp/2022/wrf/bin/mirror_server
# libtool: install: /usr/bin/install -c .libs/mirror_server_stop /home/soporte/tmp/2022/wrf/bin/mirror_server_stop
# make[3]: No se hace nada para 'install-data-am'.
# make[3]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/utils/mirror_vfd'
# make[2]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/utils/mirror_vfd'
# make[2]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/utils'
# make[3]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/utils'
# make[3]: No se hace nada para 'install-exec-am'.
# make[3]: No se hace nada para 'install-data-am'.
# make[3]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/utils'
# make[2]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/utils'
# make[1]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/utils'
# Making install in tools
# make[1]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools'
# Making install in lib
# make[2]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/lib'
# make[3]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/lib'
# make[3]: No se hace nada para 'install-exec-am'.
# make[3]: No se hace nada para 'install-data-am'.
# make[3]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/lib'
# make[2]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/lib'
# Making install in src
# make[2]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/src'
# Making install in h5diff
# make[3]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/src/h5diff'
# make[4]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/src/h5diff'
#  /usr/bin/mkdir -p '/home/soporte/tmp/2022/wrf/bin'
#   /bin/bash ../../../libtool   --mode=install /usr/bin/install -c h5diff '/home/soporte/tmp/2022/wrf/bin'
# libtool: install: /usr/bin/install -c .libs/h5diff /home/soporte/tmp/2022/wrf/bin/h5diff
# make[4]: No se hace nada para 'install-data-am'.
# make[4]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/src/h5diff'
# make[3]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/src/h5diff'
# Making install in h5ls
# make[3]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/src/h5ls'
# make[4]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/src/h5ls'
#  /usr/bin/mkdir -p '/home/soporte/tmp/2022/wrf/bin'
#   /bin/bash ../../../libtool   --mode=install /usr/bin/install -c h5ls '/home/soporte/tmp/2022/wrf/bin'
# libtool: install: /usr/bin/install -c .libs/h5ls /home/soporte/tmp/2022/wrf/bin/h5ls
# make[4]: No se hace nada para 'install-data-am'.
# make[4]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/src/h5ls'
# make[3]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/src/h5ls'
# Making install in h5dump
# make[3]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/src/h5dump'
# make[4]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/src/h5dump'
#  /usr/bin/mkdir -p '/home/soporte/tmp/2022/wrf/bin'
#   /bin/bash ../../../libtool   --mode=install /usr/bin/install -c h5dump '/home/soporte/tmp/2022/wrf/bin'
# libtool: install: /usr/bin/install -c .libs/h5dump /home/soporte/tmp/2022/wrf/bin/h5dump
# make[4]: No se hace nada para 'install-data-am'.
# make[4]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/src/h5dump'
# make[3]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/src/h5dump'
# Making install in misc
# make[3]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/src/misc'
# make[4]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/src/misc'
#  /usr/bin/mkdir -p '/home/soporte/tmp/2022/wrf/bin'
#   /bin/bash ../../../libtool   --mode=install /usr/bin/install -c h5debug h5repart h5mkgrp h5clear '/home/soporte/tmp/2022/wrf/bin'
# libtool: install: /usr/bin/install -c .libs/h5debug /home/soporte/tmp/2022/wrf/bin/h5debug
# libtool: install: /usr/bin/install -c .libs/h5repart /home/soporte/tmp/2022/wrf/bin/h5repart
# libtool: install: /usr/bin/install -c .libs/h5mkgrp /home/soporte/tmp/2022/wrf/bin/h5mkgrp
# libtool: install: /usr/bin/install -c .libs/h5clear /home/soporte/tmp/2022/wrf/bin/h5clear
# make[4]: No se hace nada para 'install-data-am'.
# make[4]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/src/misc'
# make[3]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/src/misc'
# Making install in h5import
# make[3]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/src/h5import'
# make[4]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/src/h5import'
#  /usr/bin/mkdir -p '/home/soporte/tmp/2022/wrf/bin'
#   /bin/bash ../../../libtool   --mode=install /usr/bin/install -c h5import '/home/soporte/tmp/2022/wrf/bin'
# libtool: install: /usr/bin/install -c .libs/h5import /home/soporte/tmp/2022/wrf/bin/h5import
# make[4]: No se hace nada para 'install-data-am'.
# make[4]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/src/h5import'
# make[3]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/src/h5import'
# Making install in h5repack
# make[3]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/src/h5repack'
# make[4]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/src/h5repack'
#  /usr/bin/mkdir -p '/home/soporte/tmp/2022/wrf/bin'
#   /bin/bash ../../../libtool   --mode=install /usr/bin/install -c h5repack '/home/soporte/tmp/2022/wrf/bin'
# libtool: install: /usr/bin/install -c .libs/h5repack /home/soporte/tmp/2022/wrf/bin/h5repack
# make[4]: No se hace nada para 'install-data-am'.
# make[4]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/src/h5repack'
# make[3]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/src/h5repack'
# Making install in h5jam
# make[3]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/src/h5jam'
# make[4]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/src/h5jam'
#  /usr/bin/mkdir -p '/home/soporte/tmp/2022/wrf/bin'
#   /bin/bash ../../../libtool   --mode=install /usr/bin/install -c h5jam h5unjam '/home/soporte/tmp/2022/wrf/bin'
# libtool: install: /usr/bin/install -c .libs/h5jam /home/soporte/tmp/2022/wrf/bin/h5jam
# libtool: install: /usr/bin/install -c .libs/h5unjam /home/soporte/tmp/2022/wrf/bin/h5unjam
# make[4]: No se hace nada para 'install-data-am'.
# make[4]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/src/h5jam'
# make[3]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/src/h5jam'
# Making install in h5copy
# make[3]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/src/h5copy'
# make[4]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/src/h5copy'
#  /usr/bin/mkdir -p '/home/soporte/tmp/2022/wrf/bin'
#   /bin/bash ../../../libtool   --mode=install /usr/bin/install -c h5copy '/home/soporte/tmp/2022/wrf/bin'
# libtool: install: /usr/bin/install -c .libs/h5copy /home/soporte/tmp/2022/wrf/bin/h5copy
# make[4]: No se hace nada para 'install-data-am'.
# make[4]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/src/h5copy'
# make[3]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/src/h5copy'
# Making install in h5format_convert
# make[3]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/src/h5format_convert'
# make[4]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/src/h5format_convert'
#  /usr/bin/mkdir -p '/home/soporte/tmp/2022/wrf/bin'
#   /bin/bash ../../../libtool   --mode=install /usr/bin/install -c h5format_convert '/home/soporte/tmp/2022/wrf/bin'
# libtool: install: /usr/bin/install -c .libs/h5format_convert /home/soporte/tmp/2022/wrf/bin/h5format_convert
# make[4]: No se hace nada para 'install-data-am'.
# make[4]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/src/h5format_convert'
# make[3]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/src/h5format_convert'
# Making install in h5stat
# make[3]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/src/h5stat'
# make[4]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/src/h5stat'
#  /usr/bin/mkdir -p '/home/soporte/tmp/2022/wrf/bin'
#   /bin/bash ../../../libtool   --mode=install /usr/bin/install -c h5stat '/home/soporte/tmp/2022/wrf/bin'
# libtool: install: /usr/bin/install -c .libs/h5stat /home/soporte/tmp/2022/wrf/bin/h5stat
# make[4]: No se hace nada para 'install-data-am'.
# make[4]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/src/h5stat'
# make[3]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/src/h5stat'
# Making install in h5perf
# make[3]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/src/h5perf'
# make[4]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/src/h5perf'
#  /usr/bin/mkdir -p '/home/soporte/tmp/2022/wrf/bin'
#   /bin/bash ../../../libtool   --mode=install /usr/bin/install -c h5perf_serial '/home/soporte/tmp/2022/wrf/bin'
# libtool: install: /usr/bin/install -c .libs/h5perf_serial /home/soporte/tmp/2022/wrf/bin/h5perf_serial
# make[4]: No se hace nada para 'install-data-am'.
# make[4]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/src/h5perf'
# make[3]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/src/h5perf'
# make[3]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/src'
# make[4]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/src'
# make[4]: No se hace nada para 'install-exec-am'.
# make[4]: No se hace nada para 'install-data-am'.
# make[4]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/src'
# make[3]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/src'
# make[2]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/src'
# Making install in test
# make[2]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/test'
# Making install in h5diff
# make[3]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/test/h5diff'
# make[4]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/test/h5diff'
# make[4]: No se hace nada para 'install-exec-am'.
# make[4]: No se hace nada para 'install-data-am'.
# make[4]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/test/h5diff'
# make[3]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/test/h5diff'
# Making install in h5ls
# make[3]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/test/h5ls'
# make[4]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/test/h5ls'
# make[4]: No se hace nada para 'install-exec-am'.
# make[4]: No se hace nada para 'install-data-am'.
# make[4]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/test/h5ls'
# make[3]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/test/h5ls'
# Making install in h5dump
# make[3]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/test/h5dump'
# make[4]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/test/h5dump'
# make[4]: No se hace nada para 'install-exec-am'.
# make[4]: No se hace nada para 'install-data-am'.
# make[4]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/test/h5dump'
# make[3]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/test/h5dump'
# Making install in misc
# make[3]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/test/misc'
# Making install in vds
# make[4]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/test/misc/vds'
# make[5]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/test/misc/vds'
# make[5]: No se hace nada para 'install-exec-am'.
# make[5]: No se hace nada para 'install-data-am'.
# make[5]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/test/misc/vds'
# make[4]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/test/misc/vds'
# make[4]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/test/misc'
# make[5]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/test/misc'
# make[5]: No se hace nada para 'install-exec-am'.
# make[5]: No se hace nada para 'install-data-am'.
# make[5]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/test/misc'
# make[4]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/test/misc'
# make[3]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/test/misc'
# Making install in h5import
# make[3]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/test/h5import'
# make[4]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/test/h5import'
# make[4]: No se hace nada para 'install-exec-am'.
# make[4]: No se hace nada para 'install-data-am'.
# make[4]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/test/h5import'
# make[3]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/test/h5import'
# Making install in h5repack
# make[3]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/test/h5repack'
# make[4]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/test/h5repack'
# make[4]: No se hace nada para 'install-exec-am'.
# make[4]: No se hace nada para 'install-data-am'.
# make[4]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/test/h5repack'
# make[3]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/test/h5repack'
# Making install in h5jam
# make[3]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/test/h5jam'
# make[4]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/test/h5jam'
# make[4]: No se hace nada para 'install-exec-am'.
# make[4]: No se hace nada para 'install-data-am'.
# make[4]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/test/h5jam'
# make[3]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/test/h5jam'
# Making install in h5copy
# make[3]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/test/h5copy'
# make[4]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/test/h5copy'
# make[4]: No se hace nada para 'install-exec-am'.
# make[4]: No se hace nada para 'install-data-am'.
# make[4]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/test/h5copy'
# make[3]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/test/h5copy'
# Making install in h5format_convert
# make[3]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/test/h5format_convert'
# make[4]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/test/h5format_convert'
# make[4]: No se hace nada para 'install-exec-am'.
# make[4]: No se hace nada para 'install-data-am'.
# make[4]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/test/h5format_convert'
# make[3]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/test/h5format_convert'
# Making install in h5stat
# make[3]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/test/h5stat'
# make[4]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/test/h5stat'
# make[4]: No se hace nada para 'install-exec-am'.
# make[4]: No se hace nada para 'install-data-am'.
# make[4]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/test/h5stat'
# make[3]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/test/h5stat'
# Making install in perform
# make[3]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/test/perform'
# make[4]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/test/perform'
# make[4]: No se hace nada para 'install-exec-am'.
# make[4]: No se hace nada para 'install-data-am'.
# make[4]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/test/perform'
# make[3]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/test/perform'
# make[3]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/test'
# make[4]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/test'
# make[4]: No se hace nada para 'install-exec-am'.
# make[4]: No se hace nada para 'install-data-am'.
# make[4]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/test'
# make[3]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/test'
# make[2]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/test'
# Making install in libtest
# make[2]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/libtest'
# make[3]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/libtest'
# make[3]: No se hace nada para 'install-exec-am'.
# make[3]: No se hace nada para 'install-data-am'.
# make[3]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/libtest'
# make[2]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools/libtest'
# make[2]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools'
# make[3]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools'
# make[3]: No se hace nada para 'install-exec-am'.
# make[3]: No se hace nada para 'install-data-am'.
# make[3]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools'
# make[2]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools'
# make[1]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/tools'
# Making install in .
# make[1]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8'
# make[2]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8'
# make[2]: No se hace nada para 'install-exec-am'.
# make[2]: No se hace nada para 'install-data-am'.
# make[2]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8'
# make[1]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8'
# Making install in fortran
# make[1]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/fortran'
# Making install in src
# make[2]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/fortran/src'
# make  install-am
# make[3]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/fortran/src'
# make[4]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/fortran/src'
#  /usr/bin/mkdir -p '/home/soporte/tmp/2022/wrf/lib'
#  /bin/bash ../../libtool   --mode=install /usr/bin/install -c   libhdf5_fortran.la '/home/soporte/tmp/2022/wrf/lib'
# libtool: install: (cd /LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/fortran/src; /bin/bash "/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/libtool"  --silent --tag FC --mode=relink ifort -stand:f03 -free -warn:all -O3 -I../../src -I../../fortran/src -version-info 103:1:1 -L/home/soporte/tmp/2022/wrf/lib -L/home/soporte/tmp/2022/wrf/lib -L/home/soporte/tmp/2022/wrf/lib -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o libhdf5_fortran.la -rpath /home/soporte/tmp/2022/wrf/lib H5f90global.lo H5fortran_types.lo H5_ff.lo H5Aff.lo H5Dff.lo H5Eff.lo H5Fff.lo H5Gff.lo H5Iff.lo H5Lff.lo H5Off.lo H5Pff.lo H5Rff.lo H5Sff.lo H5Tff.lo H5Zff.lo H5_gen.lo H5fortkit.lo H5f90kit.lo H5_f.lo H5Af.lo H5Df.lo H5Ef.lo H5Ff.lo H5Gf.lo H5If.lo H5Lf.lo H5Of.lo H5Pf.lo H5Rf.lo H5Sf.lo H5Tf.lo H5Zf.lo HDF5.lo ../../src/libhdf5.la -lsz -lz -ldl -lm )
# libtool: install: /usr/bin/install -c .libs/libhdf5_fortran.so.102.1.1T /home/soporte/tmp/2022/wrf/lib/libhdf5_fortran.so.102.1.1
# libtool: install: (cd /home/soporte/tmp/2022/wrf/lib && { ln -s -f libhdf5_fortran.so.102.1.1 libhdf5_fortran.so.102 || { rm -f libhdf5_fortran.so.102 && ln -s libhdf5_fortran.so.102.1.1 libhdf5_fortran.so.102; }; })
# libtool: install: (cd /home/soporte/tmp/2022/wrf/lib && { ln -s -f libhdf5_fortran.so.102.1.1 libhdf5_fortran.so || { rm -f libhdf5_fortran.so && ln -s libhdf5_fortran.so.102.1.1 libhdf5_fortran.so; }; })
# libtool: install: /usr/bin/install -c .libs/libhdf5_fortran.lai /home/soporte/tmp/2022/wrf/lib/libhdf5_fortran.la
# libtool: install: /usr/bin/install -c .libs/libhdf5_fortran.a /home/soporte/tmp/2022/wrf/lib/libhdf5_fortran.a
# libtool: install: chmod 644 /home/soporte/tmp/2022/wrf/lib/libhdf5_fortran.a
# libtool: install: ranlib /home/soporte/tmp/2022/wrf/lib/libhdf5_fortran.a
# libtool: finish: PATH="/opt/software/apps/intel/oneapi/mpi/2021.5.1//libfabric/bin:/opt/software/apps/intel/oneapi/mpi/2021.5.1//bin:/opt/software/apps/intel/oneapi/compiler/2022.0.2/linux/lib/oclfpga/bin:/opt/software/apps/intel/oneapi/compiler/2022.0.2/linux/bin/intel64:/opt/software/apps/intel/oneapi/compiler/2022.0.2/linux/bin:/opt/software/apps/slurm/slurm/bin:/usr/local/bin:/usr/bin:/bin:/usr/local/games:/usr/games:/home/soporte/bin:/sbin" ldconfig -n /home/soporte/tmp/2022/wrf/lib
# ----------------------------------------------------------------------
# Libraries have been installed in:
#    /home/soporte/tmp/2022/wrf/lib
#
# If you ever happen to want to link against installed libraries
# in a given directory, LIBDIR, you must either use libtool, and
# specify the full pathname of the library, or use the '-LLIBDIR'
# flag during linking and do at least one of the following:
#    - add LIBDIR to the 'LD_LIBRARY_PATH' environment variable
#      during execution
#    - add LIBDIR to the 'LD_RUN_PATH' environment variable
#      during linking
#    - use the '-Wl,-rpath -Wl,LIBDIR' linker flag
#    - have your system administrator add LIBDIR to '/etc/ld.so.conf'
#
# See any operating system documentation about shared libraries for
# more information, such as the ld(1) and ld.so(8) manual pages.
# ----------------------------------------------------------------------
# cp ../../fortran/src/H5f90i_gen.h /home/soporte/tmp/2022/wrf/include/.
# cp ../../fortran/src/H5f90i.h /home/soporte/tmp/2022/wrf/include/.
# make[4]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/fortran/src'
# make[3]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/fortran/src'
# make[2]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/fortran/src'
# Making install in test
# make[2]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/fortran/test'
# make[3]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/fortran/test'
# make[3]: No se hace nada para 'install-exec-am'.
# make[3]: No se hace nada para 'install-data-am'.
# make[3]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/fortran/test'
# make[2]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/fortran/test'
# make[2]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/fortran'
# make[3]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/fortran'
# make[3]: No se hace nada para 'install-exec-am'.
# make[3]: No se hace nada para 'install-data-am'.
# make[3]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/fortran'
# make[2]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/fortran'
# make[1]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/fortran'
# Making install in hl
# make[1]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/hl'
# Making install in src
# make[2]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/hl/src'
# make[3]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/hl/src'
#  /usr/bin/mkdir -p '/home/soporte/tmp/2022/wrf/lib'
#  /bin/bash ../../libtool   --mode=install /usr/bin/install -c   libhdf5_hl.la '/home/soporte/tmp/2022/wrf/lib'
# libtool: install: (cd /LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/hl/src; /bin/bash "/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/libtool"  --silent --tag CC --mode=relink icc -std=c99 -Wall -Wcomment -Wdeprecated -Wextra-tokens -Wformat -Wformat-security -Wmain -Wmissing-declarations -Wmissing-prototypes -Wp64 -Wpointer-arith -Wreturn-type -Wshadow -Wstrict-prototypes -Wtrigraphs -Wuninitialized -Wunknown-pragmas -Wunused-function -Wunused-variable -Wwrite-strings -Wic-pointer -Wsign-compare -Wl,-s -O3 -O3 -version-info 101:5:1 -L/home/soporte/tmp/2022/wrf/lib -L/home/soporte/tmp/2022/wrf/lib -L/home/soporte/tmp/2022/wrf/lib -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o libhdf5_hl.la -rpath /home/soporte/tmp/2022/wrf/lib H5DO.lo H5DS.lo H5IM.lo H5LT.lo H5LTanalyze.lo H5LTparse.lo H5PT.lo H5TB.lo H5LD.lo ../../src/libhdf5.la -lsz -lz -ldl -lm )
# libtool: install: /usr/bin/install -c .libs/libhdf5_hl.so.100.1.5T /home/soporte/tmp/2022/wrf/lib/libhdf5_hl.so.100.1.5
# libtool: install: (cd /home/soporte/tmp/2022/wrf/lib && { ln -s -f libhdf5_hl.so.100.1.5 libhdf5_hl.so.100 || { rm -f libhdf5_hl.so.100 && ln -s libhdf5_hl.so.100.1.5 libhdf5_hl.so.100; }; })
# libtool: install: (cd /home/soporte/tmp/2022/wrf/lib && { ln -s -f libhdf5_hl.so.100.1.5 libhdf5_hl.so || { rm -f libhdf5_hl.so && ln -s libhdf5_hl.so.100.1.5 libhdf5_hl.so; }; })
# libtool: install: /usr/bin/install -c .libs/libhdf5_hl.lai /home/soporte/tmp/2022/wrf/lib/libhdf5_hl.la
# libtool: install: /usr/bin/install -c .libs/libhdf5_hl.a /home/soporte/tmp/2022/wrf/lib/libhdf5_hl.a
# libtool: install: chmod 644 /home/soporte/tmp/2022/wrf/lib/libhdf5_hl.a
# libtool: install: ranlib /home/soporte/tmp/2022/wrf/lib/libhdf5_hl.a
# libtool: finish: PATH="/opt/software/apps/intel/oneapi/mpi/2021.5.1//libfabric/bin:/opt/software/apps/intel/oneapi/mpi/2021.5.1//bin:/opt/software/apps/intel/oneapi/compiler/2022.0.2/linux/lib/oclfpga/bin:/opt/software/apps/intel/oneapi/compiler/2022.0.2/linux/bin/intel64:/opt/software/apps/intel/oneapi/compiler/2022.0.2/linux/bin:/opt/software/apps/slurm/slurm/bin:/usr/local/bin:/usr/bin:/bin:/usr/local/games:/usr/games:/home/soporte/bin:/sbin" ldconfig -n /home/soporte/tmp/2022/wrf/lib
# ----------------------------------------------------------------------
# Libraries have been installed in:
#    /home/soporte/tmp/2022/wrf/lib
#
# If you ever happen to want to link against installed libraries
# in a given directory, LIBDIR, you must either use libtool, and
# specify the full pathname of the library, or use the '-LLIBDIR'
# flag during linking and do at least one of the following:
#    - add LIBDIR to the 'LD_LIBRARY_PATH' environment variable
#      during execution
#    - add LIBDIR to the 'LD_RUN_PATH' environment variable
#      during linking
#    - use the '-Wl,-rpath -Wl,LIBDIR' linker flag
#    - have your system administrator add LIBDIR to '/etc/ld.so.conf'
#
# See any operating system documentation about shared libraries for
# more information, such as the ld(1) and ld.so(8) manual pages.
# ----------------------------------------------------------------------
#  /usr/bin/mkdir -p '/home/soporte/tmp/2022/wrf/include'
#  /usr/bin/install -c -m 644 hdf5_hl.h H5DOpublic.h H5IMpublic.h H5LTpublic.h H5TBpublic.h H5DSpublic.h H5PTpublic.h H5LDpublic.h '/home/soporte/tmp/2022/wrf/include'
# make[3]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/hl/src'
# make[2]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/hl/src'
# Making install in test
# make[2]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/hl/test'
# make[3]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/hl/test'
# make[3]: No se hace nada para 'install-exec-am'.
# make[3]: No se hace nada para 'install-data-am'.
# make[3]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/hl/test'
# make[2]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/hl/test'
# Making install in fortran
# make[2]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/hl/fortran'
# Making install in src
# make[3]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/hl/fortran/src'
# make[4]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/hl/fortran/src'
#  /usr/bin/mkdir -p '/home/soporte/tmp/2022/wrf/lib'
#  /bin/bash ../../../libtool   --mode=install /usr/bin/install -c   libhdf5hl_fortran.la '/home/soporte/tmp/2022/wrf/lib'
# libtool: install: (cd /LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/hl/fortran/src; /bin/bash "/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/libtool"  --silent --tag FC --mode=relink ifort -stand:f03 -free -warn:all -O3 -I../../../fortran/src -I../../../fortran/src -version-info 100:7:0 -L/home/soporte/tmp/2022/wrf/lib -L/home/soporte/tmp/2022/wrf/lib -L/home/soporte/tmp/2022/wrf/lib -Wl,-rpath=/home/soporte/tmp/2022/wrf/lib -o libhdf5hl_fortran.la -rpath /home/soporte/tmp/2022/wrf/lib H5DSfc.lo H5LTfc.lo H5IMfc.lo H5IMcc.lo H5TBfc.lo H5DSff.lo H5LTff.lo H5TBff.lo H5IMff.lo H5LTff_gen.lo H5TBff_gen.lo ../../../hl/src/libhdf5_hl.la ../../../fortran/src/libhdf5_fortran.la -lsz -lz -ldl -lm )
# libtool: install: /usr/bin/install -c .libs/libhdf5hl_fortran.so.100.0.7T /home/soporte/tmp/2022/wrf/lib/libhdf5hl_fortran.so.100.0.7
# libtool: install: (cd /home/soporte/tmp/2022/wrf/lib && { ln -s -f libhdf5hl_fortran.so.100.0.7 libhdf5hl_fortran.so.100 || { rm -f libhdf5hl_fortran.so.100 && ln -s libhdf5hl_fortran.so.100.0.7 libhdf5hl_fortran.so.100; }; })
# libtool: install: (cd /home/soporte/tmp/2022/wrf/lib && { ln -s -f libhdf5hl_fortran.so.100.0.7 libhdf5hl_fortran.so || { rm -f libhdf5hl_fortran.so && ln -s libhdf5hl_fortran.so.100.0.7 libhdf5hl_fortran.so; }; })
# libtool: install: /usr/bin/install -c .libs/libhdf5hl_fortran.lai /home/soporte/tmp/2022/wrf/lib/libhdf5hl_fortran.la
# libtool: install: /usr/bin/install -c .libs/libhdf5hl_fortran.a /home/soporte/tmp/2022/wrf/lib/libhdf5hl_fortran.a
# libtool: install: chmod 644 /home/soporte/tmp/2022/wrf/lib/libhdf5hl_fortran.a
# libtool: install: ranlib /home/soporte/tmp/2022/wrf/lib/libhdf5hl_fortran.a
# libtool: finish: PATH="/opt/software/apps/intel/oneapi/mpi/2021.5.1//libfabric/bin:/opt/software/apps/intel/oneapi/mpi/2021.5.1//bin:/opt/software/apps/intel/oneapi/compiler/2022.0.2/linux/lib/oclfpga/bin:/opt/software/apps/intel/oneapi/compiler/2022.0.2/linux/bin/intel64:/opt/software/apps/intel/oneapi/compiler/2022.0.2/linux/bin:/opt/software/apps/slurm/slurm/bin:/usr/local/bin:/usr/bin:/bin:/usr/local/games:/usr/games:/home/soporte/bin:/sbin" ldconfig -n /home/soporte/tmp/2022/wrf/lib
# ----------------------------------------------------------------------
# Libraries have been installed in:
#    /home/soporte/tmp/2022/wrf/lib
#
# If you ever happen to want to link against installed libraries
# in a given directory, LIBDIR, you must either use libtool, and
# specify the full pathname of the library, or use the '-LLIBDIR'
# flag during linking and do at least one of the following:
#    - add LIBDIR to the 'LD_LIBRARY_PATH' environment variable
#      during execution
#    - add LIBDIR to the 'LD_RUN_PATH' environment variable
#      during linking
#    - use the '-Wl,-rpath -Wl,LIBDIR' linker flag
#    - have your system administrator add LIBDIR to '/etc/ld.so.conf'
#
# See any operating system documentation about shared libraries for
# more information, such as the ld(1) and ld.so(8) manual pages.
# ----------------------------------------------------------------------
# make  install-exec-hook
# make[5]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/hl/fortran/src'
# cd /home/soporte/tmp/2022/wrf/lib && \
#     if test -f libhdf5hl_fortran.a -a \
#     ! -f libhdf5_hl_fortran.a; then \
#         ln -s libhdf5hl_fortran.a libhdf5_hl_fortran.a; \
#     fi; \
#     if test -f libhdf5hl_fortran.so -a \
#     ! -f libhdf5_hl_fortran.so; then \
#         ln -s libhdf5hl_fortran.so libhdf5_hl_fortran.so; \
#     fi;
# make[5]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/hl/fortran/src'
# make[4]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/hl/fortran/src'
# make[3]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/hl/fortran/src'
# Making install in test
# make[3]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/hl/fortran/test'
# make[4]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/hl/fortran/test'
# make[4]: No se hace nada para 'install-exec-am'.
# make[4]: No se hace nada para 'install-data-am'.
# make[4]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/hl/fortran/test'
# make[3]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/hl/fortran/test'
# make[3]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/hl/fortran'
# make[4]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/hl/fortran'
# make[4]: No se hace nada para 'install-exec-am'.
# make[4]: No se hace nada para 'install-data-am'.
# make[4]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/hl/fortran'
# make[3]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/hl/fortran'
# make[2]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/hl/fortran'
# make[2]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/hl'
# make[3]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/hl'
# make[3]: No se hace nada para 'install-exec-am'.
# make[3]: No se hace nada para 'install-data-am'.
# make[3]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/hl'
# make[2]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/hl'
# make[1]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/hl'
# for d in examples fortran hl; do               \
#     (cd $d && make  install-examples) || exit 1;           \
# done
# make[1]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/examples'
# ../bin/mkdirs /home/soporte/tmp/2022/wrf/share/hdf5_examples/c
# make[1]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/examples'
# make[1]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/fortran'
# make[2]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/fortran/examples'
# ../../bin/mkdirs /home/soporte/tmp/2022/wrf/share/hdf5_examples/fortran
# make[2]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/fortran/examples'
# make[1]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/fortran'
# make[1]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/hl'
# for d in examples fortran; do               \
#     (cd $d && make  install-examples) || exit 1;           \
# done
# make[2]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/hl/examples'
# ../../bin/mkdirs /home/soporte/tmp/2022/wrf/share/hdf5_examples/hl/c
# make[2]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/hl/examples'
# make[2]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/hl/fortran'
# make[3]: se entra en el directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/hl/fortran/examples'
# ../../../bin/mkdirs /home/soporte/tmp/2022/wrf/share/hdf5_examples/hl/fortran
# make[3]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/hl/fortran/examples'
# make[2]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/hl/fortran'
# make[1]: se sale del directorio '/LUSTRE/tmp/soporte/compila-WRF/build/hdf5-1.10.8/hl'
# libtool: warning: relinking 'libhdf5_fortran.la'
# ifort: command line warning #10434: option '-nofor_main' use with underscore is deprecated; use '-nofor-main' instead
# libtool: warning: relinking 'libhdf5_hl.la'
# libtool: warning: relinking 'libhdf5hl_fortran.la'
# ifort: command line warning #10434: option '-nofor_main' use with underscore is deprecated; use '-nofor-main' instead
# + /usr/bin/install -c ./h5_write.c /home/soporte/tmp/2022/wrf/share/hdf5_examples/c/.
# + /usr/bin/install -c ./h5_read.c /home/soporte/tmp/2022/wrf/share/hdf5_examples/c/.
# + /usr/bin/install -c ./h5_extend_write.c /home/soporte/tmp/2022/wrf/share/hdf5_examples/c/.
# + /usr/bin/install -c ./h5_chunk_read.c /home/soporte/tmp/2022/wrf/share/hdf5_examples/c/.
# + /usr/bin/install -c ./h5_compound.c /home/soporte/tmp/2022/wrf/share/hdf5_examples/c/.
# + /usr/bin/install -c ./h5_crtgrpd.c /home/soporte/tmp/2022/wrf/share/hdf5_examples/c/.
# + /usr/bin/install -c ./h5_subset.c /home/soporte/tmp/2022/wrf/share/hdf5_examples/c/.
# + /usr/bin/install -c ./h5_cmprss.c /home/soporte/tmp/2022/wrf/share/hdf5_examples/c/.
# + /usr/bin/install -c ./h5_rdwt.c /home/soporte/tmp/2022/wrf/share/hdf5_examples/c/.
# + /usr/bin/install -c ./h5_crtgrpar.c /home/soporte/tmp/2022/wrf/share/hdf5_examples/c/.
# + /usr/bin/install -c ./h5_extend.c /home/soporte/tmp/2022/wrf/share/hdf5_examples/c/.
# + /usr/bin/install -c ./h5_crtatt.c /home/soporte/tmp/2022/wrf/share/hdf5_examples/c/.
# + /usr/bin/install -c ./h5_crtgrp.c /home/soporte/tmp/2022/wrf/share/hdf5_examples/c/.
# + /usr/bin/install -c ./h5_crtdat.c /home/soporte/tmp/2022/wrf/share/hdf5_examples/c/.
# + /usr/bin/install -c ./h5_group.c /home/soporte/tmp/2022/wrf/share/hdf5_examples/c/.
# + /usr/bin/install -c ./h5_select.c /home/soporte/tmp/2022/wrf/share/hdf5_examples/c/.
# + /usr/bin/install -c ./h5_attribute.c /home/soporte/tmp/2022/wrf/share/hdf5_examples/c/.
# + /usr/bin/install -c ./h5_mount.c /home/soporte/tmp/2022/wrf/share/hdf5_examples/c/.
# + /usr/bin/install -c ./h5_drivers.c /home/soporte/tmp/2022/wrf/share/hdf5_examples/c/.
# + /usr/bin/install -c ./h5_reference.c /home/soporte/tmp/2022/wrf/share/hdf5_examples/c/.
# + /usr/bin/install -c ./h5_ref2reg.c /home/soporte/tmp/2022/wrf/share/hdf5_examples/c/.
# + /usr/bin/install -c ./h5_extlink.c /home/soporte/tmp/2022/wrf/share/hdf5_examples/c/.
# + /usr/bin/install -c ./h5_elink_unix2win.c /home/soporte/tmp/2022/wrf/share/hdf5_examples/c/.
# + /usr/bin/install -c ./h5_shared_mesg.c /home/soporte/tmp/2022/wrf/share/hdf5_examples/c/.
# + /usr/bin/install -c ./h5_debug_trace.c /home/soporte/tmp/2022/wrf/share/hdf5_examples/c/.
# + /usr/bin/install -c ./ph5example.c /home/soporte/tmp/2022/wrf/share/hdf5_examples/c/.
# + /usr/bin/install -c ./h5_vds.c /home/soporte/tmp/2022/wrf/share/hdf5_examples/c/.
# + /usr/bin/install -c ./h5_vds-exc.c /home/soporte/tmp/2022/wrf/share/hdf5_examples/c/.
# + /usr/bin/install -c ./h5_vds-exclim.c /home/soporte/tmp/2022/wrf/share/hdf5_examples/c/.
# + /usr/bin/install -c ./h5_vds-eiger.c /home/soporte/tmp/2022/wrf/share/hdf5_examples/c/.
# + /usr/bin/install -c ./h5_vds-simpleIO.c /home/soporte/tmp/2022/wrf/share/hdf5_examples/c/.
# + /usr/bin/install -c ./h5_vds-percival.c /home/soporte/tmp/2022/wrf/share/hdf5_examples/c/.
# + /usr/bin/install -c ./h5_vds-percival-unlim.c /home/soporte/tmp/2022/wrf/share/hdf5_examples/c/.
# + /usr/bin/install -c ./h5_vds-percival-unlim-maxmin.c /home/soporte/tmp/2022/wrf/share/hdf5_examples/c/.
# + /usr/bin/install -c run-c-ex.sh /home/soporte/tmp/2022/wrf/share/hdf5_examples/c/.
# + /usr/bin/install -c ./README /home/soporte/tmp/2022/wrf/share/hdf5_examples/.
# + /usr/bin/install -c ./run-all-ex.sh /home/soporte/tmp/2022/wrf/share/hdf5_examples/.
# + /usr/bin/install -c ./h5_crtdat.f90 /home/soporte/tmp/2022/wrf/share/hdf5_examples/fortran/.
# + /usr/bin/install -c ./h5_rdwt.f90 /home/soporte/tmp/2022/wrf/share/hdf5_examples/fortran/.
# + /usr/bin/install -c ./h5_crtatt.f90 /home/soporte/tmp/2022/wrf/share/hdf5_examples/fortran/.
# + /usr/bin/install -c ./h5_crtgrp.f90 /home/soporte/tmp/2022/wrf/share/hdf5_examples/fortran/.
# + /usr/bin/install -c ./h5_crtgrpar.f90 /home/soporte/tmp/2022/wrf/share/hdf5_examples/fortran/.
# + /usr/bin/install -c ./h5_crtgrpd.f90 /home/soporte/tmp/2022/wrf/share/hdf5_examples/fortran/.
# + /usr/bin/install -c ./h5_extend.f90 /home/soporte/tmp/2022/wrf/share/hdf5_examples/fortran/.
# + /usr/bin/install -c ./h5_subset.f90 /home/soporte/tmp/2022/wrf/share/hdf5_examples/fortran/.
# + /usr/bin/install -c ./h5_cmprss.f90 /home/soporte/tmp/2022/wrf/share/hdf5_examples/fortran/.
# + /usr/bin/install -c ./hyperslab.f90 /home/soporte/tmp/2022/wrf/share/hdf5_examples/fortran/.
# + /usr/bin/install -c ./selectele.f90 /home/soporte/tmp/2022/wrf/share/hdf5_examples/fortran/.
# + /usr/bin/install -c ./refobjexample.f90 /home/soporte/tmp/2022/wrf/share/hdf5_examples/fortran/.
# + /usr/bin/install -c ./refregexample.f90 /home/soporte/tmp/2022/wrf/share/hdf5_examples/fortran/.
# + /usr/bin/install -c ./mountexample.f90 /home/soporte/tmp/2022/wrf/share/hdf5_examples/fortran/.
# + /usr/bin/install -c ./compound.f90 /home/soporte/tmp/2022/wrf/share/hdf5_examples/fortran/.
# + /usr/bin/install -c ./ph5example.f90 /home/soporte/tmp/2022/wrf/share/hdf5_examples/fortran/.
# + /usr/bin/install -c ./rwdset_fortran2003.f90 /home/soporte/tmp/2022/wrf/share/hdf5_examples/fortran/.
# + /usr/bin/install -c ./nested_derived_type.f90 /home/soporte/tmp/2022/wrf/share/hdf5_examples/fortran/.
# + /usr/bin/install -c ./compound_fortran2003.f90 /home/soporte/tmp/2022/wrf/share/hdf5_examples/fortran/.
# + /usr/bin/install -c ./compound_complex_fortran2003.f90 /home/soporte/tmp/2022/wrf/share/hdf5_examples/fortran/.
# + /usr/bin/install -c run-fortran-ex.sh /home/soporte/tmp/2022/wrf/share/hdf5_examples/fortran/.
# + /usr/bin/install -c ./ex_lite1.c /home/soporte/tmp/2022/wrf/share/hdf5_examples/hl/c/.
# + /usr/bin/install -c ./ex_lite2.c /home/soporte/tmp/2022/wrf/share/hdf5_examples/hl/c/.
# + /usr/bin/install -c ./ex_lite3.c /home/soporte/tmp/2022/wrf/share/hdf5_examples/hl/c/.
# + /usr/bin/install -c ./ptExampleFL.c /home/soporte/tmp/2022/wrf/share/hdf5_examples/hl/c/.
# + /usr/bin/install -c ./ex_image1.c /home/soporte/tmp/2022/wrf/share/hdf5_examples/hl/c/.
# + /usr/bin/install -c ./ex_image2.c /home/soporte/tmp/2022/wrf/share/hdf5_examples/hl/c/.
# + /usr/bin/install -c ./ex_table_01.c /home/soporte/tmp/2022/wrf/share/hdf5_examples/hl/c/.
# + /usr/bin/install -c ./ex_table_02.c /home/soporte/tmp/2022/wrf/share/hdf5_examples/hl/c/.
# + /usr/bin/install -c ./ex_table_03.c /home/soporte/tmp/2022/wrf/share/hdf5_examples/hl/c/.
# + /usr/bin/install -c ./ex_table_04.c /home/soporte/tmp/2022/wrf/share/hdf5_examples/hl/c/.
# + /usr/bin/install -c ./ex_table_05.c /home/soporte/tmp/2022/wrf/share/hdf5_examples/hl/c/.
# + /usr/bin/install -c ./ex_table_06.c /home/soporte/tmp/2022/wrf/share/hdf5_examples/hl/c/.
# + /usr/bin/install -c ./ex_table_07.c /home/soporte/tmp/2022/wrf/share/hdf5_examples/hl/c/.
# + /usr/bin/install -c ./ex_table_08.c /home/soporte/tmp/2022/wrf/share/hdf5_examples/hl/c/.
# + /usr/bin/install -c ./ex_table_09.c /home/soporte/tmp/2022/wrf/share/hdf5_examples/hl/c/.
# + /usr/bin/install -c ./ex_table_10.c /home/soporte/tmp/2022/wrf/share/hdf5_examples/hl/c/.
# + /usr/bin/install -c ./ex_table_11.c /home/soporte/tmp/2022/wrf/share/hdf5_examples/hl/c/.
# + /usr/bin/install -c ./ex_table_12.c /home/soporte/tmp/2022/wrf/share/hdf5_examples/hl/c/.
# + /usr/bin/install -c ./ex_ds1.c /home/soporte/tmp/2022/wrf/share/hdf5_examples/hl/c/.
# + /usr/bin/install -c ./image24pixel.txt /home/soporte/tmp/2022/wrf/share/hdf5_examples/hl/c/.
# + /usr/bin/install -c ./image8.txt /home/soporte/tmp/2022/wrf/share/hdf5_examples/hl/c/.
# + /usr/bin/install -c ./pal_rgb.h /home/soporte/tmp/2022/wrf/share/hdf5_examples/hl/c/.
# + /usr/bin/install -c run-hlc-ex.sh /home/soporte/tmp/2022/wrf/share/hdf5_examples/hl/c/.
# + /usr/bin/install -c ./run-hl-ex.sh /home/soporte/tmp/2022/wrf/share/hdf5_examples/hl/.
# + /usr/bin/install -c ./exlite.f90 /home/soporte/tmp/2022/wrf/share/hdf5_examples/hl/fortran/.
# + /usr/bin/install -c ./ex_ds1.f90 /home/soporte/tmp/2022/wrf/share/hdf5_examples/hl/fortran/.
# + /usr/bin/install -c run-hlfortran-ex.sh /home/soporte/tmp/2022/wrf/share/hdf5_examples/hl/fortran/.

# %% [markdown]
# ## Contenido del directorio  $HOME/tmp/2022/wrf

# %%
# %%bash
#
# tree -d $HOME/tmp/2022/wrf
# Out:
# /home/soporte/tmp/2022/wrf
# ├── bin
# ├── include
# │   ├── curl
# │   ├── jasper
# │   └── libpng16
# ├── lib
# │   └── pkgconfig
# └── share
#     ├── aclocal
#     ├── hdf5_examples
#     │   ├── c
#     │   ├── fortran
#     │   └── hl
#     │       ├── c
#     │       └── fortran
#     └── man
#         ├── man1
#         ├── man3
#         └── man5
#
# 19 directories
